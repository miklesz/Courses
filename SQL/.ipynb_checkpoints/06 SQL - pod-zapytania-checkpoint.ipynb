-- %% [markdown]
-- # SQL - pod-zapytania
-- ![](https://memegenerator.net/img/instances/14499321/yo-dawg-i-heard-you-like-queries-so-i-put-subquery-in-your-sql-query.jpg)

-- %% [markdown]
-- ## Konspekt

-- %% [markdown]
-- * Pod-zapytania
-- * Zadania utrwalające 3

-- %% [markdown]
-- ## Pod-zapytania

-- %% [markdown]
-- Tworzenie podzapytania polega na zagnieżdżaniu zapytania w innym zapytaniu.
--
-- Aby je zagnieździć, wystarczy w miejscu, w którym oczekujemy zwróconej przez podzapytanie wartości, wstawić nawiasy i zapisać pomiędzy nimi zapytanie w takiej samej formie jak zwykłe zapytanie.
--
-- ```sqlite
-- SELECT kolumna,kolumna2,.. FROM tabela WHERE kolumna=(SELECT kolumna FROM tabela2);
-- ```

-- %% [markdown]
-- #### Przykład
--
-- **Wybieramy id, imię i nazwisko autora który napisał książkę o tytule “`Solaris`”**
--
-- Tabela **`Authors`**:

-- %%
%LOAD library_db.db rw

-- %%
SELECT * FROM authors;
-- Out:
-- +----+------------+------------+
-- | ID | surname    | name       |
-- +----+------------+------------+
-- | 1  | Lem        | Stanisław |
-- +----+------------+------------+
-- | 2  | Kosik      | Rafał     |
-- +----+------------+------------+
-- | 3  | Gombrowicz | Witold     |
-- +----+------------+------------+
-- | 4  | Mrożek    | Sławomir  |
-- +----+------------+------------+
-- | 5  | Dukaj      | Jacek      |
-- +----+------------+------------+
-- | 6  | Sapkowki   | Andrzej    |
-- +----+------------+------------+

-- %% [markdown]
-- Tabela **`Titles`**:

-- %%
SELECT * FROM titles;
-- Out:
-- +----+---------------------------------------+-----------+
-- | ID | title                                 | author_id |
-- +----+---------------------------------------+-----------+
-- | 1  | Solaris                               | 1         |
-- +----+---------------------------------------+-----------+
-- | 2  | Cyberiada                             | 1         |
-- +----+---------------------------------------+-----------+
-- | 3  | Katar                                 | 1         |
-- +----+---------------------------------------+-----------+
-- | 4  | Bajki robotów                        | 1         |
-- +----+---------------------------------------+-----------+
-- | 5  | Opowieści o Pilocie Pirxie           | 1         |
-- +----+---------------------------------------+-----------+
-- | 6  | Rękopis znaleziony w wannie          | 1         |
-- +----+---------------------------------------+-----------+
-- | 7  | Dzienniki gwiazdowe                   | 1         |
-- +----+---------------------------------------+-----------+
-- | 8  | Eden                                  | 1         |
-- +----+---------------------------------------+-----------+
-- | 9  | Śledztwo                             | 1         |
-- +----+---------------------------------------+-----------+
-- | 10 | Powrót z gwiazd                      | 1         |
-- +----+---------------------------------------+-----------+
-- | 11 | Niezwyciężony                       | 1         |
-- +----+---------------------------------------+-----------+
-- | 12 | Wysoki zamek                          | 1         |
-- +----+---------------------------------------+-----------+
-- | 13 | Głos Pana                            | 1         |
-- +----+---------------------------------------+-----------+
-- | 14 | Pożytek ze smoka                     | 1         |
-- +----+---------------------------------------+-----------+
-- | 15 | Sknocony kryminał                    | 1         |
-- +----+---------------------------------------+-----------+
-- | 16 | Mars                                  | 2         |
-- +----+---------------------------------------+-----------+
-- | 17 | Kameleon                              | 2         |
-- +----+---------------------------------------+-----------+
-- | 18 | Vertical                              | 2         |
-- +----+---------------------------------------+-----------+
-- | 19 | Różaniec                            | 2         |
-- +----+---------------------------------------+-----------+
-- | 20 | Obywatel który się zawiesił        | 2         |
-- +----+---------------------------------------+-----------+
-- | 21 | Pamiętniki z okresu dojrzewania      | 3         |
-- +----+---------------------------------------+-----------+
-- | 22 | Ferdydurke                            | 3         |
-- +----+---------------------------------------+-----------+
-- | 23 | Trans-Atlantyk                        | 3         |
-- +----+---------------------------------------+-----------+
-- | 24 | Iwona księżniczka Burgunda          | 3         |
-- +----+---------------------------------------+-----------+
-- | 25 | Ślub                                 | 3         |
-- +----+---------------------------------------+-----------+
-- | 26 | Operetka                              | 3         |
-- +----+---------------------------------------+-----------+
-- | 27 | Bakakaj                               | 3         |
-- +----+---------------------------------------+-----------+
-- | 28 | Tango                                 | 4         |
-- +----+---------------------------------------+-----------+
-- | 29 | Emigranci                             | 4         |
-- +----+---------------------------------------+-----------+
-- | 30 | Kynolog w rozterce                    | 4         |
-- +----+---------------------------------------+-----------+
-- | 31 | Miłość na Krymie                   | 4         |
-- +----+---------------------------------------+-----------+
-- | 32 | Wesele w Atomicach                    | 4         |
-- +----+---------------------------------------+-----------+
-- | 33 | Lód                                  | 5         |
-- +----+---------------------------------------+-----------+
-- | 34 | Wrociec                               | 5         |
-- +----+---------------------------------------+-----------+
-- | 35 | Perfekcyjna niedoskonałość         | 5         |
-- +----+---------------------------------------+-----------+
-- | 36 | Katedra                               | 5         |
-- +----+---------------------------------------+-----------+
-- | 37 | Narrenturm                            | 6         |
-- +----+---------------------------------------+-----------+
-- | 38 | Boży wojownicy                       | 6         |
-- +----+---------------------------------------+-----------+
-- | 39 | Lux perpetua                          | 6         |
-- +----+---------------------------------------+-----------+
-- | 40 | Rękopis znaleziony w smoczej jaskini | 6         |
-- +----+---------------------------------------+-----------+

-- %% [markdown]
-- Zapytanie i wynik zapytania:

-- %%
SELECT author_id FROM titles WHERE title='Solaris';
-- Out:
-- +-----------+
-- | author_id |
-- +-----------+
-- | 1         |
-- +-----------+

-- %%
SELECT id,name,surname FROM authors
WHERE id = '1';
-- Out:
-- +----+------------+---------+
-- | ID | name       | surname |
-- +----+------------+---------+
-- | 1  | Stanisław | Lem     |
-- +----+------------+---------+

-- %%
SELECT id,name,surname FROM authors
WHERE id = (SELECT author_id FROM titles WHERE title='Solaris');
-- Out:
-- +----+------------+---------+
-- | ID | name       | surname |
-- +----+------------+---------+
-- | 1  | Stanisław | Lem     |
-- +----+------------+---------+

-- %% [markdown]
-- #### Ćwiczenie
--
-- **Wybierz id i nazwę produktów zamówionych w zamówieniu o id `2`**
--
-- Tabela **`Product`**:

-- %%
%LOAD CodeBrainers.db rw

-- %%
SELECT * FROM product;
-- Out:
-- +----+---------+-------+--------+------------+
-- | id | name    | price | amount | date       |
-- +----+---------+-------+--------+------------+
-- | 5  | Spodnie | 100.0 | 5      | 2011-02-01 |
-- +----+---------+-------+--------+------------+
-- | 6  | Bluza   | 60.0  | 2      | 2011-02-12 |
-- +----+---------+-------+--------+------------+

-- %% [markdown]
-- Tabela **`Order_product`**:

-- %%
SELECT * FROM order_product;
-- Out:
-- +----------+------------+--------+
-- | order_id | product_id | amount |
-- +----------+------------+--------+
-- | 1        | 2          | 2      |
-- +----------+------------+--------+
-- | 1        | 4          | 1      |
-- +----------+------------+--------+
-- | 2        | 6          | 1      |
-- +----------+------------+--------+
-- | 2        | 8          | 1      |
-- +----------+------------+--------+
-- | 2        | 5          | 2      |
-- +----------+------------+--------+
-- | 3        | 5          | 1      |
-- +----------+------------+--------+
-- | 3        | 7          | 2      |
-- +----------+------------+--------+
-- | 4        | 5          | 1      |
-- +----------+------------+--------+
-- | 4        | 2          | 1      |
-- +----------+------------+--------+
-- | 4        | 7          | 2      |
-- +----------+------------+--------+
-- | 5        | 4          | 1      |
-- +----------+------------+--------+
-- | 6        | 6          | 1      |
-- +----------+------------+--------+

-- %% [markdown]
-- Wpisz zapytanie do bazy!

-- %% [markdown]
-- ---

-- %% [markdown]
-- Zapytanie i wynik zapytania:

-- %%
SELECT id,name FROM product
WHERE id IN (SELECT product_id FROM order_product WHERE order_id=2);
-- Out:
-- +----+---------+
-- | id | name    |
-- +----+---------+
-- | 5  | Spodnie |
-- +----+---------+
-- | 6  | Bluza   |
-- +----+---------+

-- %% [markdown]
-- Wynik każdego zapytania `SELECT` można traktować jak kolejną (wirtualną) tabelę. W efekcie możemy wykonywać na takiej tabeli zapytania.
--
-- * Pod-zapytania w `FROM`
-- * Pod-zapytania w `WHERE`
-- * Pod-zapytania w `SELECT`

-- %% [markdown]
-- ### Podzapytania w `FROM`

-- %% [markdown]
-- #### Przykład
--
-- **Załóżmy, że mamy gotowe zapytanie o listę użytkowników biblioteki wraz z liczbą książek pożyczonych przez każdego z nich.**

-- %% [markdown]
-- Tabela **`Users`**:

-- %%
%LOAD library_db.db rw

-- %%
SELECT * FROM users;
-- Out:
-- +-----+---------------+-------------+-------------------+
-- | ID  | surname       | name        | registration_date |
-- +-----+---------------+-------------+-------------------+
-- | 0   | Piotrowski    | Igor        | 1994-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 1   | Lewandowska   | Róża      | 2008-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 2   | Woźniak      | Adam        | 1999-08-09        |
-- +-----+---------------+-------------+-------------------+
-- | 3   | Kowalczyk     | Michał     | 2011-01-22        |
-- +-----+---------------+-------------+-------------------+
-- | 4   | Kaczmarek     | Leon        | 1990-08-15        |
-- +-----+---------------+-------------+-------------------+
-- | 5   | Kwiatkowska   | Joanna      | 2013-06-16        |
-- +-----+---------------+-------------+-------------------+
-- | 6   | Zieliński    | Michał     | 1990-09-21        |
-- +-----+---------------+-------------+-------------------+
-- | 7   | Woźniak      | Małgorzata | 1991-10-03        |
-- +-----+---------------+-------------+-------------------+
-- | 8   | Kaczmarek     | Joanna      | 2001-05-31        |
-- +-----+---------------+-------------+-------------------+
-- | 9   | Wójcik       | Izabela     | 2013-03-07        |
-- +-----+---------------+-------------+-------------------+
-- | 10  | Lewandowska   | Klaudia     | 2004-09-14        |
-- +-----+---------------+-------------+-------------------+
-- | 11  | Piotrowski    | Igor        | 1996-08-08        |
-- +-----+---------------+-------------+-------------------+
-- | 12  | Nowak         | Róża      | 2007-04-08        |
-- +-----+---------------+-------------+-------------------+
-- | 13  | Kowalska      | Izabela     | 2003-10-21        |
-- +-----+---------------+-------------+-------------------+
-- | 14  | Kamińska     | Izabela     | 2013-07-10        |
-- +-----+---------------+-------------+-------------------+
-- | 15  | Kowalczyk     | Mateusz     | 2004-08-13        |
-- +-----+---------------+-------------+-------------------+
-- | 16  | Mazur         | Michał     | 1995-03-01        |
-- +-----+---------------+-------------+-------------------+
-- | 17  | Piotrowski    | Piotr       | 1991-08-31        |
-- +-----+---------------+-------------+-------------------+
-- | 18  | Lewandowski   | Adam        | 1998-08-08        |
-- +-----+---------------+-------------+-------------------+
-- | 19  | Kowalska      | Matylda     | 2001-07-05        |
-- +-----+---------------+-------------+-------------------+
-- | 20  | Lewandowska   | Katarzyna   | 2010-03-31        |
-- +-----+---------------+-------------+-------------------+
-- | 21  | Lewandowska   | Aniela      | 2004-03-18        |
-- +-----+---------------+-------------+-------------------+
-- | 22  | Szymański    | Leon        | 2007-11-18        |
-- +-----+---------------+-------------+-------------------+
-- | 23  | Kwiatkowska   | Joanna      | 1996-01-27        |
-- +-----+---------------+-------------+-------------------+
-- | 24  | Wójcik       | Wiktor      | 1999-01-19        |
-- +-----+---------------+-------------+-------------------+
-- | 25  | Woźniak      | Piotr       | 2003-06-09        |
-- +-----+---------------+-------------+-------------------+
-- | 26  | Wójcik       | Stanisław  | 2004-07-16        |
-- +-----+---------------+-------------+-------------------+
-- | 27  | Jankowska     | Paulina     | 1998-12-15        |
-- +-----+---------------+-------------+-------------------+
-- | 28  | Kowalczyk     | Piotr       | 2017-08-20        |
-- +-----+---------------+-------------+-------------------+
-- | 29  | Wójcik       | Adam        | 1992-06-11        |
-- +-----+---------------+-------------+-------------------+
-- | 30  | Kozłowski    | Michał     | 2016-10-24        |
-- +-----+---------------+-------------+-------------------+
-- | 31  | Mazur         | Matylda     | 2001-10-18        |
-- +-----+---------------+-------------+-------------------+
-- | 32  | Wiśniewska   | Katarzyna   | 2012-07-22        |
-- +-----+---------------+-------------+-------------------+
-- | 33  | Jankowska     | Joanna      | 2006-06-17        |
-- +-----+---------------+-------------+-------------------+
-- | 34  | Szymańska    | Róża      | 1991-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 35  | Dąbrowski    | Piotr       | 1990-01-02        |
-- +-----+---------------+-------------+-------------------+
-- | 36  | Kaczmarek     | Małgorzata | 1992-03-16        |
-- +-----+---------------+-------------+-------------------+
-- | 37  | Mazur         | Marcel      | 2005-10-09        |
-- +-----+---------------+-------------+-------------------+
-- | 38  | Lewandowski   | Marcel      | 2006-09-01        |
-- +-----+---------------+-------------+-------------------+
-- | 39  | Kozłowski    | Adam        | 2012-11-13        |
-- +-----+---------------+-------------+-------------------+
-- | 40  | Szymańska    | Klaudia     | 1990-06-01        |
-- +-----+---------------+-------------+-------------------+
-- | 41  | Grabowska     | Liliana     | 1991-11-19        |
-- +-----+---------------+-------------+-------------------+
-- | 42  | Mazur         | Katarzyna   | 2007-01-15        |
-- +-----+---------------+-------------+-------------------+
-- | 43  | Szymański    | Mateusz     | 1994-07-26        |
-- +-----+---------------+-------------+-------------------+
-- | 44  | Nowak         | Klaudia     | 1992-10-24        |
-- +-----+---------------+-------------+-------------------+
-- | 45  | Grabowski     | Piotr       | 2017-01-14        |
-- +-----+---------------+-------------+-------------------+
-- | 46  | Woźniak      | Marta       | 2009-02-27        |
-- +-----+---------------+-------------+-------------------+
-- | 47  | Nowak         | Sara        | 2001-03-25        |
-- +-----+---------------+-------------+-------------------+
-- | 48  | Piotrowski    | Wiktor      | 2013-06-25        |
-- +-----+---------------+-------------+-------------------+
-- | 49  | Grabowska     | Liliana     | 2015-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 50  | Zielińska    | Matylda     | 1990-11-08        |
-- +-----+---------------+-------------+-------------------+
-- | 51  | Mazur         | Mateusz     | 2001-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 52  | Lewandowski   | Leon        | 2006-06-17        |
-- +-----+---------------+-------------+-------------------+
-- | 53  | Dąbrowski    | Adam        | 1990-03-21        |
-- +-----+---------------+-------------+-------------------+
-- | 54  | Wojciechowska | Joanna      | 2017-07-29        |
-- +-----+---------------+-------------+-------------------+
-- | 55  | Kozłowski    | Wiktor      | 2014-03-05        |
-- +-----+---------------+-------------+-------------------+
-- | 56  | Kozłowska    | Katarzyna   | 2016-08-02        |
-- +-----+---------------+-------------+-------------------+
-- | 57  | Jankowska     | Paulina     | 1992-03-01        |
-- +-----+---------------+-------------+-------------------+
-- | 58  | Krawczyk      | Adam        | 2013-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 59  | Woźniak      | Róża      | 2005-07-23        |
-- +-----+---------------+-------------+-------------------+
-- | 60  | Kaczmarek     | Aniela      | 2012-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 61  | Kaczmarek     | Matylda     | 2015-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 62  | Kamińska     | Klaudia     | 1999-09-14        |
-- +-----+---------------+-------------+-------------------+
-- | 63  | Kaczmarek     | Piotr       | 1999-04-26        |
-- +-----+---------------+-------------+-------------------+
-- | 64  | Mazur         | Wiktor      | 1990-12-22        |
-- +-----+---------------+-------------+-------------------+
-- | 65  | Dąbrowska    | Katarzyna   | 2017-11-27        |
-- +-----+---------------+-------------+-------------------+
-- | 66  | Kowalska      | Klaudia     | 1990-12-27        |
-- +-----+---------------+-------------+-------------------+
-- | 67  | Szymańska    | Klaudia     | 2007-08-17        |
-- +-----+---------------+-------------+-------------------+
-- | 68  | Wójcik       | Wiktor      | 2016-05-20        |
-- +-----+---------------+-------------+-------------------+
-- | 69  | Grabowska     | Klaudia     | 2007-06-26        |
-- +-----+---------------+-------------+-------------------+
-- | 70  | Piotrowska    | Klaudia     | 1992-08-28        |
-- +-----+---------------+-------------+-------------------+
-- | 71  | Kozłowski    | Stanisław  | 2014-06-27        |
-- +-----+---------------+-------------+-------------------+
-- | 72  | Mazur         | Joanna      | 2012-12-17        |
-- +-----+---------------+-------------+-------------------+
-- | 73  | Nowak         | Adam        | 1997-05-11        |
-- +-----+---------------+-------------+-------------------+
-- | 74  | Wiśniewska   | Małgorzata | 2003-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 75  | Kozłowska    | Joanna      | 2013-04-17        |
-- +-----+---------------+-------------+-------------------+
-- | 76  | Kowalski      | Piotr       | 2011-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 77  | Jankowski     | Marcel      | 2017-12-15        |
-- +-----+---------------+-------------+-------------------+
-- | 78  | Lewandowska   | Marta       | 2010-12-13        |
-- +-----+---------------+-------------+-------------------+
-- | 79  | Kozłowska    | Paulina     | 2017-08-20        |
-- +-----+---------------+-------------+-------------------+
-- | 80  | Nowak         | Mateusz     | 1995-11-25        |
-- +-----+---------------+-------------+-------------------+
-- | 81  | Dąbrowska    | Klaudia     | 2015-06-18        |
-- +-----+---------------+-------------+-------------------+
-- | 82  | Grabowska     | Klaudia     | 2016-10-26        |
-- +-----+---------------+-------------+-------------------+
-- | 83  | Kwiatkowska   | Marta       | 2012-05-29        |
-- +-----+---------------+-------------+-------------------+
-- | 84  | Krawczyk      | Nikodem     | 1995-05-02        |
-- +-----+---------------+-------------+-------------------+
-- | 85  | Kaczmarek     | Michał     | 2009-12-30        |
-- +-----+---------------+-------------+-------------------+
-- | 86  | Wójcik       | Klaudia     | 2003-11-08        |
-- +-----+---------------+-------------+-------------------+
-- | 87  | Dąbrowski    | Igor        | 2004-01-19        |
-- +-----+---------------+-------------+-------------------+
-- | 88  | Kaczmarek     | Michał     | 1990-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 89  | Kowalczyk     | Aniela      | 1991-03-11        |
-- +-----+---------------+-------------+-------------------+
-- | 90  | Lewandowski   | Piotr       | 2009-08-09        |
-- +-----+---------------+-------------+-------------------+
-- | 91  | Kaczmarek     | Izabela     | 2013-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 92  | Nowak         | Leon        | 2016-05-06        |
-- +-----+---------------+-------------+-------------------+
-- | 93  | Kwiatkowski   | Michał     | 2011-10-10        |
-- +-----+---------------+-------------+-------------------+
-- | 94  | Wiśniewska   | Małgorzata | 2012-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 95  | Mazur         | Katarzyna   | 2012-11-27        |
-- +-----+---------------+-------------+-------------------+
-- | 96  | Nowak         | Nikodem     | 2014-03-22        |
-- +-----+---------------+-------------+-------------------+
-- | 97  | Kaczmarek     | Małgorzata | 2001-02-10        |
-- +-----+---------------+-------------+-------------------+
-- | 98  | Lewandowska   | Małgorzata | 1990-07-21        |
-- +-----+---------------+-------------+-------------------+
-- | 99  | Grabowska     | Małgorzata | 1998-11-16        |
-- +-----+---------------+-------------+-------------------+
-- | 100 | Grabowski     | Mateusz     | 2007-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 101 | Wojciechowska | Paulina     | 2002-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 102 | Woźniak      | Marta       | 2008-03-07        |
-- +-----+---------------+-------------+-------------------+
-- | 103 | Dąbrowska    | Joanna      | 2006-01-03        |
-- +-----+---------------+-------------+-------------------+
-- | 104 | Kamiński     | Marcel      | 2007-01-12        |
-- +-----+---------------+-------------+-------------------+
-- | 105 | Nowak         | Michał     | 2005-06-13        |
-- +-----+---------------+-------------+-------------------+
-- | 106 | Wiśniewska   | Marta       | 1991-10-27        |
-- +-----+---------------+-------------+-------------------+
-- | 107 | Zieliński    | Leon        | 2014-06-01        |
-- +-----+---------------+-------------+-------------------+
-- | 108 | Wojciechowski | Wiktor      | 1992-04-04        |
-- +-----+---------------+-------------+-------------------+
-- | 109 | Piotrowska    | Małgorzata | 2009-04-21        |
-- +-----+---------------+-------------+-------------------+
-- | 110 | Kowalska      | Paulina     | 1998-01-15        |
-- +-----+---------------+-------------+-------------------+
-- | 111 | Kwiatkowska   | Paulina     | 2015-04-29        |
-- +-----+---------------+-------------+-------------------+
-- | 112 | Grabowska     | Aniela      | 2015-08-13        |
-- +-----+---------------+-------------+-------------------+
-- | 113 | Kowalczyk     | Katarzyna   | 2017-03-21        |
-- +-----+---------------+-------------+-------------------+
-- | 114 | Nowak         | Liliana     | 1997-04-04        |
-- +-----+---------------+-------------+-------------------+
-- | 115 | Kaczmarek     | Leon        | 2016-03-18        |
-- +-----+---------------+-------------+-------------------+
-- | 116 | Kowalczyk     | Leon        | 2009-04-06        |
-- +-----+---------------+-------------+-------------------+
-- | 117 | Kowalska      | Marta       | 2011-01-13        |
-- +-----+---------------+-------------+-------------------+
-- | 118 | Kowalska      | Joanna      | 1992-09-03        |
-- +-----+---------------+-------------+-------------------+
-- | 119 | Krawczyk      | Paulina     | 2008-11-04        |
-- +-----+---------------+-------------+-------------------+
-- | 120 | Dąbrowska    | Róża      | 1999-10-25        |
-- +-----+---------------+-------------+-------------------+
-- | 121 | Grabowska     | Joanna      | 2009-10-25        |
-- +-----+---------------+-------------+-------------------+
-- | 122 | Grabowski     | Igor        | 1990-10-07        |
-- +-----+---------------+-------------+-------------------+
-- | 123 | Kaczmarek     | Sara        | 2009-11-05        |
-- +-----+---------------+-------------+-------------------+
-- | 124 | Lewandowska   | Izabela     | 2015-02-13        |
-- +-----+---------------+-------------+-------------------+
-- | 125 | Piotrowska    | Izabela     | 2017-08-14        |
-- +-----+---------------+-------------+-------------------+
-- | 126 | Dąbrowska    | Róża      | 2001-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 127 | Nowak         | Katarzyna   | 2006-07-26        |
-- +-----+---------------+-------------+-------------------+
-- | 128 | Kaczmarek     | Małgorzata | 2017-03-04        |
-- +-----+---------------+-------------+-------------------+
-- | 129 | Kowalczyk     | Adam        | 2017-09-05        |
-- +-----+---------------+-------------+-------------------+
-- | 130 | Szymański    | Adam        | 2014-12-01        |
-- +-----+---------------+-------------+-------------------+
-- | 131 | Woźniak      | Nikodem     | 1991-10-10        |
-- +-----+---------------+-------------+-------------------+
-- | 132 | Wojciechowska | Katarzyna   | 2004-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 133 | Kaczmarek     | Igor        | 2007-08-11        |
-- +-----+---------------+-------------+-------------------+
-- | 134 | Dąbrowski    | Nikodem     | 2011-01-25        |
-- +-----+---------------+-------------+-------------------+
-- | 135 | Dąbrowska    | Aniela      | 1998-10-03        |
-- +-----+---------------+-------------+-------------------+
-- | 136 | Wójcik       | Izabela     | 2006-05-17        |
-- +-----+---------------+-------------+-------------------+
-- | 137 | Piotrowska    | Izabela     | 1998-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 138 | Kwiatkowska   | Izabela     | 2009-04-03        |
-- +-----+---------------+-------------+-------------------+
-- | 139 | Kowalska      | Małgorzata | 2016-05-30        |
-- +-----+---------------+-------------+-------------------+
-- | 140 | Nowak         | Mateusz     | 2011-04-12        |
-- +-----+---------------+-------------+-------------------+
-- | 141 | Zielińska    | Róża      | 2001-09-13        |
-- +-----+---------------+-------------+-------------------+
-- | 142 | Wiśniewska   | Katarzyna   | 2009-10-29        |
-- +-----+---------------+-------------+-------------------+
-- | 143 | Wiśniewski   | Michał     | 2010-03-05        |
-- +-----+---------------+-------------+-------------------+
-- | 144 | Dąbrowska    | Aniela      | 1998-04-01        |
-- +-----+---------------+-------------+-------------------+
-- | 145 | Kaczmarek     | Róża      | 2005-05-09        |
-- +-----+---------------+-------------+-------------------+
-- | 146 | Kamiński     | Piotr       | 1992-11-29        |
-- +-----+---------------+-------------+-------------------+
-- | 147 | Woźniak      | Matylda     | 2008-02-29        |
-- +-----+---------------+-------------+-------------------+
-- | 148 | Dąbrowski    | Igor        | 1996-08-25        |
-- +-----+---------------+-------------+-------------------+
-- | 149 | Lewandowski   | Marcel      | 2009-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 150 | Jankowska     | Małgorzata | 2000-09-13        |
-- +-----+---------------+-------------+-------------------+
-- | 151 | Kamiński     | Wiktor      | 1993-09-11        |
-- +-----+---------------+-------------+-------------------+
-- | 152 | Krawczyk      | Katarzyna   | 1996-08-24        |
-- +-----+---------------+-------------+-------------------+
-- | 153 | Mazur         | Adam        | 2002-09-20        |
-- +-----+---------------+-------------+-------------------+
-- | 154 | Kwiatkowska   | Sara        | 2006-10-08        |
-- +-----+---------------+-------------+-------------------+
-- | 155 | Wójcik       | Stanisław  | 2006-06-28        |
-- +-----+---------------+-------------+-------------------+
-- | 156 | Grabowski     | Mateusz     | 1998-03-13        |
-- +-----+---------------+-------------+-------------------+
-- | 157 | Wiśniewska   | Katarzyna   | 2016-11-09        |
-- +-----+---------------+-------------+-------------------+
-- | 158 | Krawczyk      | Michał     | 2007-04-25        |
-- +-----+---------------+-------------+-------------------+
-- | 159 | Szymański    | Piotr       | 1991-05-15        |
-- +-----+---------------+-------------+-------------------+
-- | 160 | Kamiński     | Leon        | 1990-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 161 | Krawczyk      | Marcel      | 2002-09-28        |
-- +-----+---------------+-------------+-------------------+
-- | 162 | Kozłowska    | Aniela      | 1993-10-19        |
-- +-----+---------------+-------------+-------------------+
-- | 163 | Wojciechowski | Leon        | 1994-08-18        |
-- +-----+---------------+-------------+-------------------+
-- | 164 | Wójcik       | Liliana     | 1999-11-10        |
-- +-----+---------------+-------------+-------------------+
-- | 165 | Piotrowski    | Wiktor      | 1999-08-25        |
-- +-----+---------------+-------------+-------------------+
-- | 166 | Wiśniewska   | Katarzyna   | 2005-06-05        |
-- +-----+---------------+-------------+-------------------+
-- | 167 | Kozłowska    | Sara        | 1992-01-03        |
-- +-----+---------------+-------------+-------------------+
-- | 168 | Woźniak      | Adam        | 2004-10-18        |
-- +-----+---------------+-------------+-------------------+
-- | 169 | Nowak         | Adam        | 2017-01-01        |
-- +-----+---------------+-------------+-------------------+
-- | 170 | Kowalska      | Róża      | 2011-11-26        |
-- +-----+---------------+-------------+-------------------+
-- | 171 | Lewandowski   | Michał     | 2015-06-19        |
-- +-----+---------------+-------------+-------------------+
-- | 172 | Nowak         | Izabela     | 2003-05-31        |
-- +-----+---------------+-------------+-------------------+
-- | 173 | Nowak         | Aniela      | 1996-07-10        |
-- +-----+---------------+-------------+-------------------+
-- | 174 | Piotrowska    | Joanna      | 1990-03-26        |
-- +-----+---------------+-------------+-------------------+
-- | 175 | Kowalczyk     | Joanna      | 1992-07-02        |
-- +-----+---------------+-------------+-------------------+
-- | 176 | Zielińska    | Liliana     | 2007-08-12        |
-- +-----+---------------+-------------+-------------------+
-- | 177 | Jankowska     | Paulina     | 2003-05-04        |
-- +-----+---------------+-------------+-------------------+
-- | 178 | Piotrowski    | Stanisław  | 2017-01-09        |
-- +-----+---------------+-------------+-------------------+
-- | 179 | Wiśniewska   | Róża      | 2006-05-12        |
-- +-----+---------------+-------------+-------------------+
-- | 180 | Piotrowski    | Piotr       | 2011-01-30        |
-- +-----+---------------+-------------+-------------------+
-- | 181 | Wójcik       | Nikodem     | 2012-02-03        |
-- +-----+---------------+-------------+-------------------+
-- | 182 | Lewandowska   | Sara        | 2004-12-26        |
-- +-----+---------------+-------------+-------------------+
-- | 183 | Wójcik       | Marcel      | 2015-12-23        |
-- +-----+---------------+-------------+-------------------+
-- | 184 | Jankowska     | Małgorzata | 2012-01-16        |
-- +-----+---------------+-------------+-------------------+
-- | 185 | Wiśniewska   | Liliana     | 2015-06-02        |
-- +-----+---------------+-------------+-------------------+
-- | 186 | Kowalski      | Stanisław  | 2013-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 187 | Nowak         | Aniela      | 2008-11-22        |
-- +-----+---------------+-------------+-------------------+
-- | 188 | Grabowska     | Marta       | 1994-07-14        |
-- +-----+---------------+-------------+-------------------+
-- | 189 | Kowalska      | Paulina     | 2006-02-21        |
-- +-----+---------------+-------------+-------------------+
-- | 190 | Dąbrowska    | Róża      | 2005-08-22        |
-- +-----+---------------+-------------+-------------------+
-- | 191 | Wójcik       | Marcel      | 2015-11-28        |
-- +-----+---------------+-------------+-------------------+
-- | 192 | Grabowska     | Matylda     | 2011-01-26        |
-- +-----+---------------+-------------+-------------------+
-- | 193 | Dąbrowski    | Nikodem     | 2006-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 194 | Nowak         | Piotr       | 2017-05-11        |
-- +-----+---------------+-------------+-------------------+
-- | 195 | Woźniak      | Liliana     | 2017-07-11        |
-- +-----+---------------+-------------+-------------------+
-- | 196 | Zieliński    | Stanisław  | 2000-06-03        |
-- +-----+---------------+-------------+-------------------+
-- | 197 | Grabowski     | Piotr       | 2011-04-19        |
-- +-----+---------------+-------------+-------------------+
-- | 198 | Szymański    | Michał     | 2013-05-10        |
-- +-----+---------------+-------------+-------------------+
-- | 199 | Kowalski      | Stanisław  | 1995-06-12        |
-- +-----+---------------+-------------+-------------------+
-- | 200 | Wójcik       | Sara        | 1990-02-18        |
-- +-----+---------------+-------------+-------------------+
-- | 201 | Kozłowska    | Aniela      | 1999-02-16        |
-- +-----+---------------+-------------+-------------------+
-- | 202 | Kowalski      | Mateusz     | 2013-06-18        |
-- +-----+---------------+-------------+-------------------+
-- | 203 | Kowalczyk     | Igor        | 1996-03-20        |
-- +-----+---------------+-------------+-------------------+
-- | 204 | Kamiński     | Leon        | 1990-07-23        |
-- +-----+---------------+-------------+-------------------+
-- | 205 | Szymańska    | Katarzyna   | 1991-12-28        |
-- +-----+---------------+-------------+-------------------+
-- | 206 | Kowalska      | Róża      | 2017-02-04        |
-- +-----+---------------+-------------+-------------------+
-- | 207 | Wojciechowska | Marta       | 2007-10-01        |
-- +-----+---------------+-------------+-------------------+
-- | 208 | Kwiatkowska   | Małgorzata | 2012-02-23        |
-- +-----+---------------+-------------+-------------------+
-- | 209 | Jankowska     | Joanna      | 1999-08-02        |
-- +-----+---------------+-------------+-------------------+
-- | 210 | Wójcik       | Igor        | 2003-02-18        |
-- +-----+---------------+-------------+-------------------+
-- | 211 | Wojciechowska | Klaudia     | 2010-12-12        |
-- +-----+---------------+-------------+-------------------+
-- | 212 | Kaczmarek     | Marta       | 1998-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 213 | Krawczyk      | Nikodem     | 1998-10-28        |
-- +-----+---------------+-------------+-------------------+
-- | 214 | Kozłowska    | Klaudia     | 1994-12-27        |
-- +-----+---------------+-------------+-------------------+
-- | 215 | Zielińska    | Izabela     | 2009-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 216 | Jankowski     | Nikodem     | 2004-08-18        |
-- +-----+---------------+-------------+-------------------+
-- | 217 | Mazur         | Adam        | 2011-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 218 | Kaczmarek     | Matylda     | 2006-05-17        |
-- +-----+---------------+-------------+-------------------+
-- | 219 | Wójcik       | Igor        | 2017-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 220 | Szymański    | Igor        | 1996-08-31        |
-- +-----+---------------+-------------+-------------------+
-- | 221 | Krawczyk      | Paulina     | 2015-09-11        |
-- +-----+---------------+-------------+-------------------+
-- | 222 | Krawczyk      | Marta       | 2010-11-04        |
-- +-----+---------------+-------------+-------------------+
-- | 223 | Kaczmarek     | Mateusz     | 2010-03-06        |
-- +-----+---------------+-------------+-------------------+
-- | 224 | Lewandowski   | Stanisław  | 1998-05-07        |
-- +-----+---------------+-------------+-------------------+
-- | 225 | Nowak         | Adam        | 2012-09-23        |
-- +-----+---------------+-------------+-------------------+
-- | 226 | Lewandowska   | Sara        | 2014-03-08        |
-- +-----+---------------+-------------+-------------------+
-- | 227 | Kozłowski    | Piotr       | 1997-09-22        |
-- +-----+---------------+-------------+-------------------+
-- | 228 | Dąbrowski    | Nikodem     | 2010-05-23        |
-- +-----+---------------+-------------+-------------------+
-- | 229 | Kaczmarek     | Nikodem     | 1991-06-21        |
-- +-----+---------------+-------------+-------------------+
-- | 230 | Kamiński     | Piotr       | 1994-02-13        |
-- +-----+---------------+-------------+-------------------+
-- | 231 | Mazur         | Igor        | 2017-03-12        |
-- +-----+---------------+-------------+-------------------+
-- | 232 | Wojciechowski | Wiktor      | 1998-12-28        |
-- +-----+---------------+-------------+-------------------+
-- | 233 | Szymańska    | Róża      | 2012-10-11        |
-- +-----+---------------+-------------+-------------------+
-- | 234 | Dąbrowska    | Małgorzata | 2009-02-15        |
-- +-----+---------------+-------------+-------------------+
-- | 235 | Grabowska     | Izabela     | 1995-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 236 | Lewandowski   | Marcel      | 2015-11-19        |
-- +-----+---------------+-------------+-------------------+
-- | 237 | Krawczyk      | Małgorzata | 2016-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 238 | Wójcik       | Izabela     | 2013-10-11        |
-- +-----+---------------+-------------+-------------------+
-- | 239 | Kowalski      | Stanisław  | 2010-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 240 | Nowak         | Wiktor      | 2007-06-29        |
-- +-----+---------------+-------------+-------------------+
-- | 241 | Kwiatkowska   | Matylda     | 2015-07-13        |
-- +-----+---------------+-------------+-------------------+
-- | 242 | Jankowska     | Paulina     | 1994-11-17        |
-- +-----+---------------+-------------+-------------------+
-- | 243 | Mazur         | Adam        | 2000-11-23        |
-- +-----+---------------+-------------+-------------------+
-- | 244 | Wójcik       | Nikodem     | 2004-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 245 | Nowak         | Mateusz     | 2006-06-13        |
-- +-----+---------------+-------------+-------------------+
-- | 246 | Wójcik       | Igor        | 1991-11-02        |
-- +-----+---------------+-------------+-------------------+
-- | 247 | Lewandowska   | Klaudia     | 1992-06-14        |
-- +-----+---------------+-------------+-------------------+
-- | 248 | Szymańska    | Małgorzata | 2006-01-21        |
-- +-----+---------------+-------------+-------------------+
-- | 249 | Woźniak      | Klaudia     | 2005-07-20        |
-- +-----+---------------+-------------+-------------------+

-- %% [markdown]
-- Tabela **`Borrowings`**:

-- %%
SELECT * FROM borrowings;
-- Out:
-- +------+---------+---------+-------------+-------------+
-- | ID   | user_id | book_id | borrow_date | return_date |
-- +------+---------+---------+-------------+-------------+
-- | 0    | 129     | 621     | 2017-09-05  | 2017-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1    | 192     | 284     | 2011-01-26  | 2011-01-31  |
-- +------+---------+---------+-------------+-------------+
-- | 2    | 235     | 160     | 1995-12-18  | 1995-12-27  |
-- +------+---------+---------+-------------+-------------+
-- | 3    | 96      | 308     | 2018-07-02  | 2018-07-19  |
-- +------+---------+---------+-------------+-------------+
-- | 4    | 195     | 180     | 2017-07-11  | 2017-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 5    | 171     | 378     | 2015-06-19  | 2015-06-29  |
-- +------+---------+---------+-------------+-------------+
-- | 6    | 94      | 359     | 2012-04-23  | 2012-05-04  |
-- +------+---------+---------+-------------+-------------+
-- | 7    | 8       | 593     | 2001-05-31  | 2001-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 8    | 223     | 37      | 2010-03-06  | 2010-04-03  |
-- +------+---------+---------+-------------+-------------+
-- | 9    | 203     | 248     | 1996-03-20  | 1996-03-26  |
-- +------+---------+---------+-------------+-------------+
-- | 10   | 150     | 471     | 2000-09-13  | 2000-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 11   | 46      | 82      | 2009-02-27  | 2009-03-06  |
-- +------+---------+---------+-------------+-------------+
-- | 12   | 199     | 626     | 1995-06-12  | 1995-06-19  |
-- +------+---------+---------+-------------+-------------+
-- | 13   | 110     | 560     | 2011-01-30  | 2011-02-23  |
-- +------+---------+---------+-------------+-------------+
-- | 14   | 203     | 617     | 1996-03-20  | 1996-04-12  |
-- +------+---------+---------+-------------+-------------+
-- | 15   | 238     | 607     | 2013-10-11  | 2013-10-25  |
-- +------+---------+---------+-------------+-------------+
-- | 16   | 117     | 272     | 2011-01-13  | 2011-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 17   | 87      | 583     | 2004-01-19  | 2004-01-23  |
-- +------+---------+---------+-------------+-------------+
-- | 18   | 16      | 1       | 2002-01-30  | 2002-02-04  |
-- +------+---------+---------+-------------+-------------+
-- | 19   | 25      | 477     | 2003-06-09  | 2003-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 20   | 26      | 215     | 2004-07-16  | 2004-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 21   | 238     | 45      | 2013-10-11  | 2013-10-16  |
-- +------+---------+---------+-------------+-------------+
-- | 22   | 28      | 222     | 2017-08-24  | 2017-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 23   | 176     | 377     | 2007-08-12  | 2007-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 24   | 114     | 403     | 1997-04-04  | 1997-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 25   | 80      | 578     | 2001-08-27  | 2001-09-16  |
-- +------+---------+---------+-------------+-------------+
-- | 26   | 133     | 313     | 2011-10-17  | 2011-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 27   | 2       | 418     | 1999-08-09  | 1999-08-27  |
-- +------+---------+---------+-------------+-------------+
-- | 28   | 8       | 498     | 2007-01-12  | 2007-02-07  |
-- +------+---------+---------+-------------+-------------+
-- | 29   | 66      | 200     | 1990-12-27  | 1991-01-06  |
-- +------+---------+---------+-------------+-------------+
-- | 30   | 42      | 265     | 2007-01-15  | 2007-01-30  |
-- +------+---------+---------+-------------+-------------+
-- | 31   | 79      | 116     | 2017-08-20  | 2017-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 32   | 199     | 610     | 1995-06-12  | 1995-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 33   | 60      | 142     | 2012-10-02  | 2012-10-02  |
-- +------+---------+---------+-------------+-------------+
-- | 34   | 233     | 60      | 2012-10-11  | 2012-10-14  |
-- +------+---------+---------+-------------+-------------+
-- | 35   | 94      | 443     | 2012-04-23  | 2012-05-15  |
-- +------+---------+---------+-------------+-------------+
-- | 36   | 92      | 129     | 2016-05-06  | 2016-06-03  |
-- +------+---------+---------+-------------+-------------+
-- | 37   | 225     | 581     | 2012-09-23  | 2012-09-24  |
-- +------+---------+---------+-------------+-------------+
-- | 38   | 200     | 505     | 1993-09-08  | 1993-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 39   | 175     | 574     | 1998-09-02  | 1998-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 40   | 248     | 141     | 2017-11-06  | 2017-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 41   | 239     | 321     | 2010-10-02  | 2010-10-15  |
-- +------+---------+---------+-------------+-------------+
-- | 42   | 86      | 271     | 2003-11-08  | 2003-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 43   | 8       | 544     | 2001-05-31  | 2001-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 44   | 234     | 563     | 2016-12-12  | 2017-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 45   | 204     | 494     | 1994-11-10  | 1994-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 46   | 229     | 426     | 1991-06-21  | 1991-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 47   | 113     | 173     | 2017-03-21  | 2017-04-10  |
-- +------+---------+---------+-------------+-------------+
-- | 48   | 66      | 200     | 1990-12-27  | 1991-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 49   | 244     | 180     | 2004-07-06  | 2004-07-07  |
-- +------+---------+---------+-------------+-------------+
-- | 50   | 24      | 309     | 1999-01-19  | 1999-02-11  |
-- +------+---------+---------+-------------+-------------+
-- | 51   | 156     | 114     | 1998-03-13  | 1998-03-16  |
-- +------+---------+---------+-------------+-------------+
-- | 52   | 29      | 163     | 2017-09-08  | 2017-09-12  |
-- +------+---------+---------+-------------+-------------+
-- | 53   | 28      | 34      | 2017-08-20  | 2017-09-04  |
-- +------+---------+---------+-------------+-------------+
-- | 54   | 185     | 383     | 2015-06-02  | 2015-06-02  |
-- +------+---------+---------+-------------+-------------+
-- | 55   | 219     | 208     | 2017-10-04  | 2017-10-26  |
-- +------+---------+---------+-------------+-------------+
-- | 56   | 234     | 199     | 2009-02-15  | 2009-02-18  |
-- +------+---------+---------+-------------+-------------+
-- | 57   | 187     | 116     | 2008-11-22  | 2008-12-06  |
-- +------+---------+---------+-------------+-------------+
-- | 58   | 67      | 628     | 2009-10-23  | 2009-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 59   | 72      | 162     | 2012-12-17  | 2012-12-30  |
-- +------+---------+---------+-------------+-------------+
-- | 60   | 51      | 1       | 2002-01-30  | 2002-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 61   | 113     | 169     | 2017-04-02  | 2017-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 62   | 197     | 577     | 2011-04-19  | 2011-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 63   | 183     | 588     | 2015-12-23  | 2016-01-16  |
-- +------+---------+---------+-------------+-------------+
-- | 64   | 214     | 90      | 2015-12-07  | 2015-12-28  |
-- +------+---------+---------+-------------+-------------+
-- | 65   | 125     | 131     | 2017-08-14  | 2017-08-30  |
-- +------+---------+---------+-------------+-------------+
-- | 66   | 164     | 113     | 1999-11-10  | 1999-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 67   | 77      | 543     | 2017-12-15  | 2017-12-31  |
-- +------+---------+---------+-------------+-------------+
-- | 68   | 172     | 30      | 2003-05-31  | 2003-06-28  |
-- +------+---------+---------+-------------+-------------+
-- | 69   | 32      | 572     | 2012-07-22  | 2012-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 70   | 176     | 185     | 2007-08-12  | 2007-08-28  |
-- +------+---------+---------+-------------+-------------+
-- | 71   | 180     | 209     | 2017-09-14  | 2017-09-30  |
-- +------+---------+---------+-------------+-------------+
-- | 72   | 193     | 455     | 2012-09-24  | 2012-09-25  |
-- +------+---------+---------+-------------+-------------+
-- | 73   | 48      | 421     | 2013-06-25  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 74   | 222     | 485     | 2017-10-05  | 2017-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 75   | 155     | 399     | 2006-06-28  | 2006-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 76   | 60      | 277     | 2017-02-22  | 2017-03-04  |
-- +------+---------+---------+-------------+-------------+
-- | 77   | 53      | 633     | 1990-03-21  | 1990-03-24  |
-- +------+---------+---------+-------------+-------------+
-- | 78   | 120     | 167     | 1999-10-25  | 1999-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 79   | 152     | 167     | 1996-08-24  | 1996-09-19  |
-- +------+---------+---------+-------------+-------------+
-- | 80   | 135     | 325     | 2013-03-11  | 2013-03-30  |
-- +------+---------+---------+-------------+-------------+
-- | 81   | 2       | 569     | 2002-02-15  | 2002-03-01  |
-- +------+---------+---------+-------------+-------------+
-- | 82   | 129     | 167     | 2017-09-05  | 2017-09-26  |
-- +------+---------+---------+-------------+-------------+
-- | 83   | 142     | 530     | 2009-10-29  | 2009-11-18  |
-- +------+---------+---------+-------------+-------------+
-- | 84   | 67      | 49      | 2007-08-17  | 2009-02-13  |
-- +------+---------+---------+-------------+-------------+
-- | 85   | 121     | 593     | 2009-10-25  | 2009-11-10  |
-- +------+---------+---------+-------------+-------------+
-- | 86   | 230     | 308     | 2018-07-02  | 2018-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 87   | 171     | 514     | 2015-06-19  | 2015-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 88   | 118     | 58      | 2015-12-13  | 2015-12-26  |
-- +------+---------+---------+-------------+-------------+
-- | 89   | 131     | 446     | 1991-10-10  | 1991-10-17  |
-- +------+---------+---------+-------------+-------------+
-- | 90   | 95      | 3       | 2017-03-02  | 2017-03-27  |
-- +------+---------+---------+-------------+-------------+
-- | 91   | 109     | 541     | 2009-04-21  | 2009-05-07  |
-- +------+---------+---------+-------------+-------------+
-- | 92   | 231     | 151     | 2017-03-12  | 2017-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 93   | 202     | 402     | 2013-06-18  |             |
-- +------+---------+---------+-------------+-------------+
-- | 94   | 245     | 71      | 2006-06-13  | 2006-06-19  |
-- +------+---------+---------+-------------+-------------+
-- | 95   | 235     | 124     | 1996-04-02  | 1996-04-19  |
-- +------+---------+---------+-------------+-------------+
-- | 96   | 159     | 411     | 2001-01-18  | 2001-01-23  |
-- +------+---------+---------+-------------+-------------+
-- | 97   | 75      | 2       | 2013-04-17  | 2013-04-17  |
-- +------+---------+---------+-------------+-------------+
-- | 98   | 4       | 256     | 2018-06-23  | 2018-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 99   | 35      | 567     | 1992-04-28  | 1992-05-26  |
-- +------+---------+---------+-------------+-------------+
-- | 100  | 19      | 360     | 2001-07-05  | 2001-07-17  |
-- +------+---------+---------+-------------+-------------+
-- | 101  | 108     | 300     | 2000-11-24  | 2000-12-16  |
-- +------+---------+---------+-------------+-------------+
-- | 102  | 154     | 525     | 2006-10-08  | 2006-10-18  |
-- +------+---------+---------+-------------+-------------+
-- | 103  | 232     | 424     | 2005-03-03  | 2005-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 104  | 96      | 137     | 2014-03-22  | 2014-04-03  |
-- +------+---------+---------+-------------+-------------+
-- | 105  | 173     | 469     | 1996-07-10  | 1996-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 106  | 205     | 210     | 2001-02-27  | 2001-03-27  |
-- +------+---------+---------+-------------+-------------+
-- | 107  | 22      | 317     | 2007-11-18  | 2007-12-05  |
-- +------+---------+---------+-------------+-------------+
-- | 108  | 137     | 330     | 1998-04-23  | 1998-04-25  |
-- +------+---------+---------+-------------+-------------+
-- | 109  | 220     | 538     | 1997-01-24  | 1997-02-04  |
-- +------+---------+---------+-------------+-------------+
-- | 110  | 90      | 544     | 2009-08-09  | 2009-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 111  | 218     | 56      | 2006-05-17  | 2006-05-25  |
-- +------+---------+---------+-------------+-------------+
-- | 112  | 222     | 217     | 2010-11-04  | 2010-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 113  | 213     | 377     | 1998-10-28  | 1998-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 114  | 88      | 33      | 1990-07-04  | 1990-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 115  | 113     | 6       | 2017-03-21  | 2017-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 116  | 173     | 394     | 1996-07-10  | 1996-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 117  | 238     | 294     | 2013-10-11  | 2013-10-17  |
-- +------+---------+---------+-------------+-------------+
-- | 118  | 3       | 100     | 2011-01-22  | 2011-02-16  |
-- +------+---------+---------+-------------+-------------+
-- | 119  | 44      | 152     | 1992-10-24  | 1992-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 120  | 127     | 40      | 2006-07-26  | 2006-08-11  |
-- +------+---------+---------+-------------+-------------+
-- | 121  | 148     | 406     | 2008-10-03  | 2008-10-07  |
-- +------+---------+---------+-------------+-------------+
-- | 122  | 95      | 78      | 2012-11-27  | 2012-12-25  |
-- +------+---------+---------+-------------+-------------+
-- | 123  | 60      | 420     | 2013-05-11  | 2013-05-11  |
-- +------+---------+---------+-------------+-------------+
-- | 124  | 67      | 286     | 2016-06-03  | 2016-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 125  | 34      | 519     | 1991-04-27  | 1991-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 126  | 138     | 77      | 2009-04-03  | 2009-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 127  | 67      | 304     | 2007-08-17  | 2007-08-25  |
-- +------+---------+---------+-------------+-------------+
-- | 128  | 14      | 20      | 2013-07-10  | 2013-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 129  | 221     | 360     | 2015-09-11  | 2015-10-02  |
-- +------+---------+---------+-------------+-------------+
-- | 130  | 201     | 150     | 1999-04-23  | 1999-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 131  | 208     | 336     | 2012-02-23  | 2012-03-23  |
-- +------+---------+---------+-------------+-------------+
-- | 132  | 181     | 332     | 2012-02-03  | 2012-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 133  | 249     | 433     | 2005-07-20  | 2005-08-07  |
-- +------+---------+---------+-------------+-------------+
-- | 134  | 88      | 564     | 1990-07-04  | 1990-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 135  | 101     | 583     | 2002-07-04  | 2002-07-19  |
-- +------+---------+---------+-------------+-------------+
-- | 136  | 9       | 373     | 2013-03-07  | 2013-03-31  |
-- +------+---------+---------+-------------+-------------+
-- | 137  | 168     | 292     | 2004-10-18  | 2004-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 138  | 39      | 57      | 2012-11-13  | 2012-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 139  | 7       | 474     | 1991-10-03  | 1991-10-09  |
-- +------+---------+---------+-------------+-------------+
-- | 140  | 174     | 135     | 2015-07-03  | 2015-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 141  | 146     | 314     | 1992-11-29  | 1992-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 142  | 93      | 300     | 2011-10-10  | 2011-11-08  |
-- +------+---------+---------+-------------+-------------+
-- | 143  | 244     | 105     | 2004-07-06  | 2004-07-31  |
-- +------+---------+---------+-------------+-------------+
-- | 144  | 74      | 311     | 2003-10-04  | 2003-10-27  |
-- +------+---------+---------+-------------+-------------+
-- | 145  | 186     | 298     | 2013-07-06  | 2013-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 146  | 157     | 366     | 2016-11-09  | 2016-11-30  |
-- +------+---------+---------+-------------+-------------+
-- | 147  | 101     | 618     | 2002-07-04  | 2002-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 148  | 215     | 448     | 2015-11-06  | 2015-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 149  | 11      | 633     | 1996-08-08  | 1996-08-25  |
-- +------+---------+---------+-------------+-------------+
-- | 150  | 60      | 322     | 2012-10-02  | 2012-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 151  | 155     | 50      | 2006-06-28  | 2006-07-20  |
-- +------+---------+---------+-------------+-------------+
-- | 152  | 246     | 68      | 1991-11-02  | 1991-11-19  |
-- +------+---------+---------+-------------+-------------+
-- | 153  | 189     | 355     | 2006-02-21  | 2006-03-17  |
-- +------+---------+---------+-------------+-------------+
-- | 154  | 159     | 197     | 1991-05-15  | 1991-06-01  |
-- +------+---------+---------+-------------+-------------+
-- | 155  | 8       | 430     | 2001-05-31  | 2001-06-24  |
-- +------+---------+---------+-------------+-------------+
-- | 156  | 103     | 155     | 2006-01-03  | 2006-01-31  |
-- +------+---------+---------+-------------+-------------+
-- | 157  | 229     | 529     | 1991-06-21  | 1991-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 158  | 230     | 119     | 2008-02-20  | 2008-03-04  |
-- +------+---------+---------+-------------+-------------+
-- | 159  | 80      | 452     | 1995-11-25  | 1995-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 160  | 34      | 228     | 2014-06-24  | 2014-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 161  | 91      | 95      | 2013-07-06  | 2013-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 162  | 34      | 133     | 2017-06-10  | 2017-06-26  |
-- +------+---------+---------+-------------+-------------+
-- | 163  | 123     | 337     | 2009-11-05  | 2009-11-13  |
-- +------+---------+---------+-------------+-------------+
-- | 164  | 57      | 92      | 2017-11-20  | 2017-12-02  |
-- +------+---------+---------+-------------+-------------+
-- | 165  | 120     | 227     | 2010-03-11  | 2010-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 166  | 128     | 189     | 2017-03-04  | 2017-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 167  | 37      | 327     | 2005-10-09  | 2005-10-13  |
-- +------+---------+---------+-------------+-------------+
-- | 168  | 138     | 287     | 2009-04-03  | 2009-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 169  | 93      | 115     | 2011-10-10  | 2011-11-07  |
-- +------+---------+---------+-------------+-------------+
-- | 170  | 125     | 178     | 2017-08-14  | 2017-08-28  |
-- +------+---------+---------+-------------+-------------+
-- | 171  | 218     | 327     | 2006-05-17  | 2006-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 172  | 119     | 85      | 2008-11-04  | 2008-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 173  | 5       | 566     | 2013-06-16  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 174  | 187     | 84      | 2008-11-22  | 2008-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 175  | 137     | 634     | 2015-11-13  | 2015-12-10  |
-- +------+---------+---------+-------------+-------------+
-- | 176  | 194     | 415     | 2017-05-11  | 2017-05-27  |
-- +------+---------+---------+-------------+-------------+
-- | 177  | 156     | 532     | 2006-02-01  | 2006-02-11  |
-- +------+---------+---------+-------------+-------------+
-- | 178  | 85      | 323     | 2009-12-30  | 2010-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 179  | 100     | 268     | 2007-11-07  | 2007-12-04  |
-- +------+---------+---------+-------------+-------------+
-- | 180  | 169     | 457     | 2017-01-01  | 2017-01-18  |
-- +------+---------+---------+-------------+-------------+
-- | 181  | 42      | 61      | 2007-01-15  | 2007-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 182  | 103     | 465     | 2006-01-03  | 2006-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 183  | 128     | 520     | 2017-03-04  | 2017-04-02  |
-- +------+---------+---------+-------------+-------------+
-- | 184  | 230     | 223     | 1994-02-13  | 1994-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 185  | 221     | 505     | 2015-09-11  | 2015-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 186  | 177     | 613     | 2003-05-04  | 2003-05-16  |
-- +------+---------+---------+-------------+-------------+
-- | 187  | 3       | 507     | 2011-01-22  | 2011-02-08  |
-- +------+---------+---------+-------------+-------------+
-- | 188  | 78      | 303     | 2010-12-13  | 2011-01-02  |
-- +------+---------+---------+-------------+-------------+
-- | 189  | 190     | 287     | 2005-08-22  | 2005-08-22  |
-- +------+---------+---------+-------------+-------------+
-- | 190  | 155     | 532     | 2006-06-28  | 2006-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 191  | 153     | 259     | 2012-12-30  | 2013-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 192  | 69      | 77      | 2007-06-26  | 2007-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 193  | 8       | 424     | 2005-03-03  | 2005-03-23  |
-- +------+---------+---------+-------------+-------------+
-- | 194  | 196     | 44      | 2018-07-19  | 2018-07-31  |
-- +------+---------+---------+-------------+-------------+
-- | 195  | 147     | 271     | 2008-02-29  | 2008-03-02  |
-- +------+---------+---------+-------------+-------------+
-- | 196  | 109     | 219     | 2016-10-16  | 2016-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 197  | 91      | 324     | 2013-07-06  | 2013-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 198  | 184     | 182     | 2018-02-03  | 2018-02-22  |
-- +------+---------+---------+-------------+-------------+
-- | 199  | 230     | 298     | 1994-02-13  | 1994-02-23  |
-- +------+---------+---------+-------------+-------------+
-- | 200  | 36      | 588     | 2010-10-26  | 2010-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 201  | 227     | 416     | 1997-09-22  | 1997-10-20  |
-- +------+---------+---------+-------------+-------------+
-- | 202  | 220     | 536     | 1996-08-31  | 1996-09-03  |
-- +------+---------+---------+-------------+-------------+
-- | 203  | 46      | 404     | 2009-02-27  | 2009-03-16  |
-- +------+---------+---------+-------------+-------------+
-- | 204  | 21      | 516     | 2006-06-16  | 2006-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 205  | 213     | 554     | 1998-10-28  | 1998-11-18  |
-- +------+---------+---------+-------------+-------------+
-- | 206  | 232     | 222     | 2017-08-24  | 2017-09-10  |
-- +------+---------+---------+-------------+-------------+
-- | 207  | 170     | 530     | 2011-11-26  | 2011-12-25  |
-- +------+---------+---------+-------------+-------------+
-- | 208  | 163     | 416     | 1994-08-18  | 1994-08-24  |
-- +------+---------+---------+-------------+-------------+
-- | 209  | 21      | 188     | 2004-03-18  | 2004-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 210  | 143     | 593     | 2010-03-05  | 2010-03-14  |
-- +------+---------+---------+-------------+-------------+
-- | 211  | 30      | 250     | 2016-10-24  | 2016-11-04  |
-- +------+---------+---------+-------------+-------------+
-- | 212  | 163     | 417     | 2006-01-12  | 2006-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 213  | 167     | 83      | 1993-07-04  | 1993-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 214  | 199     | 597     | 2007-08-07  | 2007-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 215  | 162     | 5       | 2018-08-04  | 2018-08-20  |
-- +------+---------+---------+-------------+-------------+
-- | 216  | 70      | 483     | 2006-06-25  | 2006-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 217  | 162     | 628     | 2009-10-23  | 2009-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 218  | 129     | 51      | 2017-09-05  |             |
-- +------+---------+---------+-------------+-------------+
-- | 219  | 130     | 619     | 2017-06-19  | 2017-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 220  | 99      | 198     | 2004-05-10  | 2004-06-06  |
-- +------+---------+---------+-------------+-------------+
-- | 221  | 39      | 463     | 2012-11-13  | 2012-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 222  | 119     | 245     | 2008-11-04  | 2008-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 223  | 145     | 339     | 2005-05-09  | 2005-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 224  | 193     | 295     | 2006-12-18  | 2007-01-06  |
-- +------+---------+---------+-------------+-------------+
-- | 225  | 148     | 601     | 1998-10-16  | 1998-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 226  | 205     | 329     | 2000-06-15  | 2000-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 227  | 36      | 423     | 1992-03-16  | 1992-04-06  |
-- +------+---------+---------+-------------+-------------+
-- | 228  | 24      | 173     | 1999-01-19  | 1999-01-25  |
-- +------+---------+---------+-------------+-------------+
-- | 229  | 205     | 529     | 1991-12-28  | 1992-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 230  | 163     | 35      | 1994-08-18  | 1994-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 231  | 144     | 540     | 1998-04-01  | 1998-04-26  |
-- +------+---------+---------+-------------+-------------+
-- | 232  | 224     | 122     | 2018-04-22  | 2018-05-03  |
-- +------+---------+---------+-------------+-------------+
-- | 233  | 20      | 130     | 2010-03-31  | 2010-04-04  |
-- +------+---------+---------+-------------+-------------+
-- | 234  | 126     | 331     | 2001-10-14  | 2001-10-14  |
-- +------+---------+---------+-------------+-------------+
-- | 235  | 159     | 219     | 2016-10-16  | 2016-10-20  |
-- +------+---------+---------+-------------+-------------+
-- | 236  | 19      | 607     | 2006-01-06  | 2006-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 237  | 209     | 563     | 2016-12-12  | 2017-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 238  | 168     | 399     | 2004-10-18  | 2004-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 239  | 8       | 476     | 2001-05-31  | 2001-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 240  | 238     | 578     | 2013-10-11  | 2013-11-05  |
-- +------+---------+---------+-------------+-------------+
-- | 241  | 80      | 291     | 1995-11-25  | 1995-12-18  |
-- +------+---------+---------+-------------+-------------+
-- | 242  | 31      | 468     | 2001-10-18  | 2001-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 243  | 72      | 498     | 2012-12-17  | 2012-12-22  |
-- +------+---------+---------+-------------+-------------+
-- | 244  | 205     | 203     | 2017-12-24  | 2018-01-09  |
-- +------+---------+---------+-------------+-------------+
-- | 245  | 2       | 481     | 1999-08-09  | 1999-09-04  |
-- +------+---------+---------+-------------+-------------+
-- | 246  | 173     | 228     | 2014-06-24  | 2014-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 247  | 248     | 310     | 2006-01-21  | 2006-01-30  |
-- +------+---------+---------+-------------+-------------+
-- | 248  | 144     | 59      | 1998-04-01  | 1998-04-18  |
-- +------+---------+---------+-------------+-------------+
-- | 249  | 245     | 289     | 2006-06-13  | 2006-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 250  | 67      | 628     | 2009-10-23  | 2009-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 251  | 45      | 98      | 2017-01-14  | 2017-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 252  | 237     | 505     | 2016-10-16  | 2016-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 253  | 117     | 627     | 2011-01-13  | 2011-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 254  | 123     | 561     | 2009-11-05  | 2009-11-17  |
-- +------+---------+---------+-------------+-------------+
-- | 255  | 119     | 216     | 2008-11-04  | 2008-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 256  | 22      | 460     | 2007-11-18  | 2007-11-30  |
-- +------+---------+---------+-------------+-------------+
-- | 257  | 32      | 6       | 2012-07-22  | 2012-08-09  |
-- +------+---------+---------+-------------+-------------+
-- | 258  | 139     | 496     | 2016-05-30  | 2016-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 259  | 55      | 336     | 2014-03-05  | 2014-03-19  |
-- +------+---------+---------+-------------+-------------+
-- | 260  | 219     | 26      | 2017-10-04  | 2017-10-21  |
-- +------+---------+---------+-------------+-------------+
-- | 261  | 191     | 197     | 2015-11-28  | 2015-12-07  |
-- +------+---------+---------+-------------+-------------+
-- | 262  | 166     | 341     | 2005-06-05  | 2005-07-01  |
-- +------+---------+---------+-------------+-------------+
-- | 263  | 69      | 585     | 2007-06-26  | 2007-07-07  |
-- +------+---------+---------+-------------+-------------+
-- | 264  | 48      | 481     | 2013-06-25  | 2013-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 265  | 105     | 15      | 2005-06-13  | 2005-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 266  | 120     | 356     | 1999-10-25  | 1999-10-29  |
-- +------+---------+---------+-------------+-------------+
-- | 267  | 91      | 606     | 2013-07-06  | 2013-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 268  | 196     | 228     | 2014-06-24  | 2014-06-29  |
-- +------+---------+---------+-------------+-------------+
-- | 269  | 84      | 244     | 2010-04-05  | 2010-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 270  | 73      | 48      | 2013-06-30  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 271  | 178     | 52      | 2017-01-09  | 2017-02-06  |
-- +------+---------+---------+-------------+-------------+
-- | 272  | 35      | 108     | 2005-02-26  | 2005-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 273  | 158     | 387     | 2007-04-25  | 2007-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 274  | 165     | 260     | 2016-09-05  | 2016-09-30  |
-- +------+---------+---------+-------------+-------------+
-- | 275  | 61      | 56      | 2015-10-14  | 2015-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 276  | 199     | 316     | 1995-06-29  | 1995-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 277  | 23      | 141     | 2017-11-06  | 2017-11-24  |
-- +------+---------+---------+-------------+-------------+
-- | 278  | 188     | 362     | 1994-07-14  | 1994-08-12  |
-- +------+---------+---------+-------------+-------------+
-- | 279  | 147     | 221     | 2008-02-29  | 2008-03-28  |
-- +------+---------+---------+-------------+-------------+
-- | 280  | 109     | 575     | 2009-04-21  | 2009-05-12  |
-- +------+---------+---------+-------------+-------------+
-- | 281  | 92      | 626     | 2016-05-06  | 2016-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 282  | 215     | 617     | 2009-11-07  | 2009-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 283  | 155     | 4       | 2006-06-28  | 2006-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 284  | 71      | 332     | 2014-06-27  | 2014-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 285  | 12      | 147     | 2007-04-08  | 2007-04-24  |
-- +------+---------+---------+-------------+-------------+
-- | 286  | 185     | 305     | 2015-06-02  | 2015-06-30  |
-- +------+---------+---------+-------------+-------------+
-- | 287  | 66      | 521     | 2006-05-22  | 2006-06-15  |
-- +------+---------+---------+-------------+-------------+
-- | 288  | 138     | 372     | 2015-09-25  | 2015-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 289  | 14      | 530     | 2013-07-10  | 2013-07-27  |
-- +------+---------+---------+-------------+-------------+
-- | 290  | 38      | 275     | 2006-09-01  | 2006-09-29  |
-- +------+---------+---------+-------------+-------------+
-- | 291  | 52      | 441     | 2006-06-17  | 2006-07-03  |
-- +------+---------+---------+-------------+-------------+
-- | 292  | 34      | 357     | 1991-04-27  | 1991-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 293  | 20      | 605     | 2010-03-31  | 2010-04-15  |
-- +------+---------+---------+-------------+-------------+
-- | 294  | 71      | 14      | 2014-06-27  | 2014-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 295  | 40      | 260     | 2016-09-05  | 2016-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 296  | 53      | 299     | 1990-03-21  | 1990-04-19  |
-- +------+---------+---------+-------------+-------------+
-- | 297  | 208     | 293     | 2012-02-23  | 2012-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 298  | 245     | 376     | 2006-06-13  | 2006-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 299  | 164     | 138     | 1999-11-10  | 1999-11-29  |
-- +------+---------+---------+-------------+-------------+
-- | 300  | 64      | 626     | 1990-12-22  | 1991-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 301  | 121     | 468     | 2009-10-25  | 2009-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 302  | 17      | 616     | 2000-04-21  | 2000-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 303  | 181     | 523     | 2015-06-12  | 2015-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 304  | 26      | 106     | 2004-07-16  | 2004-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 305  | 57      | 440     | 1992-03-01  | 1992-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 306  | 242     | 58      | 2015-12-13  | 2015-12-21  |
-- +------+---------+---------+-------------+-------------+
-- | 307  | 203     | 247     | 1996-03-20  | 1996-04-17  |
-- +------+---------+---------+-------------+-------------+
-- | 308  | 221     | 55      | 2015-09-11  | 2015-09-25  |
-- +------+---------+---------+-------------+-------------+
-- | 309  | 60      | 123     | 2012-10-02  | 2012-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 310  | 143     | 587     | 2010-03-05  | 2010-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 311  | 1       | 444     | 2008-07-04  | 2008-08-01  |
-- +------+---------+---------+-------------+-------------+
-- | 312  | 108     | 449     | 1992-04-04  | 1992-04-12  |
-- +------+---------+---------+-------------+-------------+
-- | 313  | 195     | 334     | 2017-07-11  | 2017-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 314  | 54      | 81      | 2017-07-29  | 2017-08-08  |
-- +------+---------+---------+-------------+-------------+
-- | 315  | 136     | 210     | 2006-05-17  | 2006-05-31  |
-- +------+---------+---------+-------------+-------------+
-- | 316  | 98      | 141     | 2017-11-06  | 2017-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 317  | 120     | 438     | 1999-10-25  | 1999-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 318  | 41      | 297     | 2013-02-28  | 2013-02-28  |
-- +------+---------+---------+-------------+-------------+
-- | 319  | 24      | 19      | 1999-01-19  | 1999-02-16  |
-- +------+---------+---------+-------------+-------------+
-- | 320  | 158     | 94      | 2012-08-23  | 2012-09-07  |
-- +------+---------+---------+-------------+-------------+
-- | 321  | 39      | 29      | 2016-02-23  | 2016-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 322  | 173     | 308     | 2018-07-02  | 2018-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 323  | 5       | 420     | 2013-06-16  | 2013-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 324  | 14      | 323     | 2013-07-10  | 2013-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 325  | 163     | 177     | 1994-08-18  | 1994-08-20  |
-- +------+---------+---------+-------------+-------------+
-- | 326  | 5       | 270     | 2013-06-16  | 2013-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 327  | 212     | 274     | 1998-10-14  | 1998-10-15  |
-- +------+---------+---------+-------------+-------------+
-- | 328  | 8       | 320     | 2001-06-01  | 2001-06-17  |
-- +------+---------+---------+-------------+-------------+
-- | 329  | 243     | 33      | 2000-11-23  | 2000-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 330  | 164     | 94      | 2012-08-23  | 2012-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 331  | 229     | 259     | 2012-12-30  |             |
-- +------+---------+---------+-------------+-------------+
-- | 332  | 197     | 363     | 2012-11-05  | 2012-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 333  | 25      | 330     | 2003-06-09  | 2003-06-23  |
-- +------+---------+---------+-------------+-------------+
-- | 334  | 101     | 45      | 2002-07-04  | 2002-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 335  | 50      | 476     | 1990-11-08  | 1990-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 336  | 140     | 608     | 2011-04-12  | 2011-04-16  |
-- +------+---------+---------+-------------+-------------+
-- | 337  | 31      | 9       | 2001-10-18  | 2001-10-21  |
-- +------+---------+---------+-------------+-------------+
-- | 338  | 153     | 15      | 2002-09-20  | 2002-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 339  | 149     | 241     | 2009-10-04  | 2009-10-19  |
-- +------+---------+---------+-------------+-------------+
-- | 340  | 72      | 563     | 2016-12-12  | 2016-12-12  |
-- +------+---------+---------+-------------+-------------+
-- | 341  | 73      | 167     | 1997-05-11  | 1997-05-12  |
-- +------+---------+---------+-------------+-------------+
-- | 342  | 78      | 562     | 2010-12-13  |             |
-- +------+---------+---------+-------------+-------------+
-- | 343  | 136     | 177     | 2006-05-17  | 2006-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 344  | 231     | 495     | 2017-03-12  | 2017-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 345  | 76      | 612     | 2011-04-23  | 2011-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 346  | 90      | 367     | 2009-08-09  | 2009-08-12  |
-- +------+---------+---------+-------------+-------------+
-- | 347  | 82      | 153     | 2016-10-26  | 2016-11-05  |
-- +------+---------+---------+-------------+-------------+
-- | 348  | 57      | 436     | 1992-03-01  | 1992-03-07  |
-- +------+---------+---------+-------------+-------------+
-- | 349  | 94      | 99      | 2012-04-23  | 2012-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 350  | 130     | 104     | 2014-12-01  | 2014-12-20  |
-- +------+---------+---------+-------------+-------------+
-- | 351  | 115     | 92      | 2017-11-20  | 2017-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 352  | 190     | 38      | 2005-08-22  | 2005-08-22  |
-- +------+---------+---------+-------------+-------------+
-- | 353  | 239     | 620     | 2010-10-02  | 2010-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 354  | 188     | 247     | 1994-07-14  | 1994-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 355  | 171     | 37      | 2015-06-19  | 2015-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 356  | 173     | 223     | 1996-07-10  | 1996-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 357  | 246     | 49      | 1991-11-02  | 1991-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 358  | 229     | 247     | 1991-06-21  | 1991-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 359  | 17      | 527     | 2010-12-07  | 2010-12-17  |
-- +------+---------+---------+-------------+-------------+
-- | 360  | 152     | 267     | 2012-09-13  | 2012-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 361  | 123     | 483     | 2009-11-05  | 2009-12-02  |
-- +------+---------+---------+-------------+-------------+
-- | 362  | 123     | 492     | 2009-11-05  | 2009-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 363  | 242     | 349     | 1994-11-17  | 1994-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 364  | 167     | 443     | 1992-01-03  | 1992-01-24  |
-- +------+---------+---------+-------------+-------------+
-- | 365  | 7       | 569     | 2002-02-15  | 2002-03-07  |
-- +------+---------+---------+-------------+-------------+
-- | 366  | 81      | 465     | 2015-06-18  | 2015-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 367  | 2       | 107     | 1999-08-09  | 1999-08-19  |
-- +------+---------+---------+-------------+-------------+
-- | 368  | 120     | 323     | 1999-10-25  | 1999-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 369  | 82      | 402     | 2016-10-26  | 2016-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 370  | 168     | 607     | 2006-01-06  | 2006-02-01  |
-- +------+---------+---------+-------------+-------------+
-- | 371  | 147     | 617     | 2008-02-29  | 2008-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 372  | 183     | 418     | 2015-12-23  | 2016-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 373  | 45      | 44      | 2018-07-19  | 2018-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 374  | 226     | 437     | 2014-03-08  | 2014-03-18  |
-- +------+---------+---------+-------------+-------------+
-- | 375  | 136     | 41      | 2006-05-17  | 2006-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 376  | 180     | 342     | 2011-01-30  | 2011-02-15  |
-- +------+---------+---------+-------------+-------------+
-- | 377  | 197     | 257     | 2011-04-19  | 2011-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 378  | 59      | 285     | 2005-07-23  | 2005-07-26  |
-- +------+---------+---------+-------------+-------------+
-- | 379  | 145     | 57      | 2005-05-09  | 2005-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 380  | 237     | 406     | 2016-10-16  | 2016-10-22  |
-- +------+---------+---------+-------------+-------------+
-- | 381  | 244     | 31      | 2014-04-02  | 2014-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 382  | 196     | 93      | 2000-06-03  | 2000-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 383  | 136     | 545     | 2006-05-17  | 2006-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 384  | 112     | 92      | 2017-11-20  | 2017-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 385  | 164     | 502     | 1999-11-10  | 1999-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 386  | 107     | 148     | 2014-06-01  | 2014-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 387  | 90      | 237     | 2014-05-01  | 2014-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 388  | 190     | 336     | 2005-08-22  | 2005-08-30  |
-- +------+---------+---------+-------------+-------------+
-- | 389  | 120     | 405     | 1999-10-25  | 1999-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 390  | 104     | 97      | 2007-01-12  | 2007-01-28  |
-- +------+---------+---------+-------------+-------------+
-- | 391  | 0       | 530     | 1994-04-27  | 1994-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 392  | 49      | 312     | 2015-04-27  | 2015-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 393  | 120     | 252     | 1999-10-25  | 1999-10-25  |
-- +------+---------+---------+-------------+-------------+
-- | 394  | 247     | 196     | 1992-06-14  | 1992-06-24  |
-- +------+---------+---------+-------------+-------------+
-- | 395  | 229     | 587     | 1991-06-21  | 1991-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 396  | 32      | 168     | 2012-07-22  | 2012-08-09  |
-- +------+---------+---------+-------------+-------------+
-- | 397  | 238     | 509     | 2013-10-11  | 2013-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 398  | 164     | 540     | 1999-11-10  | 1999-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 399  | 154     | 393     | 2006-10-08  | 2006-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 400  | 188     | 37      | 1994-07-14  | 1994-08-11  |
-- +------+---------+---------+-------------+-------------+
-- | 401  | 14      | 214     | 2015-11-19  | 2015-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 402  | 157     | 490     | 2016-11-09  | 2016-12-07  |
-- +------+---------+---------+-------------+-------------+
-- | 403  | 79      | 173     | 2017-08-20  | 2017-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 404  | 154     | 2       | 2006-10-08  | 2006-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 405  | 244     | 70      | 2004-07-06  | 2004-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 406  | 19      | 288     | 2001-07-05  | 2001-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 407  | 194     | 488     | 2017-05-11  | 2017-05-25  |
-- +------+---------+---------+-------------+-------------+
-- | 408  | 21      | 207     | 2004-03-18  | 2004-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 409  | 74      | 127     | 2003-10-04  | 2003-10-09  |
-- +------+---------+---------+-------------+-------------+
-- | 410  | 77      | 610     | 2017-12-15  | 2017-12-18  |
-- +------+---------+---------+-------------+-------------+
-- | 411  | 214     | 579     | 1994-12-27  | 1995-01-08  |
-- +------+---------+---------+-------------+-------------+
-- | 412  | 90      | 115     | 2009-08-09  | 2009-08-16  |
-- +------+---------+---------+-------------+-------------+
-- | 413  | 220     | 623     | 1996-08-31  | 1996-09-15  |
-- +------+---------+---------+-------------+-------------+
-- | 414  | 83      | 98      | 2012-05-29  |             |
-- +------+---------+---------+-------------+-------------+
-- | 415  | 223     | 466     | 2010-03-06  | 2010-03-12  |
-- +------+---------+---------+-------------+-------------+
-- | 416  | 34      | 579     | 1991-04-27  | 1991-05-24  |
-- +------+---------+---------+-------------+-------------+
-- | 417  | 234     | 89      | 2009-02-15  | 2009-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 418  | 189     | 448     | 2015-11-06  | 2015-11-24  |
-- +------+---------+---------+-------------+-------------+
-- | 419  | 138     | 506     | 2009-04-03  | 2009-04-07  |
-- ...
-- | 1860 | 94      | 436     | 2012-04-23  | 2012-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1861 | 61      | 91      | 2015-10-14  | 2015-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1862 | 247     | 286     | 2016-06-03  | 2016-06-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1863 | 169     | 384     | 2017-01-01  | 2017-01-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1864 | 151     | 529     | 1993-09-11  | 1993-10-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1865 | 0       | 563     | 2016-12-12  | 2016-12-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1866 | 84      | 453     | 1995-05-02  | 1995-05-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1867 | 68      | 82      | 2016-05-20  | 2016-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1868 | 76      | 53      | 2011-04-23  | 2011-05-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1869 | 155     | 17      | 2006-06-28  | 2006-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1870 | 238     | 313     | 2013-10-11  | 2013-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1871 | 101     | 438     | 2002-07-04  | 2002-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1872 | 66      | 126     | 2015-02-17  | 2015-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1873 | 182     | 524     | 2004-12-26  | 2005-01-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1874 | 212     | 416     | 1998-10-14  | 1998-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1875 | 227     | 135     | 2015-07-03  | 2015-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1876 | 109     | 569     | 2009-04-21  | 2009-05-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1877 | 111     | 218     | 2015-04-29  | 2015-05-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1878 | 53      | 362     | 1990-10-21  | 1990-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1879 | 155     | 580     | 2009-10-08  | 2009-10-26  |
-- +------+---------+---------+-------------+-------------+
-- | 1880 | 73      | 458     | 1997-05-11  | 1997-05-19  |
-- +------+---------+---------+-------------+-------------+
-- | 1881 | 197     | 3       | 2017-03-02  | 2017-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 1882 | 230     | 12      | 1994-02-13  | 1994-02-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1883 | 21      | 490     | 2004-03-18  | 2004-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1884 | 89      | 476     | 1991-03-11  | 1991-04-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1885 | 126     | 130     | 2001-10-14  | 2001-11-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1886 | 133     | 338     | 2018-04-23  | 2018-05-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1887 | 38      | 459     | 2006-09-01  | 2006-09-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1888 | 123     | 310     | 2009-11-05  | 2009-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1889 | 1       | 190     | 2008-07-04  | 2008-07-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1890 | 123     | 153     | 2009-11-05  | 2009-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1891 | 150     | 277     | 2017-02-22  | 2017-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1892 | 86      | 417     | 2006-01-12  | 2006-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1893 | 131     | 239     | 2001-07-09  | 2001-08-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1894 | 218     | 602     | 2006-05-17  | 2006-05-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1895 | 56      | 489     | 2016-08-02  | 2016-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1896 | 92      | 9       | 2016-05-06  | 2016-06-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1897 | 185     | 82      | 2015-06-02  | 2015-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1898 | 78      | 191     | 2010-12-13  | 2011-01-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1899 | 203     | 302     | 2018-08-01  | 2018-08-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1900 | 71      | 339     | 2014-06-27  | 2014-07-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1901 | 165     | 183     | 1999-08-25  | 1999-09-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1902 | 38      | 114     | 2006-09-01  | 2006-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1903 | 91      | 602     | 2013-07-06  | 2013-07-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1904 | 243     | 167     | 2000-11-23  | 2000-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1905 | 225     | 613     | 2012-09-23  | 2012-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1906 | 247     | 208     | 1992-06-14  | 1992-06-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1907 | 132     | 316     | 2004-10-16  | 2004-10-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1908 | 102     | 195     | 2013-09-11  | 2013-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1909 | 68      | 228     | 2016-05-20  | 2016-05-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1910 | 109     | 365     | 2009-04-21  | 2009-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1911 | 38      | 543     | 2015-11-09  | 2015-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1912 | 142     | 534     | 2009-10-29  | 2009-10-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1913 | 29      | 293     | 2000-02-14  | 2000-02-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1914 | 171     | 135     | 2015-07-03  | 2015-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1915 | 127     | 63      | 2006-07-26  | 2006-08-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1916 | 230     | 196     | 1994-02-13  | 1994-02-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1917 | 95      | 368     | 2012-11-27  | 2012-12-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1918 | 32      | 624     | 2012-07-22  | 2012-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1919 | 160     | 446     | 1990-12-18  | 1991-01-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1920 | 31      | 268     | 2001-10-18  | 2001-10-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1921 | 156     | 405     | 1998-03-13  | 1998-03-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1922 | 248     | 587     | 2006-01-21  | 2006-01-25  |
-- +------+---------+---------+-------------+-------------+
-- | 1923 | 76      | 150     | 2011-04-23  | 2011-05-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1924 | 223     | 327     | 2010-03-06  | 2010-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1925 | 6       | 45      | 1999-02-13  | 1999-02-18  |
-- +------+---------+---------+-------------+-------------+
-- | 1926 | 1       | 504     | 2008-07-04  | 2008-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1927 | 245     | 455     | 2012-09-24  | 2012-10-19  |
-- +------+---------+---------+-------------+-------------+
-- | 1928 | 166     | 97      | 2005-06-05  | 2005-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1929 | 48      | 636     | 2013-06-25  | 2013-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1930 | 184     | 172     | 2012-01-16  | 2012-02-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1931 | 169     | 622     | 2017-01-01  | 2017-01-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1932 | 51      | 141     | 2017-11-06  | 2017-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1933 | 60      | 81      | 2012-10-02  | 2012-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1934 | 5       | 451     | 2013-06-16  | 2013-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1935 | 63      | 277     | 2017-02-22  | 2017-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1936 | 215     | 288     | 2009-11-07  | 2009-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1937 | 136     | 86      | 2006-05-17  | 2006-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1938 | 33      | 436     | 2006-06-17  | 2006-06-18  |
-- +------+---------+---------+-------------+-------------+
-- | 1939 | 104     | 104     | 2007-01-12  | 2007-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1940 | 109     | 373     | 2009-04-21  | 2009-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1941 | 102     | 419     | 2008-03-07  | 2008-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1942 | 137     | 562     | 1998-04-23  | 1998-04-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1943 | 13      | 598     | 2003-10-21  | 2003-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1944 | 15      | 47      | 2004-08-13  | 2004-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1945 | 87      | 563     | 2016-12-12  | 2016-12-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1946 | 193     | 323     | 2006-12-18  | 2006-12-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1947 | 69      | 428     | 2007-06-26  | 2007-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1948 | 24      | 217     | 2008-09-17  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1949 | 180     | 48      | 2013-06-30  | 2013-06-30  |
-- +------+---------+---------+-------------+-------------+
-- | 1950 | 44      | 65      | 1992-10-24  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1951 | 32      | 349     | 2012-07-22  | 2012-08-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1952 | 207     | 7       | 2007-10-01  | 2007-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1953 | 201     | 50      | 1999-02-16  | 1999-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1954 | 54      | 506     | 2017-07-29  | 2017-08-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1955 | 9       | 317     | 2013-03-07  | 2013-03-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1956 | 229     | 37      | 1991-06-21  | 1991-07-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1957 | 5       | 421     | 2013-06-16  | 2013-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1958 | 194     | 90      | 2017-05-11  | 2017-05-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1959 | 14      | 411     | 2013-07-10  | 2013-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1960 | 166     | 249     | 2005-06-05  | 2005-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1961 | 241     | 135     | 2015-07-13  | 2015-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1962 | 31      | 445     | 2001-10-18  | 2001-11-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1963 | 237     | 230     | 2016-10-16  | 2016-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1964 | 101     | 170     | 2002-07-04  | 2002-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 1965 | 185     | 425     | 2015-06-02  | 2015-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1966 | 80      | 443     | 1995-11-25  | 1995-12-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1967 | 119     | 337     | 2008-11-04  | 2008-12-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1968 | 196     | 100     | 2000-06-03  | 2000-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1969 | 94      | 424     | 2012-04-23  | 2012-04-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1970 | 187     | 282     | 2008-11-22  | 2008-12-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1971 | 83      | 71      | 2012-05-29  | 2012-06-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1972 | 112     | 541     | 2015-08-13  | 2015-09-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1973 | 72      | 543     | 2015-11-09  | 2015-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1974 | 56      | 564     | 2016-08-02  | 2016-08-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1975 | 168     | 530     | 2004-10-18  | 2004-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1976 | 220     | 256     | 2018-06-23  | 2018-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1977 | 240     | 503     | 2007-06-29  | 2007-07-26  |
-- +------+---------+---------+-------------+-------------+
-- | 1978 | 10      | 163     | 2017-09-08  | 2017-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1979 | 36      | 313     | 2011-10-17  | 2011-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1980 | 130     | 333     | 2014-12-01  | 2014-12-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1981 | 33      | 347     | 2013-07-31  | 2013-08-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1982 | 166     | 181     | 2016-01-26  | 2016-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1983 | 28      | 116     | 2017-08-20  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1984 | 44      | 133     | 2017-06-10  | 2017-06-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1985 | 103     | 309     | 2006-01-03  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1986 | 102     | 633     | 2008-03-07  | 2008-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1987 | 120     | 310     | 1999-10-25  | 1999-11-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1988 | 248     | 185     | 2006-01-21  | 2006-02-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1989 | 174     | 623     | 1990-03-26  | 1990-04-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1990 | 14      | 479     | 2013-07-10  | 2013-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1991 | 36      | 211     | 1995-05-18  | 1995-06-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1992 | 89      | 547     | 1991-03-11  | 1991-03-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1993 | 183     | 274     | 2015-12-23  | 2016-01-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1994 | 67      | 256     | 2018-06-23  | 2018-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1995 | 182     | 414     | 2004-12-26  | 2005-01-12  |
-- +------+---------+---------+-------------+-------------+
-- | 1996 | 127     | 230     | 2006-07-26  | 2006-08-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1997 | 118     | 356     | 1998-06-26  | 1998-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 1998 | 212     | 11      | 1998-10-14  | 1998-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1999 | 173     | 547     | 1996-07-10  | 1996-07-22  |
-- +------+---------+---------+-------------+-------------+

-- %% [markdown]
-- Zapytanie i wynik zapytania:

-- %%
SELECT users.name, users.surname, COUNT(borrowings.ID) AS activity FROM users JOIN borrowings
ON users.ID=borrowings.user_id GROUP BY users.ID;
-- Out:
-- +-------------+---------------+----------+
-- | name        | surname       | activity |
-- +-------------+---------------+----------+
-- | Igor        | Piotrowski    | 8        |
-- +-------------+---------------+----------+
-- | Róża      | Lewandowska   | 8        |
-- +-------------+---------------+----------+
-- | Klaudia     | Lewandowska   | 10       |
-- +-------------+---------------+----------+
-- | Mateusz     | Grabowski     | 4        |
-- +-------------+---------------+----------+
-- | Paulina     | Wojciechowska | 13       |
-- +-------------+---------------+----------+
-- | Marta       | Woźniak      | 5        |
-- +-------------+---------------+----------+
-- | Joanna      | Dąbrowska    | 7        |
-- +-------------+---------------+----------+
-- | Marcel      | Kamiński     | 11       |
-- +-------------+---------------+----------+
-- | Michał     | Nowak         | 6        |
-- +-------------+---------------+----------+
-- | Marta       | Wiśniewska   | 3        |
-- +-------------+---------------+----------+
-- | Leon        | Zieliński    | 5        |
-- +-------------+---------------+----------+
-- | Wiktor      | Wojciechowski | 8        |
-- +-------------+---------------+----------+
-- | Małgorzata | Piotrowska    | 13       |
-- +-------------+---------------+----------+
-- | Igor        | Piotrowski    | 8        |
-- +-------------+---------------+----------+
-- | Paulina     | Kowalska      | 5        |
-- +-------------+---------------+----------+
-- | Paulina     | Kwiatkowska   | 2        |
-- +-------------+---------------+----------+
-- | Aniela      | Grabowska     | 8        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Kowalczyk     | 7        |
-- +-------------+---------------+----------+
-- | Liliana     | Nowak         | 7        |
-- +-------------+---------------+----------+
-- | Leon        | Kaczmarek     | 7        |
-- +-------------+---------------+----------+
-- | Leon        | Kowalczyk     | 8        |
-- +-------------+---------------+----------+
-- | Marta       | Kowalska      | 10       |
-- +-------------+---------------+----------+
-- | Joanna      | Kowalska      | 6        |
-- +-------------+---------------+----------+
-- | Paulina     | Krawczyk      | 10       |
-- +-------------+---------------+----------+
-- | Róża      | Nowak         | 4        |
-- +-------------+---------------+----------+
-- | Róża      | Dąbrowska    | 14       |
-- +-------------+---------------+----------+
-- | Joanna      | Grabowska     | 9        |
-- +-------------+---------------+----------+
-- | Igor        | Grabowski     | 6        |
-- +-------------+---------------+----------+
-- | Sara        | Kaczmarek     | 14       |
-- +-------------+---------------+----------+
-- | Izabela     | Lewandowska   | 7        |
-- +-------------+---------------+----------+
-- | Izabela     | Piotrowska    | 9        |
-- +-------------+---------------+----------+
-- | Róża      | Dąbrowska    | 7        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Nowak         | 6        |
-- +-------------+---------------+----------+
-- | Małgorzata | Kaczmarek     | 9        |
-- +-------------+---------------+----------+
-- | Adam        | Kowalczyk     | 13       |
-- +-------------+---------------+----------+
-- | Izabela     | Kowalska      | 3        |
-- +-------------+---------------+----------+
-- | Adam        | Szymański    | 7        |
-- +-------------+---------------+----------+
-- | Nikodem     | Woźniak      | 4        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Wojciechowska | 8        |
-- +-------------+---------------+----------+
-- | Igor        | Kaczmarek     | 8        |
-- +-------------+---------------+----------+
-- | Nikodem     | Dąbrowski    | 3        |
-- +-------------+---------------+----------+
-- | Aniela      | Dąbrowska    | 13       |
-- +-------------+---------------+----------+
-- | Izabela     | Wójcik       | 9        |
-- +-------------+---------------+----------+
-- | Izabela     | Piotrowska    | 7        |
-- +-------------+---------------+----------+
-- | Izabela     | Kwiatkowska   | 10       |
-- +-------------+---------------+----------+
-- | Małgorzata | Kowalska      | 2        |
-- +-------------+---------------+----------+
-- | Izabela     | Kamińska     | 10       |
-- +-------------+---------------+----------+
-- | Mateusz     | Nowak         | 6        |
-- +-------------+---------------+----------+
-- | Róża      | Zielińska    | 6        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Wiśniewska   | 9        |
-- +-------------+---------------+----------+
-- | Michał     | Wiśniewski   | 6        |
-- +-------------+---------------+----------+
-- | Aniela      | Dąbrowska    | 7        |
-- +-------------+---------------+----------+
-- | Róża      | Kaczmarek     | 3        |
-- +-------------+---------------+----------+
-- | Piotr       | Kamiński     | 5        |
-- +-------------+---------------+----------+
-- | Matylda     | Woźniak      | 5        |
-- +-------------+---------------+----------+
-- | Igor        | Dąbrowski    | 10       |
-- +-------------+---------------+----------+
-- | Marcel      | Lewandowski   | 6        |
-- +-------------+---------------+----------+
-- | Mateusz     | Kowalczyk     | 8        |
-- +-------------+---------------+----------+
-- | Małgorzata | Jankowska     | 6        |
-- +-------------+---------------+----------+
-- | Wiktor      | Kamiński     | 7        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Krawczyk      | 14       |
-- +-------------+---------------+----------+
-- | Adam        | Mazur         | 2        |
-- +-------------+---------------+----------+
-- | Sara        | Kwiatkowska   | 9        |
-- +-------------+---------------+----------+
-- | Stanisław  | Wójcik       | 13       |
-- +-------------+---------------+----------+
-- | Mateusz     | Grabowski     | 10       |
-- +-------------+---------------+----------+
-- | Katarzyna   | Wiśniewska   | 5        |
-- +-------------+---------------+----------+
-- | Michał     | Krawczyk      | 10       |
-- +-------------+---------------+----------+
-- | Piotr       | Szymański    | 12       |
-- +-------------+---------------+----------+
-- | Michał     | Mazur         | 8        |
-- +-------------+---------------+----------+
-- | Leon        | Kamiński     | 11       |
-- +-------------+---------------+----------+
-- | Marcel      | Krawczyk      | 9        |
-- +-------------+---------------+----------+
-- | Aniela      | Kozłowska    | 7        |
-- +-------------+---------------+----------+
-- | Leon        | Wojciechowski | 9        |
-- +-------------+---------------+----------+
-- | Liliana     | Wójcik       | 13       |
-- +-------------+---------------+----------+
-- | Wiktor      | Piotrowski    | 8        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Wiśniewska   | 10       |
-- +-------------+---------------+----------+
-- | Sara        | Kozłowska    | 6        |
-- +-------------+---------------+----------+
-- | Adam        | Woźniak      | 8        |
-- +-------------+---------------+----------+
-- | Adam        | Nowak         | 8        |
-- +-------------+---------------+----------+
-- | Piotr       | Piotrowski    | 9        |
-- +-------------+---------------+----------+
-- | Róża      | Kowalska      | 11       |
-- +-------------+---------------+----------+
-- | Michał     | Lewandowski   | 8        |
-- +-------------+---------------+----------+
-- | Izabela     | Nowak         | 7        |
-- +-------------+---------------+----------+
-- | Aniela      | Nowak         | 14       |
-- +-------------+---------------+----------+
-- | Joanna      | Piotrowska    | 11       |
-- +-------------+---------------+----------+
-- | Joanna      | Kowalczyk     | 7        |
-- +-------------+---------------+----------+
-- | Liliana     | Zielińska    | 10       |
-- +-------------+---------------+----------+
-- | Paulina     | Jankowska     | 9        |
-- +-------------+---------------+----------+
-- | Stanisław  | Piotrowski    | 9        |
-- +-------------+---------------+----------+
-- | Róża      | Wiśniewska   | 8        |
-- +-------------+---------------+----------+
-- | Adam        | Lewandowski   | 4        |
-- +-------------+---------------+----------+
-- | Piotr       | Piotrowski    | 14       |
-- +-------------+---------------+----------+
-- | Nikodem     | Wójcik       | 5        |
-- +-------------+---------------+----------+
-- | Sara        | Lewandowska   | 6        |
-- +-------------+---------------+----------+
-- | Marcel      | Wójcik       | 8        |
-- +-------------+---------------+----------+
-- | Małgorzata | Jankowska     | 7        |
-- +-------------+---------------+----------+
-- | Liliana     | Wiśniewska   | 9        |
-- +-------------+---------------+----------+
-- | Stanisław  | Kowalski      | 8        |
-- +-------------+---------------+----------+
-- | Aniela      | Nowak         | 9        |
-- +-------------+---------------+----------+
-- | Marta       | Grabowska     | 10       |
-- +-------------+---------------+----------+
-- | Paulina     | Kowalska      | 7        |
-- +-------------+---------------+----------+
-- | Matylda     | Kowalska      | 9        |
-- +-------------+---------------+----------+
-- | Róża      | Dąbrowska    | 7        |
-- +-------------+---------------+----------+
-- | Marcel      | Wójcik       | 7        |
-- +-------------+---------------+----------+
-- | Matylda     | Grabowska     | 10       |
-- +-------------+---------------+----------+
-- | Nikodem     | Dąbrowski    | 7        |
-- +-------------+---------------+----------+
-- | Piotr       | Nowak         | 6        |
-- +-------------+---------------+----------+
-- | Liliana     | Woźniak      | 8        |
-- +-------------+---------------+----------+
-- | Stanisław  | Zieliński    | 12       |
-- +-------------+---------------+----------+
-- | Piotr       | Grabowski     | 9        |
-- +-------------+---------------+----------+
-- | Michał     | Szymański    | 6        |
-- +-------------+---------------+----------+
-- | Stanisław  | Kowalski      | 12       |
-- +-------------+---------------+----------+
-- | Adam        | Woźniak      | 10       |
-- +-------------+---------------+----------+
-- | Katarzyna   | Lewandowska   | 6        |
-- +-------------+---------------+----------+
-- | Sara        | Wójcik       | 9        |
-- +-------------+---------------+----------+
-- | Aniela      | Kozłowska    | 7        |
-- +-------------+---------------+----------+
-- | Mateusz     | Kowalski      | 6        |
-- +-------------+---------------+----------+
-- | Igor        | Kowalczyk     | 13       |
-- +-------------+---------------+----------+
-- | Leon        | Kamiński     | 2        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Szymańska    | 7        |
-- +-------------+---------------+----------+
-- | Róża      | Kowalska      | 12       |
-- +-------------+---------------+----------+
-- | Marta       | Wojciechowska | 4        |
-- +-------------+---------------+----------+
-- | Małgorzata | Kwiatkowska   | 11       |
-- +-------------+---------------+----------+
-- | Joanna      | Jankowska     | 4        |
-- +-------------+---------------+----------+
-- | Aniela      | Lewandowska   | 15       |
-- +-------------+---------------+----------+
-- | Igor        | Wójcik       | 5        |
-- +-------------+---------------+----------+
-- | Klaudia     | Wojciechowska | 5        |
-- +-------------+---------------+----------+
-- | Marta       | Kaczmarek     | 10       |
-- +-------------+---------------+----------+
-- | Nikodem     | Krawczyk      | 7        |
-- +-------------+---------------+----------+
-- | Klaudia     | Kozłowska    | 7        |
-- +-------------+---------------+----------+
-- | Izabela     | Zielińska    | 10       |
-- +-------------+---------------+----------+
-- | Nikodem     | Jankowski     | 7        |
-- +-------------+---------------+----------+
-- | Adam        | Mazur         | 6        |
-- +-------------+---------------+----------+
-- | Matylda     | Kaczmarek     | 8        |
-- +-------------+---------------+----------+
-- | Igor        | Wójcik       | 8        |
-- +-------------+---------------+----------+
-- | Leon        | Szymański    | 8        |
-- +-------------+---------------+----------+
-- | Igor        | Szymański    | 9        |
-- +-------------+---------------+----------+
-- | Paulina     | Krawczyk      | 8        |
-- +-------------+---------------+----------+
-- | Marta       | Krawczyk      | 9        |
-- +-------------+---------------+----------+
-- | Mateusz     | Kaczmarek     | 9        |
-- +-------------+---------------+----------+
-- | Stanisław  | Lewandowski   | 6        |
-- +-------------+---------------+----------+
-- | Adam        | Nowak         | 5        |
-- +-------------+---------------+----------+
-- | Sara        | Lewandowska   | 6        |
-- +-------------+---------------+----------+
-- | Piotr       | Kozłowski    | 8        |
-- +-------------+---------------+----------+
-- | Nikodem     | Dąbrowski    | 4        |
-- +-------------+---------------+----------+
-- | Nikodem     | Kaczmarek     | 12       |
-- +-------------+---------------+----------+
-- | Joanna      | Kwiatkowska   | 8        |
-- +-------------+---------------+----------+
-- | Piotr       | Kamiński     | 12       |
-- +-------------+---------------+----------+
-- | Igor        | Mazur         | 7        |
-- +-------------+---------------+----------+
-- | Wiktor      | Wojciechowski | 7        |
-- +-------------+---------------+----------+
-- | Róża      | Szymańska    | 4        |
-- +-------------+---------------+----------+
-- | Małgorzata | Dąbrowska    | 9        |
-- +-------------+---------------+----------+
-- | Izabela     | Grabowska     | 9        |
-- +-------------+---------------+----------+
-- | Marcel      | Lewandowski   | 5        |
-- +-------------+---------------+----------+
-- | Małgorzata | Krawczyk      | 4        |
-- +-------------+---------------+----------+
-- | Izabela     | Wójcik       | 12       |
-- +-------------+---------------+----------+
-- | Stanisław  | Kowalski      | 5        |
-- +-------------+---------------+----------+
-- | Wiktor      | Wójcik       | 7        |
-- +-------------+---------------+----------+
-- | Wiktor      | Nowak         | 9        |
-- +-------------+---------------+----------+
-- | Matylda     | Kwiatkowska   | 5        |
-- +-------------+---------------+----------+
-- | Paulina     | Jankowska     | 9        |
-- +-------------+---------------+----------+
-- | Adam        | Mazur         | 10       |
-- +-------------+---------------+----------+
-- | Nikodem     | Wójcik       | 8        |
-- +-------------+---------------+----------+
-- | Mateusz     | Nowak         | 7        |
-- +-------------+---------------+----------+
-- | Igor        | Wójcik       | 6        |
-- +-------------+---------------+----------+
-- | Klaudia     | Lewandowska   | 10       |
-- +-------------+---------------+----------+
-- | Małgorzata | Szymańska    | 12       |
-- +-------------+---------------+----------+
-- | Klaudia     | Woźniak      | 6        |
-- +-------------+---------------+----------+
-- | Piotr       | Woźniak      | 9        |
-- +-------------+---------------+----------+
-- | Stanisław  | Wójcik       | 8        |
-- +-------------+---------------+----------+
-- | Paulina     | Jankowska     | 6        |
-- +-------------+---------------+----------+
-- | Piotr       | Kowalczyk     | 11       |
-- +-------------+---------------+----------+
-- | Adam        | Wójcik       | 8        |
-- +-------------+---------------+----------+
-- | Michał     | Kowalczyk     | 7        |
-- +-------------+---------------+----------+
-- | Michał     | Kozłowski    | 10       |
-- +-------------+---------------+----------+
-- | Matylda     | Mazur         | 13       |
-- +-------------+---------------+----------+
-- | Katarzyna   | Wiśniewska   | 7        |
-- +-------------+---------------+----------+
-- | Joanna      | Jankowska     | 7        |
-- +-------------+---------------+----------+
-- | Róża      | Szymańska    | 13       |
-- +-------------+---------------+----------+
-- | Piotr       | Dąbrowski    | 3        |
-- +-------------+---------------+----------+
-- | Małgorzata | Kaczmarek     | 14       |
-- +-------------+---------------+----------+
-- | Marcel      | Mazur         | 8        |
-- +-------------+---------------+----------+
-- | Marcel      | Lewandowski   | 12       |
-- +-------------+---------------+----------+
-- | Adam        | Kozłowski    | 4        |
-- +-------------+---------------+----------+
-- | Leon        | Kaczmarek     | 9        |
-- +-------------+---------------+----------+
-- | Klaudia     | Szymańska    | 10       |
-- +-------------+---------------+----------+
-- | Liliana     | Grabowska     | 8        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Mazur         | 7        |
-- +-------------+---------------+----------+
-- | Mateusz     | Szymański    | 9        |
-- +-------------+---------------+----------+
-- | Klaudia     | Nowak         | 7        |
-- +-------------+---------------+----------+
-- | Piotr       | Grabowski     | 5        |
-- +-------------+---------------+----------+
-- | Marta       | Woźniak      | 8        |
-- +-------------+---------------+----------+
-- | Sara        | Nowak         | 6        |
-- +-------------+---------------+----------+
-- | Wiktor      | Piotrowski    | 8        |
-- +-------------+---------------+----------+
-- | Liliana     | Grabowska     | 5        |
-- +-------------+---------------+----------+
-- | Joanna      | Kwiatkowska   | 13       |
-- +-------------+---------------+----------+
-- | Matylda     | Zielińska    | 5        |
-- +-------------+---------------+----------+
-- | Mateusz     | Mazur         | 4        |
-- +-------------+---------------+----------+
-- | Leon        | Lewandowski   | 7        |
-- +-------------+---------------+----------+
-- | Adam        | Dąbrowski    | 7        |
-- +-------------+---------------+----------+
-- | Joanna      | Wojciechowska | 9        |
-- +-------------+---------------+----------+
-- | Wiktor      | Kozłowski    | 6        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Kozłowska    | 5        |
-- +-------------+---------------+----------+
-- | Paulina     | Jankowska     | 9        |
-- +-------------+---------------+----------+
-- | Adam        | Krawczyk      | 7        |
-- +-------------+---------------+----------+
-- | Róża      | Woźniak      | 9        |
-- +-------------+---------------+----------+
-- | Michał     | Zieliński    | 10       |
-- +-------------+---------------+----------+
-- | Aniela      | Kaczmarek     | 13       |
-- +-------------+---------------+----------+
-- | Matylda     | Kaczmarek     | 9        |
-- +-------------+---------------+----------+
-- | Klaudia     | Kamińska     | 4        |
-- +-------------+---------------+----------+
-- | Piotr       | Kaczmarek     | 8        |
-- +-------------+---------------+----------+
-- | Wiktor      | Mazur         | 7        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Dąbrowska    | 2        |
-- +-------------+---------------+----------+
-- | Klaudia     | Kowalska      | 8        |
-- +-------------+---------------+----------+
-- | Klaudia     | Szymańska    | 10       |
-- +-------------+---------------+----------+
-- | Wiktor      | Wójcik       | 10       |
-- +-------------+---------------+----------+
-- | Klaudia     | Grabowska     | 10       |
-- +-------------+---------------+----------+
-- | Małgorzata | Woźniak      | 9        |
-- +-------------+---------------+----------+
-- | Klaudia     | Piotrowska    | 6        |
-- +-------------+---------------+----------+
-- | Stanisław  | Kozłowski    | 10       |
-- +-------------+---------------+----------+
-- | Joanna      | Mazur         | 6        |
-- +-------------+---------------+----------+
-- | Adam        | Nowak         | 6        |
-- +-------------+---------------+----------+
-- | Małgorzata | Wiśniewska   | 7        |
-- +-------------+---------------+----------+
-- | Joanna      | Kozłowska    | 8        |
-- +-------------+---------------+----------+
-- | Piotr       | Kowalski      | 10       |
-- +-------------+---------------+----------+
-- | Marcel      | Jankowski     | 7        |
-- +-------------+---------------+----------+
-- | Marta       | Lewandowska   | 7        |
-- +-------------+---------------+----------+
-- | Paulina     | Kozłowska    | 8        |
-- +-------------+---------------+----------+
-- | Joanna      | Kaczmarek     | 10       |
-- +-------------+---------------+----------+
-- | Mateusz     | Nowak         | 10       |
-- +-------------+---------------+----------+
-- | Klaudia     | Dąbrowska    | 11       |
-- +-------------+---------------+----------+
-- | Klaudia     | Grabowska     | 5        |
-- +-------------+---------------+----------+
-- | Marta       | Kwiatkowska   | 9        |
-- +-------------+---------------+----------+
-- | Nikodem     | Krawczyk      | 7        |
-- +-------------+---------------+----------+
-- | Michał     | Kaczmarek     | 8        |
-- +-------------+---------------+----------+
-- | Klaudia     | Wójcik       | 12       |
-- +-------------+---------------+----------+
-- | Igor        | Dąbrowski    | 8        |
-- +-------------+---------------+----------+
-- | Michał     | Kaczmarek     | 8        |
-- +-------------+---------------+----------+
-- | Aniela      | Kowalczyk     | 6        |
-- +-------------+---------------+----------+
-- | Izabela     | Wójcik       | 11       |
-- +-------------+---------------+----------+
-- | Piotr       | Lewandowski   | 18       |
-- +-------------+---------------+----------+
-- | Izabela     | Kaczmarek     | 10       |
-- +-------------+---------------+----------+
-- | Leon        | Nowak         | 7        |
-- +-------------+---------------+----------+
-- | Michał     | Kwiatkowski   | 11       |
-- +-------------+---------------+----------+
-- | Małgorzata | Wiśniewska   | 7        |
-- +-------------+---------------+----------+
-- | Katarzyna   | Mazur         | 9        |
-- +-------------+---------------+----------+
-- | Nikodem     | Nowak         | 3        |
-- +-------------+---------------+----------+
-- | Małgorzata | Kaczmarek     | 5        |
-- +-------------+---------------+----------+
-- | Małgorzata | Lewandowska   | 7        |
-- +-------------+---------------+----------+
-- | Małgorzata | Grabowska     | 6        |
-- +-------------+---------------+----------+

-- %% [markdown]
-- Na wyniku tego zapytania możemy wykonać kolejne zapytanie, by otrzymać listę użytkowników, którzy pożyczyli więcej niż 10 książek.

-- %% [markdown]
-- Zapytanie i wynik zapytania:

-- %%
SELECT * FROM
(
    SELECT users.name, users.surname, COUNT(borrowings.ID) AS activity FROM users JOIN borrowings
    ON users.ID=borrowings.user_id GROUP BY users.ID
)
WHERE activity>10;
-- Out:
-- +-------------+---------------+----------+
-- | name        | surname       | activity |
-- +-------------+---------------+----------+
-- | Paulina     | Wojciechowska | 13       |
-- +-------------+---------------+----------+
-- | Marcel      | Kamiński     | 11       |
-- +-------------+---------------+----------+
-- | Małgorzata | Piotrowska    | 13       |
-- +-------------+---------------+----------+
-- | Róża      | Dąbrowska    | 14       |
-- +-------------+---------------+----------+
-- | Sara        | Kaczmarek     | 14       |
-- +-------------+---------------+----------+
-- | Adam        | Kowalczyk     | 13       |
-- +-------------+---------------+----------+
-- | Aniela      | Dąbrowska    | 13       |
-- +-------------+---------------+----------+
-- | Katarzyna   | Krawczyk      | 14       |
-- +-------------+---------------+----------+
-- | Stanisław  | Wójcik       | 13       |
-- +-------------+---------------+----------+
-- | Piotr       | Szymański    | 12       |
-- +-------------+---------------+----------+
-- | Leon        | Kamiński     | 11       |
-- +-------------+---------------+----------+
-- | Liliana     | Wójcik       | 13       |
-- +-------------+---------------+----------+
-- | Róża      | Kowalska      | 11       |
-- +-------------+---------------+----------+
-- | Aniela      | Nowak         | 14       |
-- +-------------+---------------+----------+
-- | Joanna      | Piotrowska    | 11       |
-- +-------------+---------------+----------+
-- | Piotr       | Piotrowski    | 14       |
-- +-------------+---------------+----------+
-- | Stanisław  | Zieliński    | 12       |
-- +-------------+---------------+----------+
-- | Stanisław  | Kowalski      | 12       |
-- +-------------+---------------+----------+
-- | Igor        | Kowalczyk     | 13       |
-- +-------------+---------------+----------+
-- | Róża      | Kowalska      | 12       |
-- +-------------+---------------+----------+
-- | Małgorzata | Kwiatkowska   | 11       |
-- +-------------+---------------+----------+
-- | Aniela      | Lewandowska   | 15       |
-- +-------------+---------------+----------+
-- | Nikodem     | Kaczmarek     | 12       |
-- +-------------+---------------+----------+
-- | Piotr       | Kamiński     | 12       |
-- +-------------+---------------+----------+
-- | Izabela     | Wójcik       | 12       |
-- +-------------+---------------+----------+
-- | Małgorzata | Szymańska    | 12       |
-- +-------------+---------------+----------+
-- | Piotr       | Kowalczyk     | 11       |
-- +-------------+---------------+----------+
-- | Matylda     | Mazur         | 13       |
-- +-------------+---------------+----------+
-- | Róża      | Szymańska    | 13       |
-- +-------------+---------------+----------+
-- | Małgorzata | Kaczmarek     | 14       |
-- +-------------+---------------+----------+
-- | Marcel      | Lewandowski   | 12       |
-- +-------------+---------------+----------+
-- | Joanna      | Kwiatkowska   | 13       |
-- +-------------+---------------+----------+
-- | Aniela      | Kaczmarek     | 13       |
-- +-------------+---------------+----------+
-- | Klaudia     | Dąbrowska    | 11       |
-- +-------------+---------------+----------+
-- | Klaudia     | Wójcik       | 12       |
-- +-------------+---------------+----------+
-- | Izabela     | Wójcik       | 11       |
-- +-------------+---------------+----------+
-- | Piotr       | Lewandowski   | 18       |
-- +-------------+---------------+----------+
-- | Michał     | Kwiatkowski   | 11       |
-- +-------------+---------------+----------+

-- %% [markdown]
-- ### Podzapytania w `WHERE`

-- %% [markdown]
-- #### Przykład
--
-- **Zapytania zwracające w wyniku pojedynczą wartość możemy użyć np. w wyrażeniach warunkowych (`WHERE`, `HAVING`). Mając zapytanie o średnią liczbę wypożyczeń dokonanych przez użytkownika.**

-- %% [markdown]
-- Tabela **`Borrowings`**:

-- %%
SELECT * FROM borrowings;
-- Out:
-- +------+---------+---------+-------------+-------------+
-- | ID   | user_id | book_id | borrow_date | return_date |
-- +------+---------+---------+-------------+-------------+
-- | 0    | 129     | 621     | 2017-09-05  | 2017-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1    | 192     | 284     | 2011-01-26  | 2011-01-31  |
-- +------+---------+---------+-------------+-------------+
-- | 2    | 235     | 160     | 1995-12-18  | 1995-12-27  |
-- +------+---------+---------+-------------+-------------+
-- | 3    | 96      | 308     | 2018-07-02  | 2018-07-19  |
-- +------+---------+---------+-------------+-------------+
-- | 4    | 195     | 180     | 2017-07-11  | 2017-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 5    | 171     | 378     | 2015-06-19  | 2015-06-29  |
-- +------+---------+---------+-------------+-------------+
-- | 6    | 94      | 359     | 2012-04-23  | 2012-05-04  |
-- +------+---------+---------+-------------+-------------+
-- | 7    | 8       | 593     | 2001-05-31  | 2001-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 8    | 223     | 37      | 2010-03-06  | 2010-04-03  |
-- +------+---------+---------+-------------+-------------+
-- | 9    | 203     | 248     | 1996-03-20  | 1996-03-26  |
-- +------+---------+---------+-------------+-------------+
-- | 10   | 150     | 471     | 2000-09-13  | 2000-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 11   | 46      | 82      | 2009-02-27  | 2009-03-06  |
-- +------+---------+---------+-------------+-------------+
-- | 12   | 199     | 626     | 1995-06-12  | 1995-06-19  |
-- +------+---------+---------+-------------+-------------+
-- | 13   | 110     | 560     | 2011-01-30  | 2011-02-23  |
-- +------+---------+---------+-------------+-------------+
-- | 14   | 203     | 617     | 1996-03-20  | 1996-04-12  |
-- +------+---------+---------+-------------+-------------+
-- | 15   | 238     | 607     | 2013-10-11  | 2013-10-25  |
-- +------+---------+---------+-------------+-------------+
-- | 16   | 117     | 272     | 2011-01-13  | 2011-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 17   | 87      | 583     | 2004-01-19  | 2004-01-23  |
-- +------+---------+---------+-------------+-------------+
-- | 18   | 16      | 1       | 2002-01-30  | 2002-02-04  |
-- +------+---------+---------+-------------+-------------+
-- | 19   | 25      | 477     | 2003-06-09  | 2003-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 20   | 26      | 215     | 2004-07-16  | 2004-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 21   | 238     | 45      | 2013-10-11  | 2013-10-16  |
-- +------+---------+---------+-------------+-------------+
-- | 22   | 28      | 222     | 2017-08-24  | 2017-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 23   | 176     | 377     | 2007-08-12  | 2007-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 24   | 114     | 403     | 1997-04-04  | 1997-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 25   | 80      | 578     | 2001-08-27  | 2001-09-16  |
-- +------+---------+---------+-------------+-------------+
-- | 26   | 133     | 313     | 2011-10-17  | 2011-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 27   | 2       | 418     | 1999-08-09  | 1999-08-27  |
-- +------+---------+---------+-------------+-------------+
-- | 28   | 8       | 498     | 2007-01-12  | 2007-02-07  |
-- +------+---------+---------+-------------+-------------+
-- | 29   | 66      | 200     | 1990-12-27  | 1991-01-06  |
-- +------+---------+---------+-------------+-------------+
-- | 30   | 42      | 265     | 2007-01-15  | 2007-01-30  |
-- +------+---------+---------+-------------+-------------+
-- | 31   | 79      | 116     | 2017-08-20  | 2017-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 32   | 199     | 610     | 1995-06-12  | 1995-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 33   | 60      | 142     | 2012-10-02  | 2012-10-02  |
-- +------+---------+---------+-------------+-------------+
-- | 34   | 233     | 60      | 2012-10-11  | 2012-10-14  |
-- +------+---------+---------+-------------+-------------+
-- | 35   | 94      | 443     | 2012-04-23  | 2012-05-15  |
-- +------+---------+---------+-------------+-------------+
-- | 36   | 92      | 129     | 2016-05-06  | 2016-06-03  |
-- +------+---------+---------+-------------+-------------+
-- | 37   | 225     | 581     | 2012-09-23  | 2012-09-24  |
-- +------+---------+---------+-------------+-------------+
-- | 38   | 200     | 505     | 1993-09-08  | 1993-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 39   | 175     | 574     | 1998-09-02  | 1998-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 40   | 248     | 141     | 2017-11-06  | 2017-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 41   | 239     | 321     | 2010-10-02  | 2010-10-15  |
-- +------+---------+---------+-------------+-------------+
-- | 42   | 86      | 271     | 2003-11-08  | 2003-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 43   | 8       | 544     | 2001-05-31  | 2001-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 44   | 234     | 563     | 2016-12-12  | 2017-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 45   | 204     | 494     | 1994-11-10  | 1994-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 46   | 229     | 426     | 1991-06-21  | 1991-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 47   | 113     | 173     | 2017-03-21  | 2017-04-10  |
-- +------+---------+---------+-------------+-------------+
-- | 48   | 66      | 200     | 1990-12-27  | 1991-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 49   | 244     | 180     | 2004-07-06  | 2004-07-07  |
-- +------+---------+---------+-------------+-------------+
-- | 50   | 24      | 309     | 1999-01-19  | 1999-02-11  |
-- +------+---------+---------+-------------+-------------+
-- | 51   | 156     | 114     | 1998-03-13  | 1998-03-16  |
-- +------+---------+---------+-------------+-------------+
-- | 52   | 29      | 163     | 2017-09-08  | 2017-09-12  |
-- +------+---------+---------+-------------+-------------+
-- | 53   | 28      | 34      | 2017-08-20  | 2017-09-04  |
-- +------+---------+---------+-------------+-------------+
-- | 54   | 185     | 383     | 2015-06-02  | 2015-06-02  |
-- +------+---------+---------+-------------+-------------+
-- | 55   | 219     | 208     | 2017-10-04  | 2017-10-26  |
-- +------+---------+---------+-------------+-------------+
-- | 56   | 234     | 199     | 2009-02-15  | 2009-02-18  |
-- +------+---------+---------+-------------+-------------+
-- | 57   | 187     | 116     | 2008-11-22  | 2008-12-06  |
-- +------+---------+---------+-------------+-------------+
-- | 58   | 67      | 628     | 2009-10-23  | 2009-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 59   | 72      | 162     | 2012-12-17  | 2012-12-30  |
-- +------+---------+---------+-------------+-------------+
-- | 60   | 51      | 1       | 2002-01-30  | 2002-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 61   | 113     | 169     | 2017-04-02  | 2017-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 62   | 197     | 577     | 2011-04-19  | 2011-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 63   | 183     | 588     | 2015-12-23  | 2016-01-16  |
-- +------+---------+---------+-------------+-------------+
-- | 64   | 214     | 90      | 2015-12-07  | 2015-12-28  |
-- +------+---------+---------+-------------+-------------+
-- | 65   | 125     | 131     | 2017-08-14  | 2017-08-30  |
-- +------+---------+---------+-------------+-------------+
-- | 66   | 164     | 113     | 1999-11-10  | 1999-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 67   | 77      | 543     | 2017-12-15  | 2017-12-31  |
-- +------+---------+---------+-------------+-------------+
-- | 68   | 172     | 30      | 2003-05-31  | 2003-06-28  |
-- +------+---------+---------+-------------+-------------+
-- | 69   | 32      | 572     | 2012-07-22  | 2012-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 70   | 176     | 185     | 2007-08-12  | 2007-08-28  |
-- +------+---------+---------+-------------+-------------+
-- | 71   | 180     | 209     | 2017-09-14  | 2017-09-30  |
-- +------+---------+---------+-------------+-------------+
-- | 72   | 193     | 455     | 2012-09-24  | 2012-09-25  |
-- +------+---------+---------+-------------+-------------+
-- | 73   | 48      | 421     | 2013-06-25  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 74   | 222     | 485     | 2017-10-05  | 2017-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 75   | 155     | 399     | 2006-06-28  | 2006-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 76   | 60      | 277     | 2017-02-22  | 2017-03-04  |
-- +------+---------+---------+-------------+-------------+
-- | 77   | 53      | 633     | 1990-03-21  | 1990-03-24  |
-- +------+---------+---------+-------------+-------------+
-- | 78   | 120     | 167     | 1999-10-25  | 1999-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 79   | 152     | 167     | 1996-08-24  | 1996-09-19  |
-- +------+---------+---------+-------------+-------------+
-- | 80   | 135     | 325     | 2013-03-11  | 2013-03-30  |
-- +------+---------+---------+-------------+-------------+
-- | 81   | 2       | 569     | 2002-02-15  | 2002-03-01  |
-- +------+---------+---------+-------------+-------------+
-- | 82   | 129     | 167     | 2017-09-05  | 2017-09-26  |
-- +------+---------+---------+-------------+-------------+
-- | 83   | 142     | 530     | 2009-10-29  | 2009-11-18  |
-- +------+---------+---------+-------------+-------------+
-- | 84   | 67      | 49      | 2007-08-17  | 2009-02-13  |
-- +------+---------+---------+-------------+-------------+
-- | 85   | 121     | 593     | 2009-10-25  | 2009-11-10  |
-- +------+---------+---------+-------------+-------------+
-- | 86   | 230     | 308     | 2018-07-02  | 2018-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 87   | 171     | 514     | 2015-06-19  | 2015-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 88   | 118     | 58      | 2015-12-13  | 2015-12-26  |
-- +------+---------+---------+-------------+-------------+
-- | 89   | 131     | 446     | 1991-10-10  | 1991-10-17  |
-- +------+---------+---------+-------------+-------------+
-- | 90   | 95      | 3       | 2017-03-02  | 2017-03-27  |
-- +------+---------+---------+-------------+-------------+
-- | 91   | 109     | 541     | 2009-04-21  | 2009-05-07  |
-- +------+---------+---------+-------------+-------------+
-- | 92   | 231     | 151     | 2017-03-12  | 2017-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 93   | 202     | 402     | 2013-06-18  |             |
-- +------+---------+---------+-------------+-------------+
-- | 94   | 245     | 71      | 2006-06-13  | 2006-06-19  |
-- +------+---------+---------+-------------+-------------+
-- | 95   | 235     | 124     | 1996-04-02  | 1996-04-19  |
-- +------+---------+---------+-------------+-------------+
-- | 96   | 159     | 411     | 2001-01-18  | 2001-01-23  |
-- +------+---------+---------+-------------+-------------+
-- | 97   | 75      | 2       | 2013-04-17  | 2013-04-17  |
-- +------+---------+---------+-------------+-------------+
-- | 98   | 4       | 256     | 2018-06-23  | 2018-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 99   | 35      | 567     | 1992-04-28  | 1992-05-26  |
-- +------+---------+---------+-------------+-------------+
-- | 100  | 19      | 360     | 2001-07-05  | 2001-07-17  |
-- +------+---------+---------+-------------+-------------+
-- | 101  | 108     | 300     | 2000-11-24  | 2000-12-16  |
-- +------+---------+---------+-------------+-------------+
-- | 102  | 154     | 525     | 2006-10-08  | 2006-10-18  |
-- +------+---------+---------+-------------+-------------+
-- | 103  | 232     | 424     | 2005-03-03  | 2005-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 104  | 96      | 137     | 2014-03-22  | 2014-04-03  |
-- +------+---------+---------+-------------+-------------+
-- | 105  | 173     | 469     | 1996-07-10  | 1996-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 106  | 205     | 210     | 2001-02-27  | 2001-03-27  |
-- +------+---------+---------+-------------+-------------+
-- | 107  | 22      | 317     | 2007-11-18  | 2007-12-05  |
-- +------+---------+---------+-------------+-------------+
-- | 108  | 137     | 330     | 1998-04-23  | 1998-04-25  |
-- +------+---------+---------+-------------+-------------+
-- | 109  | 220     | 538     | 1997-01-24  | 1997-02-04  |
-- +------+---------+---------+-------------+-------------+
-- | 110  | 90      | 544     | 2009-08-09  | 2009-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 111  | 218     | 56      | 2006-05-17  | 2006-05-25  |
-- +------+---------+---------+-------------+-------------+
-- | 112  | 222     | 217     | 2010-11-04  | 2010-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 113  | 213     | 377     | 1998-10-28  | 1998-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 114  | 88      | 33      | 1990-07-04  | 1990-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 115  | 113     | 6       | 2017-03-21  | 2017-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 116  | 173     | 394     | 1996-07-10  | 1996-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 117  | 238     | 294     | 2013-10-11  | 2013-10-17  |
-- +------+---------+---------+-------------+-------------+
-- | 118  | 3       | 100     | 2011-01-22  | 2011-02-16  |
-- +------+---------+---------+-------------+-------------+
-- | 119  | 44      | 152     | 1992-10-24  | 1992-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 120  | 127     | 40      | 2006-07-26  | 2006-08-11  |
-- +------+---------+---------+-------------+-------------+
-- | 121  | 148     | 406     | 2008-10-03  | 2008-10-07  |
-- +------+---------+---------+-------------+-------------+
-- | 122  | 95      | 78      | 2012-11-27  | 2012-12-25  |
-- +------+---------+---------+-------------+-------------+
-- | 123  | 60      | 420     | 2013-05-11  | 2013-05-11  |
-- +------+---------+---------+-------------+-------------+
-- | 124  | 67      | 286     | 2016-06-03  | 2016-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 125  | 34      | 519     | 1991-04-27  | 1991-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 126  | 138     | 77      | 2009-04-03  | 2009-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 127  | 67      | 304     | 2007-08-17  | 2007-08-25  |
-- +------+---------+---------+-------------+-------------+
-- | 128  | 14      | 20      | 2013-07-10  | 2013-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 129  | 221     | 360     | 2015-09-11  | 2015-10-02  |
-- +------+---------+---------+-------------+-------------+
-- | 130  | 201     | 150     | 1999-04-23  | 1999-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 131  | 208     | 336     | 2012-02-23  | 2012-03-23  |
-- +------+---------+---------+-------------+-------------+
-- | 132  | 181     | 332     | 2012-02-03  | 2012-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 133  | 249     | 433     | 2005-07-20  | 2005-08-07  |
-- +------+---------+---------+-------------+-------------+
-- | 134  | 88      | 564     | 1990-07-04  | 1990-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 135  | 101     | 583     | 2002-07-04  | 2002-07-19  |
-- +------+---------+---------+-------------+-------------+
-- | 136  | 9       | 373     | 2013-03-07  | 2013-03-31  |
-- +------+---------+---------+-------------+-------------+
-- | 137  | 168     | 292     | 2004-10-18  | 2004-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 138  | 39      | 57      | 2012-11-13  | 2012-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 139  | 7       | 474     | 1991-10-03  | 1991-10-09  |
-- +------+---------+---------+-------------+-------------+
-- | 140  | 174     | 135     | 2015-07-03  | 2015-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 141  | 146     | 314     | 1992-11-29  | 1992-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 142  | 93      | 300     | 2011-10-10  | 2011-11-08  |
-- +------+---------+---------+-------------+-------------+
-- | 143  | 244     | 105     | 2004-07-06  | 2004-07-31  |
-- +------+---------+---------+-------------+-------------+
-- | 144  | 74      | 311     | 2003-10-04  | 2003-10-27  |
-- +------+---------+---------+-------------+-------------+
-- | 145  | 186     | 298     | 2013-07-06  | 2013-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 146  | 157     | 366     | 2016-11-09  | 2016-11-30  |
-- +------+---------+---------+-------------+-------------+
-- | 147  | 101     | 618     | 2002-07-04  | 2002-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 148  | 215     | 448     | 2015-11-06  | 2015-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 149  | 11      | 633     | 1996-08-08  | 1996-08-25  |
-- +------+---------+---------+-------------+-------------+
-- | 150  | 60      | 322     | 2012-10-02  | 2012-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 151  | 155     | 50      | 2006-06-28  | 2006-07-20  |
-- +------+---------+---------+-------------+-------------+
-- | 152  | 246     | 68      | 1991-11-02  | 1991-11-19  |
-- +------+---------+---------+-------------+-------------+
-- | 153  | 189     | 355     | 2006-02-21  | 2006-03-17  |
-- +------+---------+---------+-------------+-------------+
-- | 154  | 159     | 197     | 1991-05-15  | 1991-06-01  |
-- +------+---------+---------+-------------+-------------+
-- | 155  | 8       | 430     | 2001-05-31  | 2001-06-24  |
-- +------+---------+---------+-------------+-------------+
-- | 156  | 103     | 155     | 2006-01-03  | 2006-01-31  |
-- +------+---------+---------+-------------+-------------+
-- | 157  | 229     | 529     | 1991-06-21  | 1991-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 158  | 230     | 119     | 2008-02-20  | 2008-03-04  |
-- +------+---------+---------+-------------+-------------+
-- | 159  | 80      | 452     | 1995-11-25  | 1995-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 160  | 34      | 228     | 2014-06-24  | 2014-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 161  | 91      | 95      | 2013-07-06  | 2013-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 162  | 34      | 133     | 2017-06-10  | 2017-06-26  |
-- +------+---------+---------+-------------+-------------+
-- | 163  | 123     | 337     | 2009-11-05  | 2009-11-13  |
-- +------+---------+---------+-------------+-------------+
-- | 164  | 57      | 92      | 2017-11-20  | 2017-12-02  |
-- +------+---------+---------+-------------+-------------+
-- | 165  | 120     | 227     | 2010-03-11  | 2010-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 166  | 128     | 189     | 2017-03-04  | 2017-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 167  | 37      | 327     | 2005-10-09  | 2005-10-13  |
-- +------+---------+---------+-------------+-------------+
-- | 168  | 138     | 287     | 2009-04-03  | 2009-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 169  | 93      | 115     | 2011-10-10  | 2011-11-07  |
-- +------+---------+---------+-------------+-------------+
-- | 170  | 125     | 178     | 2017-08-14  | 2017-08-28  |
-- +------+---------+---------+-------------+-------------+
-- | 171  | 218     | 327     | 2006-05-17  | 2006-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 172  | 119     | 85      | 2008-11-04  | 2008-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 173  | 5       | 566     | 2013-06-16  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 174  | 187     | 84      | 2008-11-22  | 2008-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 175  | 137     | 634     | 2015-11-13  | 2015-12-10  |
-- +------+---------+---------+-------------+-------------+
-- | 176  | 194     | 415     | 2017-05-11  | 2017-05-27  |
-- +------+---------+---------+-------------+-------------+
-- | 177  | 156     | 532     | 2006-02-01  | 2006-02-11  |
-- +------+---------+---------+-------------+-------------+
-- | 178  | 85      | 323     | 2009-12-30  | 2010-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 179  | 100     | 268     | 2007-11-07  | 2007-12-04  |
-- +------+---------+---------+-------------+-------------+
-- | 180  | 169     | 457     | 2017-01-01  | 2017-01-18  |
-- +------+---------+---------+-------------+-------------+
-- | 181  | 42      | 61      | 2007-01-15  | 2007-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 182  | 103     | 465     | 2006-01-03  | 2006-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 183  | 128     | 520     | 2017-03-04  | 2017-04-02  |
-- +------+---------+---------+-------------+-------------+
-- | 184  | 230     | 223     | 1994-02-13  | 1994-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 185  | 221     | 505     | 2015-09-11  | 2015-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 186  | 177     | 613     | 2003-05-04  | 2003-05-16  |
-- +------+---------+---------+-------------+-------------+
-- | 187  | 3       | 507     | 2011-01-22  | 2011-02-08  |
-- +------+---------+---------+-------------+-------------+
-- | 188  | 78      | 303     | 2010-12-13  | 2011-01-02  |
-- +------+---------+---------+-------------+-------------+
-- | 189  | 190     | 287     | 2005-08-22  | 2005-08-22  |
-- +------+---------+---------+-------------+-------------+
-- | 190  | 155     | 532     | 2006-06-28  | 2006-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 191  | 153     | 259     | 2012-12-30  | 2013-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 192  | 69      | 77      | 2007-06-26  | 2007-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 193  | 8       | 424     | 2005-03-03  | 2005-03-23  |
-- +------+---------+---------+-------------+-------------+
-- | 194  | 196     | 44      | 2018-07-19  | 2018-07-31  |
-- +------+---------+---------+-------------+-------------+
-- | 195  | 147     | 271     | 2008-02-29  | 2008-03-02  |
-- +------+---------+---------+-------------+-------------+
-- | 196  | 109     | 219     | 2016-10-16  | 2016-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 197  | 91      | 324     | 2013-07-06  | 2013-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 198  | 184     | 182     | 2018-02-03  | 2018-02-22  |
-- +------+---------+---------+-------------+-------------+
-- | 199  | 230     | 298     | 1994-02-13  | 1994-02-23  |
-- +------+---------+---------+-------------+-------------+
-- | 200  | 36      | 588     | 2010-10-26  | 2010-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 201  | 227     | 416     | 1997-09-22  | 1997-10-20  |
-- +------+---------+---------+-------------+-------------+
-- | 202  | 220     | 536     | 1996-08-31  | 1996-09-03  |
-- +------+---------+---------+-------------+-------------+
-- | 203  | 46      | 404     | 2009-02-27  | 2009-03-16  |
-- +------+---------+---------+-------------+-------------+
-- | 204  | 21      | 516     | 2006-06-16  | 2006-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 205  | 213     | 554     | 1998-10-28  | 1998-11-18  |
-- +------+---------+---------+-------------+-------------+
-- | 206  | 232     | 222     | 2017-08-24  | 2017-09-10  |
-- +------+---------+---------+-------------+-------------+
-- | 207  | 170     | 530     | 2011-11-26  | 2011-12-25  |
-- +------+---------+---------+-------------+-------------+
-- | 208  | 163     | 416     | 1994-08-18  | 1994-08-24  |
-- +------+---------+---------+-------------+-------------+
-- | 209  | 21      | 188     | 2004-03-18  | 2004-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 210  | 143     | 593     | 2010-03-05  | 2010-03-14  |
-- +------+---------+---------+-------------+-------------+
-- | 211  | 30      | 250     | 2016-10-24  | 2016-11-04  |
-- +------+---------+---------+-------------+-------------+
-- | 212  | 163     | 417     | 2006-01-12  | 2006-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 213  | 167     | 83      | 1993-07-04  | 1993-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 214  | 199     | 597     | 2007-08-07  | 2007-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 215  | 162     | 5       | 2018-08-04  | 2018-08-20  |
-- +------+---------+---------+-------------+-------------+
-- | 216  | 70      | 483     | 2006-06-25  | 2006-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 217  | 162     | 628     | 2009-10-23  | 2009-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 218  | 129     | 51      | 2017-09-05  |             |
-- +------+---------+---------+-------------+-------------+
-- | 219  | 130     | 619     | 2017-06-19  | 2017-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 220  | 99      | 198     | 2004-05-10  | 2004-06-06  |
-- +------+---------+---------+-------------+-------------+
-- | 221  | 39      | 463     | 2012-11-13  | 2012-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 222  | 119     | 245     | 2008-11-04  | 2008-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 223  | 145     | 339     | 2005-05-09  | 2005-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 224  | 193     | 295     | 2006-12-18  | 2007-01-06  |
-- +------+---------+---------+-------------+-------------+
-- | 225  | 148     | 601     | 1998-10-16  | 1998-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 226  | 205     | 329     | 2000-06-15  | 2000-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 227  | 36      | 423     | 1992-03-16  | 1992-04-06  |
-- +------+---------+---------+-------------+-------------+
-- | 228  | 24      | 173     | 1999-01-19  | 1999-01-25  |
-- +------+---------+---------+-------------+-------------+
-- | 229  | 205     | 529     | 1991-12-28  | 1992-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 230  | 163     | 35      | 1994-08-18  | 1994-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 231  | 144     | 540     | 1998-04-01  | 1998-04-26  |
-- +------+---------+---------+-------------+-------------+
-- | 232  | 224     | 122     | 2018-04-22  | 2018-05-03  |
-- +------+---------+---------+-------------+-------------+
-- | 233  | 20      | 130     | 2010-03-31  | 2010-04-04  |
-- +------+---------+---------+-------------+-------------+
-- | 234  | 126     | 331     | 2001-10-14  | 2001-10-14  |
-- +------+---------+---------+-------------+-------------+
-- | 235  | 159     | 219     | 2016-10-16  | 2016-10-20  |
-- +------+---------+---------+-------------+-------------+
-- | 236  | 19      | 607     | 2006-01-06  | 2006-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 237  | 209     | 563     | 2016-12-12  | 2017-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 238  | 168     | 399     | 2004-10-18  | 2004-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 239  | 8       | 476     | 2001-05-31  | 2001-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 240  | 238     | 578     | 2013-10-11  | 2013-11-05  |
-- +------+---------+---------+-------------+-------------+
-- | 241  | 80      | 291     | 1995-11-25  | 1995-12-18  |
-- +------+---------+---------+-------------+-------------+
-- | 242  | 31      | 468     | 2001-10-18  | 2001-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 243  | 72      | 498     | 2012-12-17  | 2012-12-22  |
-- +------+---------+---------+-------------+-------------+
-- | 244  | 205     | 203     | 2017-12-24  | 2018-01-09  |
-- +------+---------+---------+-------------+-------------+
-- | 245  | 2       | 481     | 1999-08-09  | 1999-09-04  |
-- +------+---------+---------+-------------+-------------+
-- | 246  | 173     | 228     | 2014-06-24  | 2014-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 247  | 248     | 310     | 2006-01-21  | 2006-01-30  |
-- +------+---------+---------+-------------+-------------+
-- | 248  | 144     | 59      | 1998-04-01  | 1998-04-18  |
-- +------+---------+---------+-------------+-------------+
-- | 249  | 245     | 289     | 2006-06-13  | 2006-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 250  | 67      | 628     | 2009-10-23  | 2009-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 251  | 45      | 98      | 2017-01-14  | 2017-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 252  | 237     | 505     | 2016-10-16  | 2016-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 253  | 117     | 627     | 2011-01-13  | 2011-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 254  | 123     | 561     | 2009-11-05  | 2009-11-17  |
-- +------+---------+---------+-------------+-------------+
-- | 255  | 119     | 216     | 2008-11-04  | 2008-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 256  | 22      | 460     | 2007-11-18  | 2007-11-30  |
-- +------+---------+---------+-------------+-------------+
-- | 257  | 32      | 6       | 2012-07-22  | 2012-08-09  |
-- +------+---------+---------+-------------+-------------+
-- | 258  | 139     | 496     | 2016-05-30  | 2016-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 259  | 55      | 336     | 2014-03-05  | 2014-03-19  |
-- +------+---------+---------+-------------+-------------+
-- | 260  | 219     | 26      | 2017-10-04  | 2017-10-21  |
-- +------+---------+---------+-------------+-------------+
-- | 261  | 191     | 197     | 2015-11-28  | 2015-12-07  |
-- +------+---------+---------+-------------+-------------+
-- | 262  | 166     | 341     | 2005-06-05  | 2005-07-01  |
-- +------+---------+---------+-------------+-------------+
-- | 263  | 69      | 585     | 2007-06-26  | 2007-07-07  |
-- +------+---------+---------+-------------+-------------+
-- | 264  | 48      | 481     | 2013-06-25  | 2013-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 265  | 105     | 15      | 2005-06-13  | 2005-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 266  | 120     | 356     | 1999-10-25  | 1999-10-29  |
-- +------+---------+---------+-------------+-------------+
-- | 267  | 91      | 606     | 2013-07-06  | 2013-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 268  | 196     | 228     | 2014-06-24  | 2014-06-29  |
-- +------+---------+---------+-------------+-------------+
-- | 269  | 84      | 244     | 2010-04-05  | 2010-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 270  | 73      | 48      | 2013-06-30  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 271  | 178     | 52      | 2017-01-09  | 2017-02-06  |
-- +------+---------+---------+-------------+-------------+
-- | 272  | 35      | 108     | 2005-02-26  | 2005-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 273  | 158     | 387     | 2007-04-25  | 2007-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 274  | 165     | 260     | 2016-09-05  | 2016-09-30  |
-- +------+---------+---------+-------------+-------------+
-- | 275  | 61      | 56      | 2015-10-14  | 2015-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 276  | 199     | 316     | 1995-06-29  | 1995-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 277  | 23      | 141     | 2017-11-06  | 2017-11-24  |
-- +------+---------+---------+-------------+-------------+
-- | 278  | 188     | 362     | 1994-07-14  | 1994-08-12  |
-- +------+---------+---------+-------------+-------------+
-- | 279  | 147     | 221     | 2008-02-29  | 2008-03-28  |
-- +------+---------+---------+-------------+-------------+
-- | 280  | 109     | 575     | 2009-04-21  | 2009-05-12  |
-- +------+---------+---------+-------------+-------------+
-- | 281  | 92      | 626     | 2016-05-06  | 2016-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 282  | 215     | 617     | 2009-11-07  | 2009-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 283  | 155     | 4       | 2006-06-28  | 2006-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 284  | 71      | 332     | 2014-06-27  | 2014-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 285  | 12      | 147     | 2007-04-08  | 2007-04-24  |
-- +------+---------+---------+-------------+-------------+
-- | 286  | 185     | 305     | 2015-06-02  | 2015-06-30  |
-- +------+---------+---------+-------------+-------------+
-- | 287  | 66      | 521     | 2006-05-22  | 2006-06-15  |
-- +------+---------+---------+-------------+-------------+
-- | 288  | 138     | 372     | 2015-09-25  | 2015-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 289  | 14      | 530     | 2013-07-10  | 2013-07-27  |
-- +------+---------+---------+-------------+-------------+
-- | 290  | 38      | 275     | 2006-09-01  | 2006-09-29  |
-- +------+---------+---------+-------------+-------------+
-- | 291  | 52      | 441     | 2006-06-17  | 2006-07-03  |
-- +------+---------+---------+-------------+-------------+
-- | 292  | 34      | 357     | 1991-04-27  | 1991-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 293  | 20      | 605     | 2010-03-31  | 2010-04-15  |
-- +------+---------+---------+-------------+-------------+
-- | 294  | 71      | 14      | 2014-06-27  | 2014-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 295  | 40      | 260     | 2016-09-05  | 2016-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 296  | 53      | 299     | 1990-03-21  | 1990-04-19  |
-- +------+---------+---------+-------------+-------------+
-- | 297  | 208     | 293     | 2012-02-23  | 2012-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 298  | 245     | 376     | 2006-06-13  | 2006-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 299  | 164     | 138     | 1999-11-10  | 1999-11-29  |
-- +------+---------+---------+-------------+-------------+
-- | 300  | 64      | 626     | 1990-12-22  | 1991-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 301  | 121     | 468     | 2009-10-25  | 2009-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 302  | 17      | 616     | 2000-04-21  | 2000-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 303  | 181     | 523     | 2015-06-12  | 2015-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 304  | 26      | 106     | 2004-07-16  | 2004-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 305  | 57      | 440     | 1992-03-01  | 1992-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 306  | 242     | 58      | 2015-12-13  | 2015-12-21  |
-- +------+---------+---------+-------------+-------------+
-- | 307  | 203     | 247     | 1996-03-20  | 1996-04-17  |
-- +------+---------+---------+-------------+-------------+
-- | 308  | 221     | 55      | 2015-09-11  | 2015-09-25  |
-- +------+---------+---------+-------------+-------------+
-- | 309  | 60      | 123     | 2012-10-02  | 2012-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 310  | 143     | 587     | 2010-03-05  | 2010-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 311  | 1       | 444     | 2008-07-04  | 2008-08-01  |
-- +------+---------+---------+-------------+-------------+
-- | 312  | 108     | 449     | 1992-04-04  | 1992-04-12  |
-- +------+---------+---------+-------------+-------------+
-- | 313  | 195     | 334     | 2017-07-11  | 2017-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 314  | 54      | 81      | 2017-07-29  | 2017-08-08  |
-- +------+---------+---------+-------------+-------------+
-- | 315  | 136     | 210     | 2006-05-17  | 2006-05-31  |
-- +------+---------+---------+-------------+-------------+
-- | 316  | 98      | 141     | 2017-11-06  | 2017-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 317  | 120     | 438     | 1999-10-25  | 1999-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 318  | 41      | 297     | 2013-02-28  | 2013-02-28  |
-- +------+---------+---------+-------------+-------------+
-- | 319  | 24      | 19      | 1999-01-19  | 1999-02-16  |
-- +------+---------+---------+-------------+-------------+
-- | 320  | 158     | 94      | 2012-08-23  | 2012-09-07  |
-- +------+---------+---------+-------------+-------------+
-- | 321  | 39      | 29      | 2016-02-23  | 2016-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 322  | 173     | 308     | 2018-07-02  | 2018-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 323  | 5       | 420     | 2013-06-16  | 2013-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 324  | 14      | 323     | 2013-07-10  | 2013-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 325  | 163     | 177     | 1994-08-18  | 1994-08-20  |
-- +------+---------+---------+-------------+-------------+
-- | 326  | 5       | 270     | 2013-06-16  | 2013-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 327  | 212     | 274     | 1998-10-14  | 1998-10-15  |
-- +------+---------+---------+-------------+-------------+
-- | 328  | 8       | 320     | 2001-06-01  | 2001-06-17  |
-- +------+---------+---------+-------------+-------------+
-- | 329  | 243     | 33      | 2000-11-23  | 2000-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 330  | 164     | 94      | 2012-08-23  | 2012-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 331  | 229     | 259     | 2012-12-30  |             |
-- +------+---------+---------+-------------+-------------+
-- | 332  | 197     | 363     | 2012-11-05  | 2012-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 333  | 25      | 330     | 2003-06-09  | 2003-06-23  |
-- +------+---------+---------+-------------+-------------+
-- | 334  | 101     | 45      | 2002-07-04  | 2002-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 335  | 50      | 476     | 1990-11-08  | 1990-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 336  | 140     | 608     | 2011-04-12  | 2011-04-16  |
-- +------+---------+---------+-------------+-------------+
-- | 337  | 31      | 9       | 2001-10-18  | 2001-10-21  |
-- +------+---------+---------+-------------+-------------+
-- | 338  | 153     | 15      | 2002-09-20  | 2002-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 339  | 149     | 241     | 2009-10-04  | 2009-10-19  |
-- +------+---------+---------+-------------+-------------+
-- | 340  | 72      | 563     | 2016-12-12  | 2016-12-12  |
-- +------+---------+---------+-------------+-------------+
-- | 341  | 73      | 167     | 1997-05-11  | 1997-05-12  |
-- +------+---------+---------+-------------+-------------+
-- | 342  | 78      | 562     | 2010-12-13  |             |
-- +------+---------+---------+-------------+-------------+
-- | 343  | 136     | 177     | 2006-05-17  | 2006-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 344  | 231     | 495     | 2017-03-12  | 2017-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 345  | 76      | 612     | 2011-04-23  | 2011-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 346  | 90      | 367     | 2009-08-09  | 2009-08-12  |
-- +------+---------+---------+-------------+-------------+
-- | 347  | 82      | 153     | 2016-10-26  | 2016-11-05  |
-- +------+---------+---------+-------------+-------------+
-- | 348  | 57      | 436     | 1992-03-01  | 1992-03-07  |
-- +------+---------+---------+-------------+-------------+
-- | 349  | 94      | 99      | 2012-04-23  | 2012-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 350  | 130     | 104     | 2014-12-01  | 2014-12-20  |
-- +------+---------+---------+-------------+-------------+
-- | 351  | 115     | 92      | 2017-11-20  | 2017-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 352  | 190     | 38      | 2005-08-22  | 2005-08-22  |
-- +------+---------+---------+-------------+-------------+
-- | 353  | 239     | 620     | 2010-10-02  | 2010-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 354  | 188     | 247     | 1994-07-14  | 1994-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 355  | 171     | 37      | 2015-06-19  | 2015-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 356  | 173     | 223     | 1996-07-10  | 1996-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 357  | 246     | 49      | 1991-11-02  | 1991-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 358  | 229     | 247     | 1991-06-21  | 1991-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 359  | 17      | 527     | 2010-12-07  | 2010-12-17  |
-- +------+---------+---------+-------------+-------------+
-- | 360  | 152     | 267     | 2012-09-13  | 2012-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 361  | 123     | 483     | 2009-11-05  | 2009-12-02  |
-- +------+---------+---------+-------------+-------------+
-- | 362  | 123     | 492     | 2009-11-05  | 2009-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 363  | 242     | 349     | 1994-11-17  | 1994-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 364  | 167     | 443     | 1992-01-03  | 1992-01-24  |
-- +------+---------+---------+-------------+-------------+
-- | 365  | 7       | 569     | 2002-02-15  | 2002-03-07  |
-- +------+---------+---------+-------------+-------------+
-- | 366  | 81      | 465     | 2015-06-18  | 2015-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 367  | 2       | 107     | 1999-08-09  | 1999-08-19  |
-- +------+---------+---------+-------------+-------------+
-- | 368  | 120     | 323     | 1999-10-25  | 1999-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 369  | 82      | 402     | 2016-10-26  | 2016-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 370  | 168     | 607     | 2006-01-06  | 2006-02-01  |
-- +------+---------+---------+-------------+-------------+
-- | 371  | 147     | 617     | 2008-02-29  | 2008-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 372  | 183     | 418     | 2015-12-23  | 2016-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 373  | 45      | 44      | 2018-07-19  | 2018-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 374  | 226     | 437     | 2014-03-08  | 2014-03-18  |
-- +------+---------+---------+-------------+-------------+
-- | 375  | 136     | 41      | 2006-05-17  | 2006-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 376  | 180     | 342     | 2011-01-30  | 2011-02-15  |
-- +------+---------+---------+-------------+-------------+
-- | 377  | 197     | 257     | 2011-04-19  | 2011-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 378  | 59      | 285     | 2005-07-23  | 2005-07-26  |
-- +------+---------+---------+-------------+-------------+
-- | 379  | 145     | 57      | 2005-05-09  | 2005-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 380  | 237     | 406     | 2016-10-16  | 2016-10-22  |
-- +------+---------+---------+-------------+-------------+
-- | 381  | 244     | 31      | 2014-04-02  | 2014-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 382  | 196     | 93      | 2000-06-03  | 2000-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 383  | 136     | 545     | 2006-05-17  | 2006-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 384  | 112     | 92      | 2017-11-20  | 2017-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 385  | 164     | 502     | 1999-11-10  | 1999-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 386  | 107     | 148     | 2014-06-01  | 2014-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 387  | 90      | 237     | 2014-05-01  | 2014-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 388  | 190     | 336     | 2005-08-22  | 2005-08-30  |
-- +------+---------+---------+-------------+-------------+
-- | 389  | 120     | 405     | 1999-10-25  | 1999-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 390  | 104     | 97      | 2007-01-12  | 2007-01-28  |
-- +------+---------+---------+-------------+-------------+
-- | 391  | 0       | 530     | 1994-04-27  | 1994-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 392  | 49      | 312     | 2015-04-27  | 2015-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 393  | 120     | 252     | 1999-10-25  | 1999-10-25  |
-- +------+---------+---------+-------------+-------------+
-- | 394  | 247     | 196     | 1992-06-14  | 1992-06-24  |
-- +------+---------+---------+-------------+-------------+
-- | 395  | 229     | 587     | 1991-06-21  | 1991-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 396  | 32      | 168     | 2012-07-22  | 2012-08-09  |
-- +------+---------+---------+-------------+-------------+
-- | 397  | 238     | 509     | 2013-10-11  | 2013-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 398  | 164     | 540     | 1999-11-10  | 1999-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 399  | 154     | 393     | 2006-10-08  | 2006-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 400  | 188     | 37      | 1994-07-14  | 1994-08-11  |
-- +------+---------+---------+-------------+-------------+
-- | 401  | 14      | 214     | 2015-11-19  | 2015-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 402  | 157     | 490     | 2016-11-09  | 2016-12-07  |
-- +------+---------+---------+-------------+-------------+
-- | 403  | 79      | 173     | 2017-08-20  | 2017-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 404  | 154     | 2       | 2006-10-08  | 2006-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 405  | 244     | 70      | 2004-07-06  | 2004-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 406  | 19      | 288     | 2001-07-05  | 2001-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 407  | 194     | 488     | 2017-05-11  | 2017-05-25  |
-- +------+---------+---------+-------------+-------------+
-- | 408  | 21      | 207     | 2004-03-18  | 2004-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 409  | 74      | 127     | 2003-10-04  | 2003-10-09  |
-- +------+---------+---------+-------------+-------------+
-- | 410  | 77      | 610     | 2017-12-15  | 2017-12-18  |
-- +------+---------+---------+-------------+-------------+
-- | 411  | 214     | 579     | 1994-12-27  | 1995-01-08  |
-- +------+---------+---------+-------------+-------------+
-- | 412  | 90      | 115     | 2009-08-09  | 2009-08-16  |
-- +------+---------+---------+-------------+-------------+
-- | 413  | 220     | 623     | 1996-08-31  | 1996-09-15  |
-- +------+---------+---------+-------------+-------------+
-- | 414  | 83      | 98      | 2012-05-29  |             |
-- +------+---------+---------+-------------+-------------+
-- | 415  | 223     | 466     | 2010-03-06  | 2010-03-12  |
-- +------+---------+---------+-------------+-------------+
-- | 416  | 34      | 579     | 1991-04-27  | 1991-05-24  |
-- +------+---------+---------+-------------+-------------+
-- | 417  | 234     | 89      | 2009-02-15  | 2009-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 418  | 189     | 448     | 2015-11-06  | 2015-11-24  |
-- +------+---------+---------+-------------+-------------+
-- | 419  | 138     | 506     | 2009-04-03  | 2009-04-07  |
-- ...
-- | 1860 | 94      | 436     | 2012-04-23  | 2012-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1861 | 61      | 91      | 2015-10-14  | 2015-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1862 | 247     | 286     | 2016-06-03  | 2016-06-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1863 | 169     | 384     | 2017-01-01  | 2017-01-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1864 | 151     | 529     | 1993-09-11  | 1993-10-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1865 | 0       | 563     | 2016-12-12  | 2016-12-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1866 | 84      | 453     | 1995-05-02  | 1995-05-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1867 | 68      | 82      | 2016-05-20  | 2016-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1868 | 76      | 53      | 2011-04-23  | 2011-05-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1869 | 155     | 17      | 2006-06-28  | 2006-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1870 | 238     | 313     | 2013-10-11  | 2013-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1871 | 101     | 438     | 2002-07-04  | 2002-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1872 | 66      | 126     | 2015-02-17  | 2015-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1873 | 182     | 524     | 2004-12-26  | 2005-01-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1874 | 212     | 416     | 1998-10-14  | 1998-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1875 | 227     | 135     | 2015-07-03  | 2015-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1876 | 109     | 569     | 2009-04-21  | 2009-05-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1877 | 111     | 218     | 2015-04-29  | 2015-05-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1878 | 53      | 362     | 1990-10-21  | 1990-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1879 | 155     | 580     | 2009-10-08  | 2009-10-26  |
-- +------+---------+---------+-------------+-------------+
-- | 1880 | 73      | 458     | 1997-05-11  | 1997-05-19  |
-- +------+---------+---------+-------------+-------------+
-- | 1881 | 197     | 3       | 2017-03-02  | 2017-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 1882 | 230     | 12      | 1994-02-13  | 1994-02-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1883 | 21      | 490     | 2004-03-18  | 2004-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1884 | 89      | 476     | 1991-03-11  | 1991-04-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1885 | 126     | 130     | 2001-10-14  | 2001-11-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1886 | 133     | 338     | 2018-04-23  | 2018-05-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1887 | 38      | 459     | 2006-09-01  | 2006-09-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1888 | 123     | 310     | 2009-11-05  | 2009-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1889 | 1       | 190     | 2008-07-04  | 2008-07-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1890 | 123     | 153     | 2009-11-05  | 2009-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1891 | 150     | 277     | 2017-02-22  | 2017-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1892 | 86      | 417     | 2006-01-12  | 2006-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1893 | 131     | 239     | 2001-07-09  | 2001-08-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1894 | 218     | 602     | 2006-05-17  | 2006-05-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1895 | 56      | 489     | 2016-08-02  | 2016-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1896 | 92      | 9       | 2016-05-06  | 2016-06-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1897 | 185     | 82      | 2015-06-02  | 2015-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1898 | 78      | 191     | 2010-12-13  | 2011-01-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1899 | 203     | 302     | 2018-08-01  | 2018-08-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1900 | 71      | 339     | 2014-06-27  | 2014-07-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1901 | 165     | 183     | 1999-08-25  | 1999-09-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1902 | 38      | 114     | 2006-09-01  | 2006-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1903 | 91      | 602     | 2013-07-06  | 2013-07-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1904 | 243     | 167     | 2000-11-23  | 2000-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1905 | 225     | 613     | 2012-09-23  | 2012-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1906 | 247     | 208     | 1992-06-14  | 1992-06-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1907 | 132     | 316     | 2004-10-16  | 2004-10-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1908 | 102     | 195     | 2013-09-11  | 2013-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1909 | 68      | 228     | 2016-05-20  | 2016-05-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1910 | 109     | 365     | 2009-04-21  | 2009-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1911 | 38      | 543     | 2015-11-09  | 2015-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1912 | 142     | 534     | 2009-10-29  | 2009-10-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1913 | 29      | 293     | 2000-02-14  | 2000-02-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1914 | 171     | 135     | 2015-07-03  | 2015-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1915 | 127     | 63      | 2006-07-26  | 2006-08-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1916 | 230     | 196     | 1994-02-13  | 1994-02-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1917 | 95      | 368     | 2012-11-27  | 2012-12-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1918 | 32      | 624     | 2012-07-22  | 2012-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1919 | 160     | 446     | 1990-12-18  | 1991-01-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1920 | 31      | 268     | 2001-10-18  | 2001-10-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1921 | 156     | 405     | 1998-03-13  | 1998-03-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1922 | 248     | 587     | 2006-01-21  | 2006-01-25  |
-- +------+---------+---------+-------------+-------------+
-- | 1923 | 76      | 150     | 2011-04-23  | 2011-05-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1924 | 223     | 327     | 2010-03-06  | 2010-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1925 | 6       | 45      | 1999-02-13  | 1999-02-18  |
-- +------+---------+---------+-------------+-------------+
-- | 1926 | 1       | 504     | 2008-07-04  | 2008-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1927 | 245     | 455     | 2012-09-24  | 2012-10-19  |
-- +------+---------+---------+-------------+-------------+
-- | 1928 | 166     | 97      | 2005-06-05  | 2005-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1929 | 48      | 636     | 2013-06-25  | 2013-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1930 | 184     | 172     | 2012-01-16  | 2012-02-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1931 | 169     | 622     | 2017-01-01  | 2017-01-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1932 | 51      | 141     | 2017-11-06  | 2017-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1933 | 60      | 81      | 2012-10-02  | 2012-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1934 | 5       | 451     | 2013-06-16  | 2013-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1935 | 63      | 277     | 2017-02-22  | 2017-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1936 | 215     | 288     | 2009-11-07  | 2009-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1937 | 136     | 86      | 2006-05-17  | 2006-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1938 | 33      | 436     | 2006-06-17  | 2006-06-18  |
-- +------+---------+---------+-------------+-------------+
-- | 1939 | 104     | 104     | 2007-01-12  | 2007-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1940 | 109     | 373     | 2009-04-21  | 2009-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1941 | 102     | 419     | 2008-03-07  | 2008-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1942 | 137     | 562     | 1998-04-23  | 1998-04-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1943 | 13      | 598     | 2003-10-21  | 2003-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1944 | 15      | 47      | 2004-08-13  | 2004-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1945 | 87      | 563     | 2016-12-12  | 2016-12-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1946 | 193     | 323     | 2006-12-18  | 2006-12-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1947 | 69      | 428     | 2007-06-26  | 2007-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1948 | 24      | 217     | 2008-09-17  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1949 | 180     | 48      | 2013-06-30  | 2013-06-30  |
-- +------+---------+---------+-------------+-------------+
-- | 1950 | 44      | 65      | 1992-10-24  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1951 | 32      | 349     | 2012-07-22  | 2012-08-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1952 | 207     | 7       | 2007-10-01  | 2007-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1953 | 201     | 50      | 1999-02-16  | 1999-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1954 | 54      | 506     | 2017-07-29  | 2017-08-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1955 | 9       | 317     | 2013-03-07  | 2013-03-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1956 | 229     | 37      | 1991-06-21  | 1991-07-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1957 | 5       | 421     | 2013-06-16  | 2013-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1958 | 194     | 90      | 2017-05-11  | 2017-05-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1959 | 14      | 411     | 2013-07-10  | 2013-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1960 | 166     | 249     | 2005-06-05  | 2005-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1961 | 241     | 135     | 2015-07-13  | 2015-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1962 | 31      | 445     | 2001-10-18  | 2001-11-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1963 | 237     | 230     | 2016-10-16  | 2016-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1964 | 101     | 170     | 2002-07-04  | 2002-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 1965 | 185     | 425     | 2015-06-02  | 2015-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1966 | 80      | 443     | 1995-11-25  | 1995-12-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1967 | 119     | 337     | 2008-11-04  | 2008-12-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1968 | 196     | 100     | 2000-06-03  | 2000-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1969 | 94      | 424     | 2012-04-23  | 2012-04-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1970 | 187     | 282     | 2008-11-22  | 2008-12-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1971 | 83      | 71      | 2012-05-29  | 2012-06-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1972 | 112     | 541     | 2015-08-13  | 2015-09-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1973 | 72      | 543     | 2015-11-09  | 2015-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1974 | 56      | 564     | 2016-08-02  | 2016-08-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1975 | 168     | 530     | 2004-10-18  | 2004-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1976 | 220     | 256     | 2018-06-23  | 2018-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1977 | 240     | 503     | 2007-06-29  | 2007-07-26  |
-- +------+---------+---------+-------------+-------------+
-- | 1978 | 10      | 163     | 2017-09-08  | 2017-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1979 | 36      | 313     | 2011-10-17  | 2011-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1980 | 130     | 333     | 2014-12-01  | 2014-12-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1981 | 33      | 347     | 2013-07-31  | 2013-08-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1982 | 166     | 181     | 2016-01-26  | 2016-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1983 | 28      | 116     | 2017-08-20  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1984 | 44      | 133     | 2017-06-10  | 2017-06-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1985 | 103     | 309     | 2006-01-03  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1986 | 102     | 633     | 2008-03-07  | 2008-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1987 | 120     | 310     | 1999-10-25  | 1999-11-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1988 | 248     | 185     | 2006-01-21  | 2006-02-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1989 | 174     | 623     | 1990-03-26  | 1990-04-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1990 | 14      | 479     | 2013-07-10  | 2013-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1991 | 36      | 211     | 1995-05-18  | 1995-06-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1992 | 89      | 547     | 1991-03-11  | 1991-03-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1993 | 183     | 274     | 2015-12-23  | 2016-01-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1994 | 67      | 256     | 2018-06-23  | 2018-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1995 | 182     | 414     | 2004-12-26  | 2005-01-12  |
-- +------+---------+---------+-------------+-------------+
-- | 1996 | 127     | 230     | 2006-07-26  | 2006-08-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1997 | 118     | 356     | 1998-06-26  | 1998-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 1998 | 212     | 11      | 1998-10-14  | 1998-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1999 | 173     | 547     | 1996-07-10  | 1996-07-22  |
-- +------+---------+---------+-------------+-------------+

-- %% [markdown]
-- Zapytanie i wynik zapytania:

-- %%
SELECT 1.0*COUNT(DISTINCT borrowings.ID)/COUNT(DISTINCT borrowings.user_id) FROM borrowings;
-- Out:
-- +----------------------------------------------------------------------+
-- | 1.0*COUNT(DISTINCT borrowings.ID)/COUNT(DISTINCT borrowings.user_id) |
-- +----------------------------------------------------------------------+
-- | 8.0                                                                  |
-- +----------------------------------------------------------------------+

-- %% [markdown]
-- **Możemy napisać zapytanie zwracające listę użytkowników pożyczających więcej książek niż średnia.**

-- %% [markdown]
-- Tabela **`Users`**:

-- %%
SELECT * FROM users;
-- Out:
-- +-----+---------------+-------------+-------------------+
-- | ID  | surname       | name        | registration_date |
-- +-----+---------------+-------------+-------------------+
-- | 0   | Piotrowski    | Igor        | 1994-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 1   | Lewandowska   | Róża      | 2008-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 2   | Woźniak      | Adam        | 1999-08-09        |
-- +-----+---------------+-------------+-------------------+
-- | 3   | Kowalczyk     | Michał     | 2011-01-22        |
-- +-----+---------------+-------------+-------------------+
-- | 4   | Kaczmarek     | Leon        | 1990-08-15        |
-- +-----+---------------+-------------+-------------------+
-- | 5   | Kwiatkowska   | Joanna      | 2013-06-16        |
-- +-----+---------------+-------------+-------------------+
-- | 6   | Zieliński    | Michał     | 1990-09-21        |
-- +-----+---------------+-------------+-------------------+
-- | 7   | Woźniak      | Małgorzata | 1991-10-03        |
-- +-----+---------------+-------------+-------------------+
-- | 8   | Kaczmarek     | Joanna      | 2001-05-31        |
-- +-----+---------------+-------------+-------------------+
-- | 9   | Wójcik       | Izabela     | 2013-03-07        |
-- +-----+---------------+-------------+-------------------+
-- | 10  | Lewandowska   | Klaudia     | 2004-09-14        |
-- +-----+---------------+-------------+-------------------+
-- | 11  | Piotrowski    | Igor        | 1996-08-08        |
-- +-----+---------------+-------------+-------------------+
-- | 12  | Nowak         | Róża      | 2007-04-08        |
-- +-----+---------------+-------------+-------------------+
-- | 13  | Kowalska      | Izabela     | 2003-10-21        |
-- +-----+---------------+-------------+-------------------+
-- | 14  | Kamińska     | Izabela     | 2013-07-10        |
-- +-----+---------------+-------------+-------------------+
-- | 15  | Kowalczyk     | Mateusz     | 2004-08-13        |
-- +-----+---------------+-------------+-------------------+
-- | 16  | Mazur         | Michał     | 1995-03-01        |
-- +-----+---------------+-------------+-------------------+
-- | 17  | Piotrowski    | Piotr       | 1991-08-31        |
-- +-----+---------------+-------------+-------------------+
-- | 18  | Lewandowski   | Adam        | 1998-08-08        |
-- +-----+---------------+-------------+-------------------+
-- | 19  | Kowalska      | Matylda     | 2001-07-05        |
-- +-----+---------------+-------------+-------------------+
-- | 20  | Lewandowska   | Katarzyna   | 2010-03-31        |
-- +-----+---------------+-------------+-------------------+
-- | 21  | Lewandowska   | Aniela      | 2004-03-18        |
-- +-----+---------------+-------------+-------------------+
-- | 22  | Szymański    | Leon        | 2007-11-18        |
-- +-----+---------------+-------------+-------------------+
-- | 23  | Kwiatkowska   | Joanna      | 1996-01-27        |
-- +-----+---------------+-------------+-------------------+
-- | 24  | Wójcik       | Wiktor      | 1999-01-19        |
-- +-----+---------------+-------------+-------------------+
-- | 25  | Woźniak      | Piotr       | 2003-06-09        |
-- +-----+---------------+-------------+-------------------+
-- | 26  | Wójcik       | Stanisław  | 2004-07-16        |
-- +-----+---------------+-------------+-------------------+
-- | 27  | Jankowska     | Paulina     | 1998-12-15        |
-- +-----+---------------+-------------+-------------------+
-- | 28  | Kowalczyk     | Piotr       | 2017-08-20        |
-- +-----+---------------+-------------+-------------------+
-- | 29  | Wójcik       | Adam        | 1992-06-11        |
-- +-----+---------------+-------------+-------------------+
-- | 30  | Kozłowski    | Michał     | 2016-10-24        |
-- +-----+---------------+-------------+-------------------+
-- | 31  | Mazur         | Matylda     | 2001-10-18        |
-- +-----+---------------+-------------+-------------------+
-- | 32  | Wiśniewska   | Katarzyna   | 2012-07-22        |
-- +-----+---------------+-------------+-------------------+
-- | 33  | Jankowska     | Joanna      | 2006-06-17        |
-- +-----+---------------+-------------+-------------------+
-- | 34  | Szymańska    | Róża      | 1991-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 35  | Dąbrowski    | Piotr       | 1990-01-02        |
-- +-----+---------------+-------------+-------------------+
-- | 36  | Kaczmarek     | Małgorzata | 1992-03-16        |
-- +-----+---------------+-------------+-------------------+
-- | 37  | Mazur         | Marcel      | 2005-10-09        |
-- +-----+---------------+-------------+-------------------+
-- | 38  | Lewandowski   | Marcel      | 2006-09-01        |
-- +-----+---------------+-------------+-------------------+
-- | 39  | Kozłowski    | Adam        | 2012-11-13        |
-- +-----+---------------+-------------+-------------------+
-- | 40  | Szymańska    | Klaudia     | 1990-06-01        |
-- +-----+---------------+-------------+-------------------+
-- | 41  | Grabowska     | Liliana     | 1991-11-19        |
-- +-----+---------------+-------------+-------------------+
-- | 42  | Mazur         | Katarzyna   | 2007-01-15        |
-- +-----+---------------+-------------+-------------------+
-- | 43  | Szymański    | Mateusz     | 1994-07-26        |
-- +-----+---------------+-------------+-------------------+
-- | 44  | Nowak         | Klaudia     | 1992-10-24        |
-- +-----+---------------+-------------+-------------------+
-- | 45  | Grabowski     | Piotr       | 2017-01-14        |
-- +-----+---------------+-------------+-------------------+
-- | 46  | Woźniak      | Marta       | 2009-02-27        |
-- +-----+---------------+-------------+-------------------+
-- | 47  | Nowak         | Sara        | 2001-03-25        |
-- +-----+---------------+-------------+-------------------+
-- | 48  | Piotrowski    | Wiktor      | 2013-06-25        |
-- +-----+---------------+-------------+-------------------+
-- | 49  | Grabowska     | Liliana     | 2015-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 50  | Zielińska    | Matylda     | 1990-11-08        |
-- +-----+---------------+-------------+-------------------+
-- | 51  | Mazur         | Mateusz     | 2001-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 52  | Lewandowski   | Leon        | 2006-06-17        |
-- +-----+---------------+-------------+-------------------+
-- | 53  | Dąbrowski    | Adam        | 1990-03-21        |
-- +-----+---------------+-------------+-------------------+
-- | 54  | Wojciechowska | Joanna      | 2017-07-29        |
-- +-----+---------------+-------------+-------------------+
-- | 55  | Kozłowski    | Wiktor      | 2014-03-05        |
-- +-----+---------------+-------------+-------------------+
-- | 56  | Kozłowska    | Katarzyna   | 2016-08-02        |
-- +-----+---------------+-------------+-------------------+
-- | 57  | Jankowska     | Paulina     | 1992-03-01        |
-- +-----+---------------+-------------+-------------------+
-- | 58  | Krawczyk      | Adam        | 2013-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 59  | Woźniak      | Róża      | 2005-07-23        |
-- +-----+---------------+-------------+-------------------+
-- | 60  | Kaczmarek     | Aniela      | 2012-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 61  | Kaczmarek     | Matylda     | 2015-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 62  | Kamińska     | Klaudia     | 1999-09-14        |
-- +-----+---------------+-------------+-------------------+
-- | 63  | Kaczmarek     | Piotr       | 1999-04-26        |
-- +-----+---------------+-------------+-------------------+
-- | 64  | Mazur         | Wiktor      | 1990-12-22        |
-- +-----+---------------+-------------+-------------------+
-- | 65  | Dąbrowska    | Katarzyna   | 2017-11-27        |
-- +-----+---------------+-------------+-------------------+
-- | 66  | Kowalska      | Klaudia     | 1990-12-27        |
-- +-----+---------------+-------------+-------------------+
-- | 67  | Szymańska    | Klaudia     | 2007-08-17        |
-- +-----+---------------+-------------+-------------------+
-- | 68  | Wójcik       | Wiktor      | 2016-05-20        |
-- +-----+---------------+-------------+-------------------+
-- | 69  | Grabowska     | Klaudia     | 2007-06-26        |
-- +-----+---------------+-------------+-------------------+
-- | 70  | Piotrowska    | Klaudia     | 1992-08-28        |
-- +-----+---------------+-------------+-------------------+
-- | 71  | Kozłowski    | Stanisław  | 2014-06-27        |
-- +-----+---------------+-------------+-------------------+
-- | 72  | Mazur         | Joanna      | 2012-12-17        |
-- +-----+---------------+-------------+-------------------+
-- | 73  | Nowak         | Adam        | 1997-05-11        |
-- +-----+---------------+-------------+-------------------+
-- | 74  | Wiśniewska   | Małgorzata | 2003-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 75  | Kozłowska    | Joanna      | 2013-04-17        |
-- +-----+---------------+-------------+-------------------+
-- | 76  | Kowalski      | Piotr       | 2011-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 77  | Jankowski     | Marcel      | 2017-12-15        |
-- +-----+---------------+-------------+-------------------+
-- | 78  | Lewandowska   | Marta       | 2010-12-13        |
-- +-----+---------------+-------------+-------------------+
-- | 79  | Kozłowska    | Paulina     | 2017-08-20        |
-- +-----+---------------+-------------+-------------------+
-- | 80  | Nowak         | Mateusz     | 1995-11-25        |
-- +-----+---------------+-------------+-------------------+
-- | 81  | Dąbrowska    | Klaudia     | 2015-06-18        |
-- +-----+---------------+-------------+-------------------+
-- | 82  | Grabowska     | Klaudia     | 2016-10-26        |
-- +-----+---------------+-------------+-------------------+
-- | 83  | Kwiatkowska   | Marta       | 2012-05-29        |
-- +-----+---------------+-------------+-------------------+
-- | 84  | Krawczyk      | Nikodem     | 1995-05-02        |
-- +-----+---------------+-------------+-------------------+
-- | 85  | Kaczmarek     | Michał     | 2009-12-30        |
-- +-----+---------------+-------------+-------------------+
-- | 86  | Wójcik       | Klaudia     | 2003-11-08        |
-- +-----+---------------+-------------+-------------------+
-- | 87  | Dąbrowski    | Igor        | 2004-01-19        |
-- +-----+---------------+-------------+-------------------+
-- | 88  | Kaczmarek     | Michał     | 1990-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 89  | Kowalczyk     | Aniela      | 1991-03-11        |
-- +-----+---------------+-------------+-------------------+
-- | 90  | Lewandowski   | Piotr       | 2009-08-09        |
-- +-----+---------------+-------------+-------------------+
-- | 91  | Kaczmarek     | Izabela     | 2013-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 92  | Nowak         | Leon        | 2016-05-06        |
-- +-----+---------------+-------------+-------------------+
-- | 93  | Kwiatkowski   | Michał     | 2011-10-10        |
-- +-----+---------------+-------------+-------------------+
-- | 94  | Wiśniewska   | Małgorzata | 2012-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 95  | Mazur         | Katarzyna   | 2012-11-27        |
-- +-----+---------------+-------------+-------------------+
-- | 96  | Nowak         | Nikodem     | 2014-03-22        |
-- +-----+---------------+-------------+-------------------+
-- | 97  | Kaczmarek     | Małgorzata | 2001-02-10        |
-- +-----+---------------+-------------+-------------------+
-- | 98  | Lewandowska   | Małgorzata | 1990-07-21        |
-- +-----+---------------+-------------+-------------------+
-- | 99  | Grabowska     | Małgorzata | 1998-11-16        |
-- +-----+---------------+-------------+-------------------+
-- | 100 | Grabowski     | Mateusz     | 2007-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 101 | Wojciechowska | Paulina     | 2002-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 102 | Woźniak      | Marta       | 2008-03-07        |
-- +-----+---------------+-------------+-------------------+
-- | 103 | Dąbrowska    | Joanna      | 2006-01-03        |
-- +-----+---------------+-------------+-------------------+
-- | 104 | Kamiński     | Marcel      | 2007-01-12        |
-- +-----+---------------+-------------+-------------------+
-- | 105 | Nowak         | Michał     | 2005-06-13        |
-- +-----+---------------+-------------+-------------------+
-- | 106 | Wiśniewska   | Marta       | 1991-10-27        |
-- +-----+---------------+-------------+-------------------+
-- | 107 | Zieliński    | Leon        | 2014-06-01        |
-- +-----+---------------+-------------+-------------------+
-- | 108 | Wojciechowski | Wiktor      | 1992-04-04        |
-- +-----+---------------+-------------+-------------------+
-- | 109 | Piotrowska    | Małgorzata | 2009-04-21        |
-- +-----+---------------+-------------+-------------------+
-- | 110 | Kowalska      | Paulina     | 1998-01-15        |
-- +-----+---------------+-------------+-------------------+
-- | 111 | Kwiatkowska   | Paulina     | 2015-04-29        |
-- +-----+---------------+-------------+-------------------+
-- | 112 | Grabowska     | Aniela      | 2015-08-13        |
-- +-----+---------------+-------------+-------------------+
-- | 113 | Kowalczyk     | Katarzyna   | 2017-03-21        |
-- +-----+---------------+-------------+-------------------+
-- | 114 | Nowak         | Liliana     | 1997-04-04        |
-- +-----+---------------+-------------+-------------------+
-- | 115 | Kaczmarek     | Leon        | 2016-03-18        |
-- +-----+---------------+-------------+-------------------+
-- | 116 | Kowalczyk     | Leon        | 2009-04-06        |
-- +-----+---------------+-------------+-------------------+
-- | 117 | Kowalska      | Marta       | 2011-01-13        |
-- +-----+---------------+-------------+-------------------+
-- | 118 | Kowalska      | Joanna      | 1992-09-03        |
-- +-----+---------------+-------------+-------------------+
-- | 119 | Krawczyk      | Paulina     | 2008-11-04        |
-- +-----+---------------+-------------+-------------------+
-- | 120 | Dąbrowska    | Róża      | 1999-10-25        |
-- +-----+---------------+-------------+-------------------+
-- | 121 | Grabowska     | Joanna      | 2009-10-25        |
-- +-----+---------------+-------------+-------------------+
-- | 122 | Grabowski     | Igor        | 1990-10-07        |
-- +-----+---------------+-------------+-------------------+
-- | 123 | Kaczmarek     | Sara        | 2009-11-05        |
-- +-----+---------------+-------------+-------------------+
-- | 124 | Lewandowska   | Izabela     | 2015-02-13        |
-- +-----+---------------+-------------+-------------------+
-- | 125 | Piotrowska    | Izabela     | 2017-08-14        |
-- +-----+---------------+-------------+-------------------+
-- | 126 | Dąbrowska    | Róża      | 2001-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 127 | Nowak         | Katarzyna   | 2006-07-26        |
-- +-----+---------------+-------------+-------------------+
-- | 128 | Kaczmarek     | Małgorzata | 2017-03-04        |
-- +-----+---------------+-------------+-------------------+
-- | 129 | Kowalczyk     | Adam        | 2017-09-05        |
-- +-----+---------------+-------------+-------------------+
-- | 130 | Szymański    | Adam        | 2014-12-01        |
-- +-----+---------------+-------------+-------------------+
-- | 131 | Woźniak      | Nikodem     | 1991-10-10        |
-- +-----+---------------+-------------+-------------------+
-- | 132 | Wojciechowska | Katarzyna   | 2004-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 133 | Kaczmarek     | Igor        | 2007-08-11        |
-- +-----+---------------+-------------+-------------------+
-- | 134 | Dąbrowski    | Nikodem     | 2011-01-25        |
-- +-----+---------------+-------------+-------------------+
-- | 135 | Dąbrowska    | Aniela      | 1998-10-03        |
-- +-----+---------------+-------------+-------------------+
-- | 136 | Wójcik       | Izabela     | 2006-05-17        |
-- +-----+---------------+-------------+-------------------+
-- | 137 | Piotrowska    | Izabela     | 1998-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 138 | Kwiatkowska   | Izabela     | 2009-04-03        |
-- +-----+---------------+-------------+-------------------+
-- | 139 | Kowalska      | Małgorzata | 2016-05-30        |
-- +-----+---------------+-------------+-------------------+
-- | 140 | Nowak         | Mateusz     | 2011-04-12        |
-- +-----+---------------+-------------+-------------------+
-- | 141 | Zielińska    | Róża      | 2001-09-13        |
-- +-----+---------------+-------------+-------------------+
-- | 142 | Wiśniewska   | Katarzyna   | 2009-10-29        |
-- +-----+---------------+-------------+-------------------+
-- | 143 | Wiśniewski   | Michał     | 2010-03-05        |
-- +-----+---------------+-------------+-------------------+
-- | 144 | Dąbrowska    | Aniela      | 1998-04-01        |
-- +-----+---------------+-------------+-------------------+
-- | 145 | Kaczmarek     | Róża      | 2005-05-09        |
-- +-----+---------------+-------------+-------------------+
-- | 146 | Kamiński     | Piotr       | 1992-11-29        |
-- +-----+---------------+-------------+-------------------+
-- | 147 | Woźniak      | Matylda     | 2008-02-29        |
-- +-----+---------------+-------------+-------------------+
-- | 148 | Dąbrowski    | Igor        | 1996-08-25        |
-- +-----+---------------+-------------+-------------------+
-- | 149 | Lewandowski   | Marcel      | 2009-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 150 | Jankowska     | Małgorzata | 2000-09-13        |
-- +-----+---------------+-------------+-------------------+
-- | 151 | Kamiński     | Wiktor      | 1993-09-11        |
-- +-----+---------------+-------------+-------------------+
-- | 152 | Krawczyk      | Katarzyna   | 1996-08-24        |
-- +-----+---------------+-------------+-------------------+
-- | 153 | Mazur         | Adam        | 2002-09-20        |
-- +-----+---------------+-------------+-------------------+
-- | 154 | Kwiatkowska   | Sara        | 2006-10-08        |
-- +-----+---------------+-------------+-------------------+
-- | 155 | Wójcik       | Stanisław  | 2006-06-28        |
-- +-----+---------------+-------------+-------------------+
-- | 156 | Grabowski     | Mateusz     | 1998-03-13        |
-- +-----+---------------+-------------+-------------------+
-- | 157 | Wiśniewska   | Katarzyna   | 2016-11-09        |
-- +-----+---------------+-------------+-------------------+
-- | 158 | Krawczyk      | Michał     | 2007-04-25        |
-- +-----+---------------+-------------+-------------------+
-- | 159 | Szymański    | Piotr       | 1991-05-15        |
-- +-----+---------------+-------------+-------------------+
-- | 160 | Kamiński     | Leon        | 1990-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 161 | Krawczyk      | Marcel      | 2002-09-28        |
-- +-----+---------------+-------------+-------------------+
-- | 162 | Kozłowska    | Aniela      | 1993-10-19        |
-- +-----+---------------+-------------+-------------------+
-- | 163 | Wojciechowski | Leon        | 1994-08-18        |
-- +-----+---------------+-------------+-------------------+
-- | 164 | Wójcik       | Liliana     | 1999-11-10        |
-- +-----+---------------+-------------+-------------------+
-- | 165 | Piotrowski    | Wiktor      | 1999-08-25        |
-- +-----+---------------+-------------+-------------------+
-- | 166 | Wiśniewska   | Katarzyna   | 2005-06-05        |
-- +-----+---------------+-------------+-------------------+
-- | 167 | Kozłowska    | Sara        | 1992-01-03        |
-- +-----+---------------+-------------+-------------------+
-- | 168 | Woźniak      | Adam        | 2004-10-18        |
-- +-----+---------------+-------------+-------------------+
-- | 169 | Nowak         | Adam        | 2017-01-01        |
-- +-----+---------------+-------------+-------------------+
-- | 170 | Kowalska      | Róża      | 2011-11-26        |
-- +-----+---------------+-------------+-------------------+
-- | 171 | Lewandowski   | Michał     | 2015-06-19        |
-- +-----+---------------+-------------+-------------------+
-- | 172 | Nowak         | Izabela     | 2003-05-31        |
-- +-----+---------------+-------------+-------------------+
-- | 173 | Nowak         | Aniela      | 1996-07-10        |
-- +-----+---------------+-------------+-------------------+
-- | 174 | Piotrowska    | Joanna      | 1990-03-26        |
-- +-----+---------------+-------------+-------------------+
-- | 175 | Kowalczyk     | Joanna      | 1992-07-02        |
-- +-----+---------------+-------------+-------------------+
-- | 176 | Zielińska    | Liliana     | 2007-08-12        |
-- +-----+---------------+-------------+-------------------+
-- | 177 | Jankowska     | Paulina     | 2003-05-04        |
-- +-----+---------------+-------------+-------------------+
-- | 178 | Piotrowski    | Stanisław  | 2017-01-09        |
-- +-----+---------------+-------------+-------------------+
-- | 179 | Wiśniewska   | Róża      | 2006-05-12        |
-- +-----+---------------+-------------+-------------------+
-- | 180 | Piotrowski    | Piotr       | 2011-01-30        |
-- +-----+---------------+-------------+-------------------+
-- | 181 | Wójcik       | Nikodem     | 2012-02-03        |
-- +-----+---------------+-------------+-------------------+
-- | 182 | Lewandowska   | Sara        | 2004-12-26        |
-- +-----+---------------+-------------+-------------------+
-- | 183 | Wójcik       | Marcel      | 2015-12-23        |
-- +-----+---------------+-------------+-------------------+
-- | 184 | Jankowska     | Małgorzata | 2012-01-16        |
-- +-----+---------------+-------------+-------------------+
-- | 185 | Wiśniewska   | Liliana     | 2015-06-02        |
-- +-----+---------------+-------------+-------------------+
-- | 186 | Kowalski      | Stanisław  | 2013-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 187 | Nowak         | Aniela      | 2008-11-22        |
-- +-----+---------------+-------------+-------------------+
-- | 188 | Grabowska     | Marta       | 1994-07-14        |
-- +-----+---------------+-------------+-------------------+
-- | 189 | Kowalska      | Paulina     | 2006-02-21        |
-- +-----+---------------+-------------+-------------------+
-- | 190 | Dąbrowska    | Róża      | 2005-08-22        |
-- +-----+---------------+-------------+-------------------+
-- | 191 | Wójcik       | Marcel      | 2015-11-28        |
-- +-----+---------------+-------------+-------------------+
-- | 192 | Grabowska     | Matylda     | 2011-01-26        |
-- +-----+---------------+-------------+-------------------+
-- | 193 | Dąbrowski    | Nikodem     | 2006-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 194 | Nowak         | Piotr       | 2017-05-11        |
-- +-----+---------------+-------------+-------------------+
-- | 195 | Woźniak      | Liliana     | 2017-07-11        |
-- +-----+---------------+-------------+-------------------+
-- | 196 | Zieliński    | Stanisław  | 2000-06-03        |
-- +-----+---------------+-------------+-------------------+
-- | 197 | Grabowski     | Piotr       | 2011-04-19        |
-- +-----+---------------+-------------+-------------------+
-- | 198 | Szymański    | Michał     | 2013-05-10        |
-- +-----+---------------+-------------+-------------------+
-- | 199 | Kowalski      | Stanisław  | 1995-06-12        |
-- +-----+---------------+-------------+-------------------+
-- | 200 | Wójcik       | Sara        | 1990-02-18        |
-- +-----+---------------+-------------+-------------------+
-- | 201 | Kozłowska    | Aniela      | 1999-02-16        |
-- +-----+---------------+-------------+-------------------+
-- | 202 | Kowalski      | Mateusz     | 2013-06-18        |
-- +-----+---------------+-------------+-------------------+
-- | 203 | Kowalczyk     | Igor        | 1996-03-20        |
-- +-----+---------------+-------------+-------------------+
-- | 204 | Kamiński     | Leon        | 1990-07-23        |
-- +-----+---------------+-------------+-------------------+
-- | 205 | Szymańska    | Katarzyna   | 1991-12-28        |
-- +-----+---------------+-------------+-------------------+
-- | 206 | Kowalska      | Róża      | 2017-02-04        |
-- +-----+---------------+-------------+-------------------+
-- | 207 | Wojciechowska | Marta       | 2007-10-01        |
-- +-----+---------------+-------------+-------------------+
-- | 208 | Kwiatkowska   | Małgorzata | 2012-02-23        |
-- +-----+---------------+-------------+-------------------+
-- | 209 | Jankowska     | Joanna      | 1999-08-02        |
-- +-----+---------------+-------------+-------------------+
-- | 210 | Wójcik       | Igor        | 2003-02-18        |
-- +-----+---------------+-------------+-------------------+
-- | 211 | Wojciechowska | Klaudia     | 2010-12-12        |
-- +-----+---------------+-------------+-------------------+
-- | 212 | Kaczmarek     | Marta       | 1998-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 213 | Krawczyk      | Nikodem     | 1998-10-28        |
-- +-----+---------------+-------------+-------------------+
-- | 214 | Kozłowska    | Klaudia     | 1994-12-27        |
-- +-----+---------------+-------------+-------------------+
-- | 215 | Zielińska    | Izabela     | 2009-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 216 | Jankowski     | Nikodem     | 2004-08-18        |
-- +-----+---------------+-------------+-------------------+
-- | 217 | Mazur         | Adam        | 2011-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 218 | Kaczmarek     | Matylda     | 2006-05-17        |
-- +-----+---------------+-------------+-------------------+
-- | 219 | Wójcik       | Igor        | 2017-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 220 | Szymański    | Igor        | 1996-08-31        |
-- +-----+---------------+-------------+-------------------+
-- | 221 | Krawczyk      | Paulina     | 2015-09-11        |
-- +-----+---------------+-------------+-------------------+
-- | 222 | Krawczyk      | Marta       | 2010-11-04        |
-- +-----+---------------+-------------+-------------------+
-- | 223 | Kaczmarek     | Mateusz     | 2010-03-06        |
-- +-----+---------------+-------------+-------------------+
-- | 224 | Lewandowski   | Stanisław  | 1998-05-07        |
-- +-----+---------------+-------------+-------------------+
-- | 225 | Nowak         | Adam        | 2012-09-23        |
-- +-----+---------------+-------------+-------------------+
-- | 226 | Lewandowska   | Sara        | 2014-03-08        |
-- +-----+---------------+-------------+-------------------+
-- | 227 | Kozłowski    | Piotr       | 1997-09-22        |
-- +-----+---------------+-------------+-------------------+
-- | 228 | Dąbrowski    | Nikodem     | 2010-05-23        |
-- +-----+---------------+-------------+-------------------+
-- | 229 | Kaczmarek     | Nikodem     | 1991-06-21        |
-- +-----+---------------+-------------+-------------------+
-- | 230 | Kamiński     | Piotr       | 1994-02-13        |
-- +-----+---------------+-------------+-------------------+
-- | 231 | Mazur         | Igor        | 2017-03-12        |
-- +-----+---------------+-------------+-------------------+
-- | 232 | Wojciechowski | Wiktor      | 1998-12-28        |
-- +-----+---------------+-------------+-------------------+
-- | 233 | Szymańska    | Róża      | 2012-10-11        |
-- +-----+---------------+-------------+-------------------+
-- | 234 | Dąbrowska    | Małgorzata | 2009-02-15        |
-- +-----+---------------+-------------+-------------------+
-- | 235 | Grabowska     | Izabela     | 1995-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 236 | Lewandowski   | Marcel      | 2015-11-19        |
-- +-----+---------------+-------------+-------------------+
-- | 237 | Krawczyk      | Małgorzata | 2016-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 238 | Wójcik       | Izabela     | 2013-10-11        |
-- +-----+---------------+-------------+-------------------+
-- | 239 | Kowalski      | Stanisław  | 2010-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 240 | Nowak         | Wiktor      | 2007-06-29        |
-- +-----+---------------+-------------+-------------------+
-- | 241 | Kwiatkowska   | Matylda     | 2015-07-13        |
-- +-----+---------------+-------------+-------------------+
-- | 242 | Jankowska     | Paulina     | 1994-11-17        |
-- +-----+---------------+-------------+-------------------+
-- | 243 | Mazur         | Adam        | 2000-11-23        |
-- +-----+---------------+-------------+-------------------+
-- | 244 | Wójcik       | Nikodem     | 2004-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 245 | Nowak         | Mateusz     | 2006-06-13        |
-- +-----+---------------+-------------+-------------------+
-- | 246 | Wójcik       | Igor        | 1991-11-02        |
-- +-----+---------------+-------------+-------------------+
-- | 247 | Lewandowska   | Klaudia     | 1992-06-14        |
-- +-----+---------------+-------------+-------------------+
-- | 248 | Szymańska    | Małgorzata | 2006-01-21        |
-- +-----+---------------+-------------+-------------------+
-- | 249 | Woźniak      | Klaudia     | 2005-07-20        |
-- +-----+---------------+-------------+-------------------+

-- %% [markdown]
-- Zapytanie i wynik zapytania:

-- %%
SELECT users.name,users.surname, COUNT(borrowings.ID) AS books_borrowed FROM users JOIN borrowings 
ON users.ID=borrowings.user_id GROUP BY users.ID HAVING books_borrowed>8.0;
-- Out:
-- +-------------+---------------+----------------+
-- | name        | surname       | books_borrowed |
-- +-------------+---------------+----------------+
-- | Klaudia     | Lewandowska   | 10             |
-- +-------------+---------------+----------------+
-- | Paulina     | Wojciechowska | 13             |
-- +-------------+---------------+----------------+
-- | Marcel      | Kamiński     | 11             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Piotrowska    | 13             |
-- +-------------+---------------+----------------+
-- | Marta       | Kowalska      | 10             |
-- +-------------+---------------+----------------+
-- | Paulina     | Krawczyk      | 10             |
-- +-------------+---------------+----------------+
-- | Róża      | Dąbrowska    | 14             |
-- +-------------+---------------+----------------+
-- | Joanna      | Grabowska     | 9              |
-- +-------------+---------------+----------------+
-- | Sara        | Kaczmarek     | 14             |
-- +-------------+---------------+----------------+
-- | Izabela     | Piotrowska    | 9              |
-- +-------------+---------------+----------------+
-- | Małgorzata | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Adam        | Kowalczyk     | 13             |
-- +-------------+---------------+----------------+
-- | Aniela      | Dąbrowska    | 13             |
-- +-------------+---------------+----------------+
-- | Izabela     | Wójcik       | 9              |
-- +-------------+---------------+----------------+
-- | Izabela     | Kwiatkowska   | 10             |
-- +-------------+---------------+----------------+
-- | Izabela     | Kamińska     | 10             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Wiśniewska   | 9              |
-- +-------------+---------------+----------------+
-- | Igor        | Dąbrowski    | 10             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Krawczyk      | 14             |
-- +-------------+---------------+----------------+
-- | Sara        | Kwiatkowska   | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Wójcik       | 13             |
-- +-------------+---------------+----------------+
-- | Mateusz     | Grabowski     | 10             |
-- +-------------+---------------+----------------+
-- | Michał     | Krawczyk      | 10             |
-- +-------------+---------------+----------------+
-- | Piotr       | Szymański    | 12             |
-- +-------------+---------------+----------------+
-- | Leon        | Kamiński     | 11             |
-- +-------------+---------------+----------------+
-- | Marcel      | Krawczyk      | 9              |
-- +-------------+---------------+----------------+
-- | Leon        | Wojciechowski | 9              |
-- +-------------+---------------+----------------+
-- | Liliana     | Wójcik       | 13             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Wiśniewska   | 10             |
-- +-------------+---------------+----------------+
-- | Piotr       | Piotrowski    | 9              |
-- +-------------+---------------+----------------+
-- | Róża      | Kowalska      | 11             |
-- +-------------+---------------+----------------+
-- | Aniela      | Nowak         | 14             |
-- +-------------+---------------+----------------+
-- | Joanna      | Piotrowska    | 11             |
-- +-------------+---------------+----------------+
-- | Liliana     | Zielińska    | 10             |
-- +-------------+---------------+----------------+
-- | Paulina     | Jankowska     | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Piotrowski    | 9              |
-- +-------------+---------------+----------------+
-- | Piotr       | Piotrowski    | 14             |
-- +-------------+---------------+----------------+
-- | Liliana     | Wiśniewska   | 9              |
-- +-------------+---------------+----------------+
-- | Aniela      | Nowak         | 9              |
-- +-------------+---------------+----------------+
-- | Marta       | Grabowska     | 10             |
-- +-------------+---------------+----------------+
-- | Matylda     | Kowalska      | 9              |
-- +-------------+---------------+----------------+
-- | Matylda     | Grabowska     | 10             |
-- +-------------+---------------+----------------+
-- | Stanisław  | Zieliński    | 12             |
-- +-------------+---------------+----------------+
-- | Piotr       | Grabowski     | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Kowalski      | 12             |
-- +-------------+---------------+----------------+
-- | Adam        | Woźniak      | 10             |
-- +-------------+---------------+----------------+
-- | Sara        | Wójcik       | 9              |
-- +-------------+---------------+----------------+
-- | Igor        | Kowalczyk     | 13             |
-- +-------------+---------------+----------------+
-- | Róża      | Kowalska      | 12             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Kwiatkowska   | 11             |
-- +-------------+---------------+----------------+
-- | Aniela      | Lewandowska   | 15             |
-- +-------------+---------------+----------------+
-- | Marta       | Kaczmarek     | 10             |
-- +-------------+---------------+----------------+
-- | Izabela     | Zielińska    | 10             |
-- +-------------+---------------+----------------+
-- | Igor        | Szymański    | 9              |
-- +-------------+---------------+----------------+
-- | Marta       | Krawczyk      | 9              |
-- +-------------+---------------+----------------+
-- | Mateusz     | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Nikodem     | Kaczmarek     | 12             |
-- +-------------+---------------+----------------+
-- | Piotr       | Kamiński     | 12             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Dąbrowska    | 9              |
-- +-------------+---------------+----------------+
-- | Izabela     | Grabowska     | 9              |
-- +-------------+---------------+----------------+
-- | Izabela     | Wójcik       | 12             |
-- +-------------+---------------+----------------+
-- | Wiktor      | Nowak         | 9              |
-- +-------------+---------------+----------------+
-- | Paulina     | Jankowska     | 9              |
-- +-------------+---------------+----------------+
-- | Adam        | Mazur         | 10             |
-- +-------------+---------------+----------------+
-- | Klaudia     | Lewandowska   | 10             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Szymańska    | 12             |
-- +-------------+---------------+----------------+
-- | Piotr       | Woźniak      | 9              |
-- +-------------+---------------+----------------+
-- | Piotr       | Kowalczyk     | 11             |
-- +-------------+---------------+----------------+
-- | Michał     | Kozłowski    | 10             |
-- +-------------+---------------+----------------+
-- | Matylda     | Mazur         | 13             |
-- +-------------+---------------+----------------+
-- | Róża      | Szymańska    | 13             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Kaczmarek     | 14             |
-- +-------------+---------------+----------------+
-- | Marcel      | Lewandowski   | 12             |
-- +-------------+---------------+----------------+
-- | Leon        | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Klaudia     | Szymańska    | 10             |
-- +-------------+---------------+----------------+
-- | Mateusz     | Szymański    | 9              |
-- +-------------+---------------+----------------+
-- | Joanna      | Kwiatkowska   | 13             |
-- +-------------+---------------+----------------+
-- | Joanna      | Wojciechowska | 9              |
-- +-------------+---------------+----------------+
-- | Paulina     | Jankowska     | 9              |
-- +-------------+---------------+----------------+
-- | Róża      | Woźniak      | 9              |
-- +-------------+---------------+----------------+
-- | Michał     | Zieliński    | 10             |
-- +-------------+---------------+----------------+
-- | Aniela      | Kaczmarek     | 13             |
-- +-------------+---------------+----------------+
-- | Matylda     | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Klaudia     | Szymańska    | 10             |
-- +-------------+---------------+----------------+
-- | Wiktor      | Wójcik       | 10             |
-- +-------------+---------------+----------------+
-- | Klaudia     | Grabowska     | 10             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Woźniak      | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Kozłowski    | 10             |
-- +-------------+---------------+----------------+
-- | Piotr       | Kowalski      | 10             |
-- +-------------+---------------+----------------+
-- | Joanna      | Kaczmarek     | 10             |
-- +-------------+---------------+----------------+
-- | Mateusz     | Nowak         | 10             |
-- +-------------+---------------+----------------+
-- | Klaudia     | Dąbrowska    | 11             |
-- +-------------+---------------+----------------+
-- | Marta       | Kwiatkowska   | 9              |
-- +-------------+---------------+----------------+
-- | Klaudia     | Wójcik       | 12             |
-- +-------------+---------------+----------------+
-- | Izabela     | Wójcik       | 11             |
-- +-------------+---------------+----------------+
-- | Piotr       | Lewandowski   | 18             |
-- +-------------+---------------+----------------+
-- | Izabela     | Kaczmarek     | 10             |
-- +-------------+---------------+----------------+
-- | Michał     | Kwiatkowski   | 11             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Mazur         | 9              |
-- +-------------+---------------+----------------+

-- %%
SELECT users.name,users.surname, COUNT(borrowings.ID) AS books_borrowed FROM users JOIN borrowings 
ON users.ID=borrowings.user_id GROUP BY users.ID HAVING books_borrowed>
(
    SELECT 1.0*COUNT(DISTINCT borrowings.ID)/COUNT(DISTINCT borrowings.user_id) FROM borrowings
)
;
-- Out:
-- +-------------+---------------+----------------+
-- | name        | surname       | books_borrowed |
-- +-------------+---------------+----------------+
-- | Klaudia     | Lewandowska   | 10             |
-- +-------------+---------------+----------------+
-- | Paulina     | Wojciechowska | 13             |
-- +-------------+---------------+----------------+
-- | Marcel      | Kamiński     | 11             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Piotrowska    | 13             |
-- +-------------+---------------+----------------+
-- | Marta       | Kowalska      | 10             |
-- +-------------+---------------+----------------+
-- | Paulina     | Krawczyk      | 10             |
-- +-------------+---------------+----------------+
-- | Róża      | Dąbrowska    | 14             |
-- +-------------+---------------+----------------+
-- | Joanna      | Grabowska     | 9              |
-- +-------------+---------------+----------------+
-- | Sara        | Kaczmarek     | 14             |
-- +-------------+---------------+----------------+
-- | Izabela     | Piotrowska    | 9              |
-- +-------------+---------------+----------------+
-- | Małgorzata | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Adam        | Kowalczyk     | 13             |
-- +-------------+---------------+----------------+
-- | Aniela      | Dąbrowska    | 13             |
-- +-------------+---------------+----------------+
-- | Izabela     | Wójcik       | 9              |
-- +-------------+---------------+----------------+
-- | Izabela     | Kwiatkowska   | 10             |
-- +-------------+---------------+----------------+
-- | Izabela     | Kamińska     | 10             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Wiśniewska   | 9              |
-- +-------------+---------------+----------------+
-- | Igor        | Dąbrowski    | 10             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Krawczyk      | 14             |
-- +-------------+---------------+----------------+
-- | Sara        | Kwiatkowska   | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Wójcik       | 13             |
-- +-------------+---------------+----------------+
-- | Mateusz     | Grabowski     | 10             |
-- +-------------+---------------+----------------+
-- | Michał     | Krawczyk      | 10             |
-- +-------------+---------------+----------------+
-- | Piotr       | Szymański    | 12             |
-- +-------------+---------------+----------------+
-- | Leon        | Kamiński     | 11             |
-- +-------------+---------------+----------------+
-- | Marcel      | Krawczyk      | 9              |
-- +-------------+---------------+----------------+
-- | Leon        | Wojciechowski | 9              |
-- +-------------+---------------+----------------+
-- | Liliana     | Wójcik       | 13             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Wiśniewska   | 10             |
-- +-------------+---------------+----------------+
-- | Piotr       | Piotrowski    | 9              |
-- +-------------+---------------+----------------+
-- | Róża      | Kowalska      | 11             |
-- +-------------+---------------+----------------+
-- | Aniela      | Nowak         | 14             |
-- +-------------+---------------+----------------+
-- | Joanna      | Piotrowska    | 11             |
-- +-------------+---------------+----------------+
-- | Liliana     | Zielińska    | 10             |
-- +-------------+---------------+----------------+
-- | Paulina     | Jankowska     | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Piotrowski    | 9              |
-- +-------------+---------------+----------------+
-- | Piotr       | Piotrowski    | 14             |
-- +-------------+---------------+----------------+
-- | Liliana     | Wiśniewska   | 9              |
-- +-------------+---------------+----------------+
-- | Aniela      | Nowak         | 9              |
-- +-------------+---------------+----------------+
-- | Marta       | Grabowska     | 10             |
-- +-------------+---------------+----------------+
-- | Matylda     | Kowalska      | 9              |
-- +-------------+---------------+----------------+
-- | Matylda     | Grabowska     | 10             |
-- +-------------+---------------+----------------+
-- | Stanisław  | Zieliński    | 12             |
-- +-------------+---------------+----------------+
-- | Piotr       | Grabowski     | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Kowalski      | 12             |
-- +-------------+---------------+----------------+
-- | Adam        | Woźniak      | 10             |
-- +-------------+---------------+----------------+
-- | Sara        | Wójcik       | 9              |
-- +-------------+---------------+----------------+
-- | Igor        | Kowalczyk     | 13             |
-- +-------------+---------------+----------------+
-- | Róża      | Kowalska      | 12             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Kwiatkowska   | 11             |
-- +-------------+---------------+----------------+
-- | Aniela      | Lewandowska   | 15             |
-- +-------------+---------------+----------------+
-- | Marta       | Kaczmarek     | 10             |
-- +-------------+---------------+----------------+
-- | Izabela     | Zielińska    | 10             |
-- +-------------+---------------+----------------+
-- | Igor        | Szymański    | 9              |
-- +-------------+---------------+----------------+
-- | Marta       | Krawczyk      | 9              |
-- +-------------+---------------+----------------+
-- | Mateusz     | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Nikodem     | Kaczmarek     | 12             |
-- +-------------+---------------+----------------+
-- | Piotr       | Kamiński     | 12             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Dąbrowska    | 9              |
-- +-------------+---------------+----------------+
-- | Izabela     | Grabowska     | 9              |
-- +-------------+---------------+----------------+
-- | Izabela     | Wójcik       | 12             |
-- +-------------+---------------+----------------+
-- | Wiktor      | Nowak         | 9              |
-- +-------------+---------------+----------------+
-- | Paulina     | Jankowska     | 9              |
-- +-------------+---------------+----------------+
-- | Adam        | Mazur         | 10             |
-- +-------------+---------------+----------------+
-- | Klaudia     | Lewandowska   | 10             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Szymańska    | 12             |
-- +-------------+---------------+----------------+
-- | Piotr       | Woźniak      | 9              |
-- +-------------+---------------+----------------+
-- | Piotr       | Kowalczyk     | 11             |
-- +-------------+---------------+----------------+
-- | Michał     | Kozłowski    | 10             |
-- +-------------+---------------+----------------+
-- | Matylda     | Mazur         | 13             |
-- +-------------+---------------+----------------+
-- | Róża      | Szymańska    | 13             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Kaczmarek     | 14             |
-- +-------------+---------------+----------------+
-- | Marcel      | Lewandowski   | 12             |
-- +-------------+---------------+----------------+
-- | Leon        | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Klaudia     | Szymańska    | 10             |
-- +-------------+---------------+----------------+
-- | Mateusz     | Szymański    | 9              |
-- +-------------+---------------+----------------+
-- | Joanna      | Kwiatkowska   | 13             |
-- +-------------+---------------+----------------+
-- | Joanna      | Wojciechowska | 9              |
-- +-------------+---------------+----------------+
-- | Paulina     | Jankowska     | 9              |
-- +-------------+---------------+----------------+
-- | Róża      | Woźniak      | 9              |
-- +-------------+---------------+----------------+
-- | Michał     | Zieliński    | 10             |
-- +-------------+---------------+----------------+
-- | Aniela      | Kaczmarek     | 13             |
-- +-------------+---------------+----------------+
-- | Matylda     | Kaczmarek     | 9              |
-- +-------------+---------------+----------------+
-- | Klaudia     | Szymańska    | 10             |
-- +-------------+---------------+----------------+
-- | Wiktor      | Wójcik       | 10             |
-- +-------------+---------------+----------------+
-- | Klaudia     | Grabowska     | 10             |
-- +-------------+---------------+----------------+
-- | Małgorzata | Woźniak      | 9              |
-- +-------------+---------------+----------------+
-- | Stanisław  | Kozłowski    | 10             |
-- +-------------+---------------+----------------+
-- | Piotr       | Kowalski      | 10             |
-- +-------------+---------------+----------------+
-- | Joanna      | Kaczmarek     | 10             |
-- +-------------+---------------+----------------+
-- | Mateusz     | Nowak         | 10             |
-- +-------------+---------------+----------------+
-- | Klaudia     | Dąbrowska    | 11             |
-- +-------------+---------------+----------------+
-- | Marta       | Kwiatkowska   | 9              |
-- +-------------+---------------+----------------+
-- | Klaudia     | Wójcik       | 12             |
-- +-------------+---------------+----------------+
-- | Izabela     | Wójcik       | 11             |
-- +-------------+---------------+----------------+
-- | Piotr       | Lewandowski   | 18             |
-- +-------------+---------------+----------------+
-- | Izabela     | Kaczmarek     | 10             |
-- +-------------+---------------+----------------+
-- | Michał     | Kwiatkowski   | 11             |
-- +-------------+---------------+----------------+
-- | Katarzyna   | Mazur         | 9              |
-- +-------------+---------------+----------------+

-- %% [markdown]
-- ### Podzapytania w `SELECT`

-- %% [markdown]
-- #### Przykład
--
-- **Analogicznie do poprzedniego przypadku - jeśli podzapytanie zwraca pojedynczą wartość, możemy je użyć jako jedną z kolumn w głównym zapytaniu.**

-- %% [markdown]
-- Tabela **`Users`**:

-- %%
SELECT * FROM users;
-- Out:
-- +-----+---------------+-------------+-------------------+
-- | ID  | surname       | name        | registration_date |
-- +-----+---------------+-------------+-------------------+
-- | 0   | Piotrowski    | Igor        | 1994-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 1   | Lewandowska   | Róża      | 2008-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 2   | Woźniak      | Adam        | 1999-08-09        |
-- +-----+---------------+-------------+-------------------+
-- | 3   | Kowalczyk     | Michał     | 2011-01-22        |
-- +-----+---------------+-------------+-------------------+
-- | 4   | Kaczmarek     | Leon        | 1990-08-15        |
-- +-----+---------------+-------------+-------------------+
-- | 5   | Kwiatkowska   | Joanna      | 2013-06-16        |
-- +-----+---------------+-------------+-------------------+
-- | 6   | Zieliński    | Michał     | 1990-09-21        |
-- +-----+---------------+-------------+-------------------+
-- | 7   | Woźniak      | Małgorzata | 1991-10-03        |
-- +-----+---------------+-------------+-------------------+
-- | 8   | Kaczmarek     | Joanna      | 2001-05-31        |
-- +-----+---------------+-------------+-------------------+
-- | 9   | Wójcik       | Izabela     | 2013-03-07        |
-- +-----+---------------+-------------+-------------------+
-- | 10  | Lewandowska   | Klaudia     | 2004-09-14        |
-- +-----+---------------+-------------+-------------------+
-- | 11  | Piotrowski    | Igor        | 1996-08-08        |
-- +-----+---------------+-------------+-------------------+
-- | 12  | Nowak         | Róża      | 2007-04-08        |
-- +-----+---------------+-------------+-------------------+
-- | 13  | Kowalska      | Izabela     | 2003-10-21        |
-- +-----+---------------+-------------+-------------------+
-- | 14  | Kamińska     | Izabela     | 2013-07-10        |
-- +-----+---------------+-------------+-------------------+
-- | 15  | Kowalczyk     | Mateusz     | 2004-08-13        |
-- +-----+---------------+-------------+-------------------+
-- | 16  | Mazur         | Michał     | 1995-03-01        |
-- +-----+---------------+-------------+-------------------+
-- | 17  | Piotrowski    | Piotr       | 1991-08-31        |
-- +-----+---------------+-------------+-------------------+
-- | 18  | Lewandowski   | Adam        | 1998-08-08        |
-- +-----+---------------+-------------+-------------------+
-- | 19  | Kowalska      | Matylda     | 2001-07-05        |
-- +-----+---------------+-------------+-------------------+
-- | 20  | Lewandowska   | Katarzyna   | 2010-03-31        |
-- +-----+---------------+-------------+-------------------+
-- | 21  | Lewandowska   | Aniela      | 2004-03-18        |
-- +-----+---------------+-------------+-------------------+
-- | 22  | Szymański    | Leon        | 2007-11-18        |
-- +-----+---------------+-------------+-------------------+
-- | 23  | Kwiatkowska   | Joanna      | 1996-01-27        |
-- +-----+---------------+-------------+-------------------+
-- | 24  | Wójcik       | Wiktor      | 1999-01-19        |
-- +-----+---------------+-------------+-------------------+
-- | 25  | Woźniak      | Piotr       | 2003-06-09        |
-- +-----+---------------+-------------+-------------------+
-- | 26  | Wójcik       | Stanisław  | 2004-07-16        |
-- +-----+---------------+-------------+-------------------+
-- | 27  | Jankowska     | Paulina     | 1998-12-15        |
-- +-----+---------------+-------------+-------------------+
-- | 28  | Kowalczyk     | Piotr       | 2017-08-20        |
-- +-----+---------------+-------------+-------------------+
-- | 29  | Wójcik       | Adam        | 1992-06-11        |
-- +-----+---------------+-------------+-------------------+
-- | 30  | Kozłowski    | Michał     | 2016-10-24        |
-- +-----+---------------+-------------+-------------------+
-- | 31  | Mazur         | Matylda     | 2001-10-18        |
-- +-----+---------------+-------------+-------------------+
-- | 32  | Wiśniewska   | Katarzyna   | 2012-07-22        |
-- +-----+---------------+-------------+-------------------+
-- | 33  | Jankowska     | Joanna      | 2006-06-17        |
-- +-----+---------------+-------------+-------------------+
-- | 34  | Szymańska    | Róża      | 1991-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 35  | Dąbrowski    | Piotr       | 1990-01-02        |
-- +-----+---------------+-------------+-------------------+
-- | 36  | Kaczmarek     | Małgorzata | 1992-03-16        |
-- +-----+---------------+-------------+-------------------+
-- | 37  | Mazur         | Marcel      | 2005-10-09        |
-- +-----+---------------+-------------+-------------------+
-- | 38  | Lewandowski   | Marcel      | 2006-09-01        |
-- +-----+---------------+-------------+-------------------+
-- | 39  | Kozłowski    | Adam        | 2012-11-13        |
-- +-----+---------------+-------------+-------------------+
-- | 40  | Szymańska    | Klaudia     | 1990-06-01        |
-- +-----+---------------+-------------+-------------------+
-- | 41  | Grabowska     | Liliana     | 1991-11-19        |
-- +-----+---------------+-------------+-------------------+
-- | 42  | Mazur         | Katarzyna   | 2007-01-15        |
-- +-----+---------------+-------------+-------------------+
-- | 43  | Szymański    | Mateusz     | 1994-07-26        |
-- +-----+---------------+-------------+-------------------+
-- | 44  | Nowak         | Klaudia     | 1992-10-24        |
-- +-----+---------------+-------------+-------------------+
-- | 45  | Grabowski     | Piotr       | 2017-01-14        |
-- +-----+---------------+-------------+-------------------+
-- | 46  | Woźniak      | Marta       | 2009-02-27        |
-- +-----+---------------+-------------+-------------------+
-- | 47  | Nowak         | Sara        | 2001-03-25        |
-- +-----+---------------+-------------+-------------------+
-- | 48  | Piotrowski    | Wiktor      | 2013-06-25        |
-- +-----+---------------+-------------+-------------------+
-- | 49  | Grabowska     | Liliana     | 2015-04-27        |
-- +-----+---------------+-------------+-------------------+
-- | 50  | Zielińska    | Matylda     | 1990-11-08        |
-- +-----+---------------+-------------+-------------------+
-- | 51  | Mazur         | Mateusz     | 2001-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 52  | Lewandowski   | Leon        | 2006-06-17        |
-- +-----+---------------+-------------+-------------------+
-- | 53  | Dąbrowski    | Adam        | 1990-03-21        |
-- +-----+---------------+-------------+-------------------+
-- | 54  | Wojciechowska | Joanna      | 2017-07-29        |
-- +-----+---------------+-------------+-------------------+
-- | 55  | Kozłowski    | Wiktor      | 2014-03-05        |
-- +-----+---------------+-------------+-------------------+
-- | 56  | Kozłowska    | Katarzyna   | 2016-08-02        |
-- +-----+---------------+-------------+-------------------+
-- | 57  | Jankowska     | Paulina     | 1992-03-01        |
-- +-----+---------------+-------------+-------------------+
-- | 58  | Krawczyk      | Adam        | 2013-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 59  | Woźniak      | Róża      | 2005-07-23        |
-- +-----+---------------+-------------+-------------------+
-- | 60  | Kaczmarek     | Aniela      | 2012-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 61  | Kaczmarek     | Matylda     | 2015-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 62  | Kamińska     | Klaudia     | 1999-09-14        |
-- +-----+---------------+-------------+-------------------+
-- | 63  | Kaczmarek     | Piotr       | 1999-04-26        |
-- +-----+---------------+-------------+-------------------+
-- | 64  | Mazur         | Wiktor      | 1990-12-22        |
-- +-----+---------------+-------------+-------------------+
-- | 65  | Dąbrowska    | Katarzyna   | 2017-11-27        |
-- +-----+---------------+-------------+-------------------+
-- | 66  | Kowalska      | Klaudia     | 1990-12-27        |
-- +-----+---------------+-------------+-------------------+
-- | 67  | Szymańska    | Klaudia     | 2007-08-17        |
-- +-----+---------------+-------------+-------------------+
-- | 68  | Wójcik       | Wiktor      | 2016-05-20        |
-- +-----+---------------+-------------+-------------------+
-- | 69  | Grabowska     | Klaudia     | 2007-06-26        |
-- +-----+---------------+-------------+-------------------+
-- | 70  | Piotrowska    | Klaudia     | 1992-08-28        |
-- +-----+---------------+-------------+-------------------+
-- | 71  | Kozłowski    | Stanisław  | 2014-06-27        |
-- +-----+---------------+-------------+-------------------+
-- | 72  | Mazur         | Joanna      | 2012-12-17        |
-- +-----+---------------+-------------+-------------------+
-- | 73  | Nowak         | Adam        | 1997-05-11        |
-- +-----+---------------+-------------+-------------------+
-- | 74  | Wiśniewska   | Małgorzata | 2003-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 75  | Kozłowska    | Joanna      | 2013-04-17        |
-- +-----+---------------+-------------+-------------------+
-- | 76  | Kowalski      | Piotr       | 2011-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 77  | Jankowski     | Marcel      | 2017-12-15        |
-- +-----+---------------+-------------+-------------------+
-- | 78  | Lewandowska   | Marta       | 2010-12-13        |
-- +-----+---------------+-------------+-------------------+
-- | 79  | Kozłowska    | Paulina     | 2017-08-20        |
-- +-----+---------------+-------------+-------------------+
-- | 80  | Nowak         | Mateusz     | 1995-11-25        |
-- +-----+---------------+-------------+-------------------+
-- | 81  | Dąbrowska    | Klaudia     | 2015-06-18        |
-- +-----+---------------+-------------+-------------------+
-- | 82  | Grabowska     | Klaudia     | 2016-10-26        |
-- +-----+---------------+-------------+-------------------+
-- | 83  | Kwiatkowska   | Marta       | 2012-05-29        |
-- +-----+---------------+-------------+-------------------+
-- | 84  | Krawczyk      | Nikodem     | 1995-05-02        |
-- +-----+---------------+-------------+-------------------+
-- | 85  | Kaczmarek     | Michał     | 2009-12-30        |
-- +-----+---------------+-------------+-------------------+
-- | 86  | Wójcik       | Klaudia     | 2003-11-08        |
-- +-----+---------------+-------------+-------------------+
-- | 87  | Dąbrowski    | Igor        | 2004-01-19        |
-- +-----+---------------+-------------+-------------------+
-- | 88  | Kaczmarek     | Michał     | 1990-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 89  | Kowalczyk     | Aniela      | 1991-03-11        |
-- +-----+---------------+-------------+-------------------+
-- | 90  | Lewandowski   | Piotr       | 2009-08-09        |
-- +-----+---------------+-------------+-------------------+
-- | 91  | Kaczmarek     | Izabela     | 2013-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 92  | Nowak         | Leon        | 2016-05-06        |
-- +-----+---------------+-------------+-------------------+
-- | 93  | Kwiatkowski   | Michał     | 2011-10-10        |
-- +-----+---------------+-------------+-------------------+
-- | 94  | Wiśniewska   | Małgorzata | 2012-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 95  | Mazur         | Katarzyna   | 2012-11-27        |
-- +-----+---------------+-------------+-------------------+
-- | 96  | Nowak         | Nikodem     | 2014-03-22        |
-- +-----+---------------+-------------+-------------------+
-- | 97  | Kaczmarek     | Małgorzata | 2001-02-10        |
-- +-----+---------------+-------------+-------------------+
-- | 98  | Lewandowska   | Małgorzata | 1990-07-21        |
-- +-----+---------------+-------------+-------------------+
-- | 99  | Grabowska     | Małgorzata | 1998-11-16        |
-- +-----+---------------+-------------+-------------------+
-- | 100 | Grabowski     | Mateusz     | 2007-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 101 | Wojciechowska | Paulina     | 2002-07-04        |
-- +-----+---------------+-------------+-------------------+
-- | 102 | Woźniak      | Marta       | 2008-03-07        |
-- +-----+---------------+-------------+-------------------+
-- | 103 | Dąbrowska    | Joanna      | 2006-01-03        |
-- +-----+---------------+-------------+-------------------+
-- | 104 | Kamiński     | Marcel      | 2007-01-12        |
-- +-----+---------------+-------------+-------------------+
-- | 105 | Nowak         | Michał     | 2005-06-13        |
-- +-----+---------------+-------------+-------------------+
-- | 106 | Wiśniewska   | Marta       | 1991-10-27        |
-- +-----+---------------+-------------+-------------------+
-- | 107 | Zieliński    | Leon        | 2014-06-01        |
-- +-----+---------------+-------------+-------------------+
-- | 108 | Wojciechowski | Wiktor      | 1992-04-04        |
-- +-----+---------------+-------------+-------------------+
-- | 109 | Piotrowska    | Małgorzata | 2009-04-21        |
-- +-----+---------------+-------------+-------------------+
-- | 110 | Kowalska      | Paulina     | 1998-01-15        |
-- +-----+---------------+-------------+-------------------+
-- | 111 | Kwiatkowska   | Paulina     | 2015-04-29        |
-- +-----+---------------+-------------+-------------------+
-- | 112 | Grabowska     | Aniela      | 2015-08-13        |
-- +-----+---------------+-------------+-------------------+
-- | 113 | Kowalczyk     | Katarzyna   | 2017-03-21        |
-- +-----+---------------+-------------+-------------------+
-- | 114 | Nowak         | Liliana     | 1997-04-04        |
-- +-----+---------------+-------------+-------------------+
-- | 115 | Kaczmarek     | Leon        | 2016-03-18        |
-- +-----+---------------+-------------+-------------------+
-- | 116 | Kowalczyk     | Leon        | 2009-04-06        |
-- +-----+---------------+-------------+-------------------+
-- | 117 | Kowalska      | Marta       | 2011-01-13        |
-- +-----+---------------+-------------+-------------------+
-- | 118 | Kowalska      | Joanna      | 1992-09-03        |
-- +-----+---------------+-------------+-------------------+
-- | 119 | Krawczyk      | Paulina     | 2008-11-04        |
-- +-----+---------------+-------------+-------------------+
-- | 120 | Dąbrowska    | Róża      | 1999-10-25        |
-- +-----+---------------+-------------+-------------------+
-- | 121 | Grabowska     | Joanna      | 2009-10-25        |
-- +-----+---------------+-------------+-------------------+
-- | 122 | Grabowski     | Igor        | 1990-10-07        |
-- +-----+---------------+-------------+-------------------+
-- | 123 | Kaczmarek     | Sara        | 2009-11-05        |
-- +-----+---------------+-------------+-------------------+
-- | 124 | Lewandowska   | Izabela     | 2015-02-13        |
-- +-----+---------------+-------------+-------------------+
-- | 125 | Piotrowska    | Izabela     | 2017-08-14        |
-- +-----+---------------+-------------+-------------------+
-- | 126 | Dąbrowska    | Róża      | 2001-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 127 | Nowak         | Katarzyna   | 2006-07-26        |
-- +-----+---------------+-------------+-------------------+
-- | 128 | Kaczmarek     | Małgorzata | 2017-03-04        |
-- +-----+---------------+-------------+-------------------+
-- | 129 | Kowalczyk     | Adam        | 2017-09-05        |
-- +-----+---------------+-------------+-------------------+
-- | 130 | Szymański    | Adam        | 2014-12-01        |
-- +-----+---------------+-------------+-------------------+
-- | 131 | Woźniak      | Nikodem     | 1991-10-10        |
-- +-----+---------------+-------------+-------------------+
-- | 132 | Wojciechowska | Katarzyna   | 2004-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 133 | Kaczmarek     | Igor        | 2007-08-11        |
-- +-----+---------------+-------------+-------------------+
-- | 134 | Dąbrowski    | Nikodem     | 2011-01-25        |
-- +-----+---------------+-------------+-------------------+
-- | 135 | Dąbrowska    | Aniela      | 1998-10-03        |
-- +-----+---------------+-------------+-------------------+
-- | 136 | Wójcik       | Izabela     | 2006-05-17        |
-- +-----+---------------+-------------+-------------------+
-- | 137 | Piotrowska    | Izabela     | 1998-04-23        |
-- +-----+---------------+-------------+-------------------+
-- | 138 | Kwiatkowska   | Izabela     | 2009-04-03        |
-- +-----+---------------+-------------+-------------------+
-- | 139 | Kowalska      | Małgorzata | 2016-05-30        |
-- +-----+---------------+-------------+-------------------+
-- | 140 | Nowak         | Mateusz     | 2011-04-12        |
-- +-----+---------------+-------------+-------------------+
-- | 141 | Zielińska    | Róża      | 2001-09-13        |
-- +-----+---------------+-------------+-------------------+
-- | 142 | Wiśniewska   | Katarzyna   | 2009-10-29        |
-- +-----+---------------+-------------+-------------------+
-- | 143 | Wiśniewski   | Michał     | 2010-03-05        |
-- +-----+---------------+-------------+-------------------+
-- | 144 | Dąbrowska    | Aniela      | 1998-04-01        |
-- +-----+---------------+-------------+-------------------+
-- | 145 | Kaczmarek     | Róża      | 2005-05-09        |
-- +-----+---------------+-------------+-------------------+
-- | 146 | Kamiński     | Piotr       | 1992-11-29        |
-- +-----+---------------+-------------+-------------------+
-- | 147 | Woźniak      | Matylda     | 2008-02-29        |
-- +-----+---------------+-------------+-------------------+
-- | 148 | Dąbrowski    | Igor        | 1996-08-25        |
-- +-----+---------------+-------------+-------------------+
-- | 149 | Lewandowski   | Marcel      | 2009-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 150 | Jankowska     | Małgorzata | 2000-09-13        |
-- +-----+---------------+-------------+-------------------+
-- | 151 | Kamiński     | Wiktor      | 1993-09-11        |
-- +-----+---------------+-------------+-------------------+
-- | 152 | Krawczyk      | Katarzyna   | 1996-08-24        |
-- +-----+---------------+-------------+-------------------+
-- | 153 | Mazur         | Adam        | 2002-09-20        |
-- +-----+---------------+-------------+-------------------+
-- | 154 | Kwiatkowska   | Sara        | 2006-10-08        |
-- +-----+---------------+-------------+-------------------+
-- | 155 | Wójcik       | Stanisław  | 2006-06-28        |
-- +-----+---------------+-------------+-------------------+
-- | 156 | Grabowski     | Mateusz     | 1998-03-13        |
-- +-----+---------------+-------------+-------------------+
-- | 157 | Wiśniewska   | Katarzyna   | 2016-11-09        |
-- +-----+---------------+-------------+-------------------+
-- | 158 | Krawczyk      | Michał     | 2007-04-25        |
-- +-----+---------------+-------------+-------------------+
-- | 159 | Szymański    | Piotr       | 1991-05-15        |
-- +-----+---------------+-------------+-------------------+
-- | 160 | Kamiński     | Leon        | 1990-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 161 | Krawczyk      | Marcel      | 2002-09-28        |
-- +-----+---------------+-------------+-------------------+
-- | 162 | Kozłowska    | Aniela      | 1993-10-19        |
-- +-----+---------------+-------------+-------------------+
-- | 163 | Wojciechowski | Leon        | 1994-08-18        |
-- +-----+---------------+-------------+-------------------+
-- | 164 | Wójcik       | Liliana     | 1999-11-10        |
-- +-----+---------------+-------------+-------------------+
-- | 165 | Piotrowski    | Wiktor      | 1999-08-25        |
-- +-----+---------------+-------------+-------------------+
-- | 166 | Wiśniewska   | Katarzyna   | 2005-06-05        |
-- +-----+---------------+-------------+-------------------+
-- | 167 | Kozłowska    | Sara        | 1992-01-03        |
-- +-----+---------------+-------------+-------------------+
-- | 168 | Woźniak      | Adam        | 2004-10-18        |
-- +-----+---------------+-------------+-------------------+
-- | 169 | Nowak         | Adam        | 2017-01-01        |
-- +-----+---------------+-------------+-------------------+
-- | 170 | Kowalska      | Róża      | 2011-11-26        |
-- +-----+---------------+-------------+-------------------+
-- | 171 | Lewandowski   | Michał     | 2015-06-19        |
-- +-----+---------------+-------------+-------------------+
-- | 172 | Nowak         | Izabela     | 2003-05-31        |
-- +-----+---------------+-------------+-------------------+
-- | 173 | Nowak         | Aniela      | 1996-07-10        |
-- +-----+---------------+-------------+-------------------+
-- | 174 | Piotrowska    | Joanna      | 1990-03-26        |
-- +-----+---------------+-------------+-------------------+
-- | 175 | Kowalczyk     | Joanna      | 1992-07-02        |
-- +-----+---------------+-------------+-------------------+
-- | 176 | Zielińska    | Liliana     | 2007-08-12        |
-- +-----+---------------+-------------+-------------------+
-- | 177 | Jankowska     | Paulina     | 2003-05-04        |
-- +-----+---------------+-------------+-------------------+
-- | 178 | Piotrowski    | Stanisław  | 2017-01-09        |
-- +-----+---------------+-------------+-------------------+
-- | 179 | Wiśniewska   | Róża      | 2006-05-12        |
-- +-----+---------------+-------------+-------------------+
-- | 180 | Piotrowski    | Piotr       | 2011-01-30        |
-- +-----+---------------+-------------+-------------------+
-- | 181 | Wójcik       | Nikodem     | 2012-02-03        |
-- +-----+---------------+-------------+-------------------+
-- | 182 | Lewandowska   | Sara        | 2004-12-26        |
-- +-----+---------------+-------------+-------------------+
-- | 183 | Wójcik       | Marcel      | 2015-12-23        |
-- +-----+---------------+-------------+-------------------+
-- | 184 | Jankowska     | Małgorzata | 2012-01-16        |
-- +-----+---------------+-------------+-------------------+
-- | 185 | Wiśniewska   | Liliana     | 2015-06-02        |
-- +-----+---------------+-------------+-------------------+
-- | 186 | Kowalski      | Stanisław  | 2013-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 187 | Nowak         | Aniela      | 2008-11-22        |
-- +-----+---------------+-------------+-------------------+
-- | 188 | Grabowska     | Marta       | 1994-07-14        |
-- +-----+---------------+-------------+-------------------+
-- | 189 | Kowalska      | Paulina     | 2006-02-21        |
-- +-----+---------------+-------------+-------------------+
-- | 190 | Dąbrowska    | Róża      | 2005-08-22        |
-- +-----+---------------+-------------+-------------------+
-- | 191 | Wójcik       | Marcel      | 2015-11-28        |
-- +-----+---------------+-------------+-------------------+
-- | 192 | Grabowska     | Matylda     | 2011-01-26        |
-- +-----+---------------+-------------+-------------------+
-- | 193 | Dąbrowski    | Nikodem     | 2006-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 194 | Nowak         | Piotr       | 2017-05-11        |
-- +-----+---------------+-------------+-------------------+
-- | 195 | Woźniak      | Liliana     | 2017-07-11        |
-- +-----+---------------+-------------+-------------------+
-- | 196 | Zieliński    | Stanisław  | 2000-06-03        |
-- +-----+---------------+-------------+-------------------+
-- | 197 | Grabowski     | Piotr       | 2011-04-19        |
-- +-----+---------------+-------------+-------------------+
-- | 198 | Szymański    | Michał     | 2013-05-10        |
-- +-----+---------------+-------------+-------------------+
-- | 199 | Kowalski      | Stanisław  | 1995-06-12        |
-- +-----+---------------+-------------+-------------------+
-- | 200 | Wójcik       | Sara        | 1990-02-18        |
-- +-----+---------------+-------------+-------------------+
-- | 201 | Kozłowska    | Aniela      | 1999-02-16        |
-- +-----+---------------+-------------+-------------------+
-- | 202 | Kowalski      | Mateusz     | 2013-06-18        |
-- +-----+---------------+-------------+-------------------+
-- | 203 | Kowalczyk     | Igor        | 1996-03-20        |
-- +-----+---------------+-------------+-------------------+
-- | 204 | Kamiński     | Leon        | 1990-07-23        |
-- +-----+---------------+-------------+-------------------+
-- | 205 | Szymańska    | Katarzyna   | 1991-12-28        |
-- +-----+---------------+-------------+-------------------+
-- | 206 | Kowalska      | Róża      | 2017-02-04        |
-- +-----+---------------+-------------+-------------------+
-- | 207 | Wojciechowska | Marta       | 2007-10-01        |
-- +-----+---------------+-------------+-------------------+
-- | 208 | Kwiatkowska   | Małgorzata | 2012-02-23        |
-- +-----+---------------+-------------+-------------------+
-- | 209 | Jankowska     | Joanna      | 1999-08-02        |
-- +-----+---------------+-------------+-------------------+
-- | 210 | Wójcik       | Igor        | 2003-02-18        |
-- +-----+---------------+-------------+-------------------+
-- | 211 | Wojciechowska | Klaudia     | 2010-12-12        |
-- +-----+---------------+-------------+-------------------+
-- | 212 | Kaczmarek     | Marta       | 1998-10-14        |
-- +-----+---------------+-------------+-------------------+
-- | 213 | Krawczyk      | Nikodem     | 1998-10-28        |
-- +-----+---------------+-------------+-------------------+
-- | 214 | Kozłowska    | Klaudia     | 1994-12-27        |
-- +-----+---------------+-------------+-------------------+
-- | 215 | Zielińska    | Izabela     | 2009-11-07        |
-- +-----+---------------+-------------+-------------------+
-- | 216 | Jankowski     | Nikodem     | 2004-08-18        |
-- +-----+---------------+-------------+-------------------+
-- | 217 | Mazur         | Adam        | 2011-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 218 | Kaczmarek     | Matylda     | 2006-05-17        |
-- +-----+---------------+-------------+-------------------+
-- | 219 | Wójcik       | Igor        | 2017-10-04        |
-- +-----+---------------+-------------+-------------------+
-- | 220 | Szymański    | Igor        | 1996-08-31        |
-- +-----+---------------+-------------+-------------------+
-- | 221 | Krawczyk      | Paulina     | 2015-09-11        |
-- +-----+---------------+-------------+-------------------+
-- | 222 | Krawczyk      | Marta       | 2010-11-04        |
-- +-----+---------------+-------------+-------------------+
-- | 223 | Kaczmarek     | Mateusz     | 2010-03-06        |
-- +-----+---------------+-------------+-------------------+
-- | 224 | Lewandowski   | Stanisław  | 1998-05-07        |
-- +-----+---------------+-------------+-------------------+
-- | 225 | Nowak         | Adam        | 2012-09-23        |
-- +-----+---------------+-------------+-------------------+
-- | 226 | Lewandowska   | Sara        | 2014-03-08        |
-- +-----+---------------+-------------+-------------------+
-- | 227 | Kozłowski    | Piotr       | 1997-09-22        |
-- +-----+---------------+-------------+-------------------+
-- | 228 | Dąbrowski    | Nikodem     | 2010-05-23        |
-- +-----+---------------+-------------+-------------------+
-- | 229 | Kaczmarek     | Nikodem     | 1991-06-21        |
-- +-----+---------------+-------------+-------------------+
-- | 230 | Kamiński     | Piotr       | 1994-02-13        |
-- +-----+---------------+-------------+-------------------+
-- | 231 | Mazur         | Igor        | 2017-03-12        |
-- +-----+---------------+-------------+-------------------+
-- | 232 | Wojciechowski | Wiktor      | 1998-12-28        |
-- +-----+---------------+-------------+-------------------+
-- | 233 | Szymańska    | Róża      | 2012-10-11        |
-- +-----+---------------+-------------+-------------------+
-- | 234 | Dąbrowska    | Małgorzata | 2009-02-15        |
-- +-----+---------------+-------------+-------------------+
-- | 235 | Grabowska     | Izabela     | 1995-12-18        |
-- +-----+---------------+-------------+-------------------+
-- | 236 | Lewandowski   | Marcel      | 2015-11-19        |
-- +-----+---------------+-------------+-------------------+
-- | 237 | Krawczyk      | Małgorzata | 2016-10-16        |
-- +-----+---------------+-------------+-------------------+
-- | 238 | Wójcik       | Izabela     | 2013-10-11        |
-- +-----+---------------+-------------+-------------------+
-- | 239 | Kowalski      | Stanisław  | 2010-10-02        |
-- +-----+---------------+-------------+-------------------+
-- | 240 | Nowak         | Wiktor      | 2007-06-29        |
-- +-----+---------------+-------------+-------------------+
-- | 241 | Kwiatkowska   | Matylda     | 2015-07-13        |
-- +-----+---------------+-------------+-------------------+
-- | 242 | Jankowska     | Paulina     | 1994-11-17        |
-- +-----+---------------+-------------+-------------------+
-- | 243 | Mazur         | Adam        | 2000-11-23        |
-- +-----+---------------+-------------+-------------------+
-- | 244 | Wójcik       | Nikodem     | 2004-07-06        |
-- +-----+---------------+-------------+-------------------+
-- | 245 | Nowak         | Mateusz     | 2006-06-13        |
-- +-----+---------------+-------------+-------------------+
-- | 246 | Wójcik       | Igor        | 1991-11-02        |
-- +-----+---------------+-------------+-------------------+
-- | 247 | Lewandowska   | Klaudia     | 1992-06-14        |
-- +-----+---------------+-------------+-------------------+
-- | 248 | Szymańska    | Małgorzata | 2006-01-21        |
-- +-----+---------------+-------------+-------------------+
-- | 249 | Woźniak      | Klaudia     | 2005-07-20        |
-- +-----+---------------+-------------+-------------------+

-- %% [markdown]
-- Tabela **`Borrowings`**:

-- %%
SELECT * FROM borrowings;
-- Out:
-- +------+---------+---------+-------------+-------------+
-- | ID   | user_id | book_id | borrow_date | return_date |
-- +------+---------+---------+-------------+-------------+
-- | 0    | 129     | 621     | 2017-09-05  | 2017-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1    | 192     | 284     | 2011-01-26  | 2011-01-31  |
-- +------+---------+---------+-------------+-------------+
-- | 2    | 235     | 160     | 1995-12-18  | 1995-12-27  |
-- +------+---------+---------+-------------+-------------+
-- | 3    | 96      | 308     | 2018-07-02  | 2018-07-19  |
-- +------+---------+---------+-------------+-------------+
-- | 4    | 195     | 180     | 2017-07-11  | 2017-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 5    | 171     | 378     | 2015-06-19  | 2015-06-29  |
-- +------+---------+---------+-------------+-------------+
-- | 6    | 94      | 359     | 2012-04-23  | 2012-05-04  |
-- +------+---------+---------+-------------+-------------+
-- | 7    | 8       | 593     | 2001-05-31  | 2001-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 8    | 223     | 37      | 2010-03-06  | 2010-04-03  |
-- +------+---------+---------+-------------+-------------+
-- | 9    | 203     | 248     | 1996-03-20  | 1996-03-26  |
-- +------+---------+---------+-------------+-------------+
-- | 10   | 150     | 471     | 2000-09-13  | 2000-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 11   | 46      | 82      | 2009-02-27  | 2009-03-06  |
-- +------+---------+---------+-------------+-------------+
-- | 12   | 199     | 626     | 1995-06-12  | 1995-06-19  |
-- +------+---------+---------+-------------+-------------+
-- | 13   | 110     | 560     | 2011-01-30  | 2011-02-23  |
-- +------+---------+---------+-------------+-------------+
-- | 14   | 203     | 617     | 1996-03-20  | 1996-04-12  |
-- +------+---------+---------+-------------+-------------+
-- | 15   | 238     | 607     | 2013-10-11  | 2013-10-25  |
-- +------+---------+---------+-------------+-------------+
-- | 16   | 117     | 272     | 2011-01-13  | 2011-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 17   | 87      | 583     | 2004-01-19  | 2004-01-23  |
-- +------+---------+---------+-------------+-------------+
-- | 18   | 16      | 1       | 2002-01-30  | 2002-02-04  |
-- +------+---------+---------+-------------+-------------+
-- | 19   | 25      | 477     | 2003-06-09  | 2003-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 20   | 26      | 215     | 2004-07-16  | 2004-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 21   | 238     | 45      | 2013-10-11  | 2013-10-16  |
-- +------+---------+---------+-------------+-------------+
-- | 22   | 28      | 222     | 2017-08-24  | 2017-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 23   | 176     | 377     | 2007-08-12  | 2007-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 24   | 114     | 403     | 1997-04-04  | 1997-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 25   | 80      | 578     | 2001-08-27  | 2001-09-16  |
-- +------+---------+---------+-------------+-------------+
-- | 26   | 133     | 313     | 2011-10-17  | 2011-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 27   | 2       | 418     | 1999-08-09  | 1999-08-27  |
-- +------+---------+---------+-------------+-------------+
-- | 28   | 8       | 498     | 2007-01-12  | 2007-02-07  |
-- +------+---------+---------+-------------+-------------+
-- | 29   | 66      | 200     | 1990-12-27  | 1991-01-06  |
-- +------+---------+---------+-------------+-------------+
-- | 30   | 42      | 265     | 2007-01-15  | 2007-01-30  |
-- +------+---------+---------+-------------+-------------+
-- | 31   | 79      | 116     | 2017-08-20  | 2017-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 32   | 199     | 610     | 1995-06-12  | 1995-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 33   | 60      | 142     | 2012-10-02  | 2012-10-02  |
-- +------+---------+---------+-------------+-------------+
-- | 34   | 233     | 60      | 2012-10-11  | 2012-10-14  |
-- +------+---------+---------+-------------+-------------+
-- | 35   | 94      | 443     | 2012-04-23  | 2012-05-15  |
-- +------+---------+---------+-------------+-------------+
-- | 36   | 92      | 129     | 2016-05-06  | 2016-06-03  |
-- +------+---------+---------+-------------+-------------+
-- | 37   | 225     | 581     | 2012-09-23  | 2012-09-24  |
-- +------+---------+---------+-------------+-------------+
-- | 38   | 200     | 505     | 1993-09-08  | 1993-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 39   | 175     | 574     | 1998-09-02  | 1998-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 40   | 248     | 141     | 2017-11-06  | 2017-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 41   | 239     | 321     | 2010-10-02  | 2010-10-15  |
-- +------+---------+---------+-------------+-------------+
-- | 42   | 86      | 271     | 2003-11-08  | 2003-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 43   | 8       | 544     | 2001-05-31  | 2001-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 44   | 234     | 563     | 2016-12-12  | 2017-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 45   | 204     | 494     | 1994-11-10  | 1994-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 46   | 229     | 426     | 1991-06-21  | 1991-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 47   | 113     | 173     | 2017-03-21  | 2017-04-10  |
-- +------+---------+---------+-------------+-------------+
-- | 48   | 66      | 200     | 1990-12-27  | 1991-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 49   | 244     | 180     | 2004-07-06  | 2004-07-07  |
-- +------+---------+---------+-------------+-------------+
-- | 50   | 24      | 309     | 1999-01-19  | 1999-02-11  |
-- +------+---------+---------+-------------+-------------+
-- | 51   | 156     | 114     | 1998-03-13  | 1998-03-16  |
-- +------+---------+---------+-------------+-------------+
-- | 52   | 29      | 163     | 2017-09-08  | 2017-09-12  |
-- +------+---------+---------+-------------+-------------+
-- | 53   | 28      | 34      | 2017-08-20  | 2017-09-04  |
-- +------+---------+---------+-------------+-------------+
-- | 54   | 185     | 383     | 2015-06-02  | 2015-06-02  |
-- +------+---------+---------+-------------+-------------+
-- | 55   | 219     | 208     | 2017-10-04  | 2017-10-26  |
-- +------+---------+---------+-------------+-------------+
-- | 56   | 234     | 199     | 2009-02-15  | 2009-02-18  |
-- +------+---------+---------+-------------+-------------+
-- | 57   | 187     | 116     | 2008-11-22  | 2008-12-06  |
-- +------+---------+---------+-------------+-------------+
-- | 58   | 67      | 628     | 2009-10-23  | 2009-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 59   | 72      | 162     | 2012-12-17  | 2012-12-30  |
-- +------+---------+---------+-------------+-------------+
-- | 60   | 51      | 1       | 2002-01-30  | 2002-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 61   | 113     | 169     | 2017-04-02  | 2017-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 62   | 197     | 577     | 2011-04-19  | 2011-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 63   | 183     | 588     | 2015-12-23  | 2016-01-16  |
-- +------+---------+---------+-------------+-------------+
-- | 64   | 214     | 90      | 2015-12-07  | 2015-12-28  |
-- +------+---------+---------+-------------+-------------+
-- | 65   | 125     | 131     | 2017-08-14  | 2017-08-30  |
-- +------+---------+---------+-------------+-------------+
-- | 66   | 164     | 113     | 1999-11-10  | 1999-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 67   | 77      | 543     | 2017-12-15  | 2017-12-31  |
-- +------+---------+---------+-------------+-------------+
-- | 68   | 172     | 30      | 2003-05-31  | 2003-06-28  |
-- +------+---------+---------+-------------+-------------+
-- | 69   | 32      | 572     | 2012-07-22  | 2012-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 70   | 176     | 185     | 2007-08-12  | 2007-08-28  |
-- +------+---------+---------+-------------+-------------+
-- | 71   | 180     | 209     | 2017-09-14  | 2017-09-30  |
-- +------+---------+---------+-------------+-------------+
-- | 72   | 193     | 455     | 2012-09-24  | 2012-09-25  |
-- +------+---------+---------+-------------+-------------+
-- | 73   | 48      | 421     | 2013-06-25  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 74   | 222     | 485     | 2017-10-05  | 2017-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 75   | 155     | 399     | 2006-06-28  | 2006-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 76   | 60      | 277     | 2017-02-22  | 2017-03-04  |
-- +------+---------+---------+-------------+-------------+
-- | 77   | 53      | 633     | 1990-03-21  | 1990-03-24  |
-- +------+---------+---------+-------------+-------------+
-- | 78   | 120     | 167     | 1999-10-25  | 1999-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 79   | 152     | 167     | 1996-08-24  | 1996-09-19  |
-- +------+---------+---------+-------------+-------------+
-- | 80   | 135     | 325     | 2013-03-11  | 2013-03-30  |
-- +------+---------+---------+-------------+-------------+
-- | 81   | 2       | 569     | 2002-02-15  | 2002-03-01  |
-- +------+---------+---------+-------------+-------------+
-- | 82   | 129     | 167     | 2017-09-05  | 2017-09-26  |
-- +------+---------+---------+-------------+-------------+
-- | 83   | 142     | 530     | 2009-10-29  | 2009-11-18  |
-- +------+---------+---------+-------------+-------------+
-- | 84   | 67      | 49      | 2007-08-17  | 2009-02-13  |
-- +------+---------+---------+-------------+-------------+
-- | 85   | 121     | 593     | 2009-10-25  | 2009-11-10  |
-- +------+---------+---------+-------------+-------------+
-- | 86   | 230     | 308     | 2018-07-02  | 2018-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 87   | 171     | 514     | 2015-06-19  | 2015-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 88   | 118     | 58      | 2015-12-13  | 2015-12-26  |
-- +------+---------+---------+-------------+-------------+
-- | 89   | 131     | 446     | 1991-10-10  | 1991-10-17  |
-- +------+---------+---------+-------------+-------------+
-- | 90   | 95      | 3       | 2017-03-02  | 2017-03-27  |
-- +------+---------+---------+-------------+-------------+
-- | 91   | 109     | 541     | 2009-04-21  | 2009-05-07  |
-- +------+---------+---------+-------------+-------------+
-- | 92   | 231     | 151     | 2017-03-12  | 2017-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 93   | 202     | 402     | 2013-06-18  |             |
-- +------+---------+---------+-------------+-------------+
-- | 94   | 245     | 71      | 2006-06-13  | 2006-06-19  |
-- +------+---------+---------+-------------+-------------+
-- | 95   | 235     | 124     | 1996-04-02  | 1996-04-19  |
-- +------+---------+---------+-------------+-------------+
-- | 96   | 159     | 411     | 2001-01-18  | 2001-01-23  |
-- +------+---------+---------+-------------+-------------+
-- | 97   | 75      | 2       | 2013-04-17  | 2013-04-17  |
-- +------+---------+---------+-------------+-------------+
-- | 98   | 4       | 256     | 2018-06-23  | 2018-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 99   | 35      | 567     | 1992-04-28  | 1992-05-26  |
-- +------+---------+---------+-------------+-------------+
-- | 100  | 19      | 360     | 2001-07-05  | 2001-07-17  |
-- +------+---------+---------+-------------+-------------+
-- | 101  | 108     | 300     | 2000-11-24  | 2000-12-16  |
-- +------+---------+---------+-------------+-------------+
-- | 102  | 154     | 525     | 2006-10-08  | 2006-10-18  |
-- +------+---------+---------+-------------+-------------+
-- | 103  | 232     | 424     | 2005-03-03  | 2005-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 104  | 96      | 137     | 2014-03-22  | 2014-04-03  |
-- +------+---------+---------+-------------+-------------+
-- | 105  | 173     | 469     | 1996-07-10  | 1996-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 106  | 205     | 210     | 2001-02-27  | 2001-03-27  |
-- +------+---------+---------+-------------+-------------+
-- | 107  | 22      | 317     | 2007-11-18  | 2007-12-05  |
-- +------+---------+---------+-------------+-------------+
-- | 108  | 137     | 330     | 1998-04-23  | 1998-04-25  |
-- +------+---------+---------+-------------+-------------+
-- | 109  | 220     | 538     | 1997-01-24  | 1997-02-04  |
-- +------+---------+---------+-------------+-------------+
-- | 110  | 90      | 544     | 2009-08-09  | 2009-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 111  | 218     | 56      | 2006-05-17  | 2006-05-25  |
-- +------+---------+---------+-------------+-------------+
-- | 112  | 222     | 217     | 2010-11-04  | 2010-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 113  | 213     | 377     | 1998-10-28  | 1998-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 114  | 88      | 33      | 1990-07-04  | 1990-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 115  | 113     | 6       | 2017-03-21  | 2017-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 116  | 173     | 394     | 1996-07-10  | 1996-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 117  | 238     | 294     | 2013-10-11  | 2013-10-17  |
-- +------+---------+---------+-------------+-------------+
-- | 118  | 3       | 100     | 2011-01-22  | 2011-02-16  |
-- +------+---------+---------+-------------+-------------+
-- | 119  | 44      | 152     | 1992-10-24  | 1992-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 120  | 127     | 40      | 2006-07-26  | 2006-08-11  |
-- +------+---------+---------+-------------+-------------+
-- | 121  | 148     | 406     | 2008-10-03  | 2008-10-07  |
-- +------+---------+---------+-------------+-------------+
-- | 122  | 95      | 78      | 2012-11-27  | 2012-12-25  |
-- +------+---------+---------+-------------+-------------+
-- | 123  | 60      | 420     | 2013-05-11  | 2013-05-11  |
-- +------+---------+---------+-------------+-------------+
-- | 124  | 67      | 286     | 2016-06-03  | 2016-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 125  | 34      | 519     | 1991-04-27  | 1991-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 126  | 138     | 77      | 2009-04-03  | 2009-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 127  | 67      | 304     | 2007-08-17  | 2007-08-25  |
-- +------+---------+---------+-------------+-------------+
-- | 128  | 14      | 20      | 2013-07-10  | 2013-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 129  | 221     | 360     | 2015-09-11  | 2015-10-02  |
-- +------+---------+---------+-------------+-------------+
-- | 130  | 201     | 150     | 1999-04-23  | 1999-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 131  | 208     | 336     | 2012-02-23  | 2012-03-23  |
-- +------+---------+---------+-------------+-------------+
-- | 132  | 181     | 332     | 2012-02-03  | 2012-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 133  | 249     | 433     | 2005-07-20  | 2005-08-07  |
-- +------+---------+---------+-------------+-------------+
-- | 134  | 88      | 564     | 1990-07-04  | 1990-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 135  | 101     | 583     | 2002-07-04  | 2002-07-19  |
-- +------+---------+---------+-------------+-------------+
-- | 136  | 9       | 373     | 2013-03-07  | 2013-03-31  |
-- +------+---------+---------+-------------+-------------+
-- | 137  | 168     | 292     | 2004-10-18  | 2004-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 138  | 39      | 57      | 2012-11-13  | 2012-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 139  | 7       | 474     | 1991-10-03  | 1991-10-09  |
-- +------+---------+---------+-------------+-------------+
-- | 140  | 174     | 135     | 2015-07-03  | 2015-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 141  | 146     | 314     | 1992-11-29  | 1992-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 142  | 93      | 300     | 2011-10-10  | 2011-11-08  |
-- +------+---------+---------+-------------+-------------+
-- | 143  | 244     | 105     | 2004-07-06  | 2004-07-31  |
-- +------+---------+---------+-------------+-------------+
-- | 144  | 74      | 311     | 2003-10-04  | 2003-10-27  |
-- +------+---------+---------+-------------+-------------+
-- | 145  | 186     | 298     | 2013-07-06  | 2013-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 146  | 157     | 366     | 2016-11-09  | 2016-11-30  |
-- +------+---------+---------+-------------+-------------+
-- | 147  | 101     | 618     | 2002-07-04  | 2002-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 148  | 215     | 448     | 2015-11-06  | 2015-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 149  | 11      | 633     | 1996-08-08  | 1996-08-25  |
-- +------+---------+---------+-------------+-------------+
-- | 150  | 60      | 322     | 2012-10-02  | 2012-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 151  | 155     | 50      | 2006-06-28  | 2006-07-20  |
-- +------+---------+---------+-------------+-------------+
-- | 152  | 246     | 68      | 1991-11-02  | 1991-11-19  |
-- +------+---------+---------+-------------+-------------+
-- | 153  | 189     | 355     | 2006-02-21  | 2006-03-17  |
-- +------+---------+---------+-------------+-------------+
-- | 154  | 159     | 197     | 1991-05-15  | 1991-06-01  |
-- +------+---------+---------+-------------+-------------+
-- | 155  | 8       | 430     | 2001-05-31  | 2001-06-24  |
-- +------+---------+---------+-------------+-------------+
-- | 156  | 103     | 155     | 2006-01-03  | 2006-01-31  |
-- +------+---------+---------+-------------+-------------+
-- | 157  | 229     | 529     | 1991-06-21  | 1991-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 158  | 230     | 119     | 2008-02-20  | 2008-03-04  |
-- +------+---------+---------+-------------+-------------+
-- | 159  | 80      | 452     | 1995-11-25  | 1995-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 160  | 34      | 228     | 2014-06-24  | 2014-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 161  | 91      | 95      | 2013-07-06  | 2013-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 162  | 34      | 133     | 2017-06-10  | 2017-06-26  |
-- +------+---------+---------+-------------+-------------+
-- | 163  | 123     | 337     | 2009-11-05  | 2009-11-13  |
-- +------+---------+---------+-------------+-------------+
-- | 164  | 57      | 92      | 2017-11-20  | 2017-12-02  |
-- +------+---------+---------+-------------+-------------+
-- | 165  | 120     | 227     | 2010-03-11  | 2010-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 166  | 128     | 189     | 2017-03-04  | 2017-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 167  | 37      | 327     | 2005-10-09  | 2005-10-13  |
-- +------+---------+---------+-------------+-------------+
-- | 168  | 138     | 287     | 2009-04-03  | 2009-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 169  | 93      | 115     | 2011-10-10  | 2011-11-07  |
-- +------+---------+---------+-------------+-------------+
-- | 170  | 125     | 178     | 2017-08-14  | 2017-08-28  |
-- +------+---------+---------+-------------+-------------+
-- | 171  | 218     | 327     | 2006-05-17  | 2006-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 172  | 119     | 85      | 2008-11-04  | 2008-11-11  |
-- +------+---------+---------+-------------+-------------+
-- | 173  | 5       | 566     | 2013-06-16  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 174  | 187     | 84      | 2008-11-22  | 2008-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 175  | 137     | 634     | 2015-11-13  | 2015-12-10  |
-- +------+---------+---------+-------------+-------------+
-- | 176  | 194     | 415     | 2017-05-11  | 2017-05-27  |
-- +------+---------+---------+-------------+-------------+
-- | 177  | 156     | 532     | 2006-02-01  | 2006-02-11  |
-- +------+---------+---------+-------------+-------------+
-- | 178  | 85      | 323     | 2009-12-30  | 2010-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 179  | 100     | 268     | 2007-11-07  | 2007-12-04  |
-- +------+---------+---------+-------------+-------------+
-- | 180  | 169     | 457     | 2017-01-01  | 2017-01-18  |
-- +------+---------+---------+-------------+-------------+
-- | 181  | 42      | 61      | 2007-01-15  | 2007-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 182  | 103     | 465     | 2006-01-03  | 2006-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 183  | 128     | 520     | 2017-03-04  | 2017-04-02  |
-- +------+---------+---------+-------------+-------------+
-- | 184  | 230     | 223     | 1994-02-13  | 1994-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 185  | 221     | 505     | 2015-09-11  | 2015-09-21  |
-- +------+---------+---------+-------------+-------------+
-- | 186  | 177     | 613     | 2003-05-04  | 2003-05-16  |
-- +------+---------+---------+-------------+-------------+
-- | 187  | 3       | 507     | 2011-01-22  | 2011-02-08  |
-- +------+---------+---------+-------------+-------------+
-- | 188  | 78      | 303     | 2010-12-13  | 2011-01-02  |
-- +------+---------+---------+-------------+-------------+
-- | 189  | 190     | 287     | 2005-08-22  | 2005-08-22  |
-- +------+---------+---------+-------------+-------------+
-- | 190  | 155     | 532     | 2006-06-28  | 2006-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 191  | 153     | 259     | 2012-12-30  | 2013-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 192  | 69      | 77      | 2007-06-26  | 2007-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 193  | 8       | 424     | 2005-03-03  | 2005-03-23  |
-- +------+---------+---------+-------------+-------------+
-- | 194  | 196     | 44      | 2018-07-19  | 2018-07-31  |
-- +------+---------+---------+-------------+-------------+
-- | 195  | 147     | 271     | 2008-02-29  | 2008-03-02  |
-- +------+---------+---------+-------------+-------------+
-- | 196  | 109     | 219     | 2016-10-16  | 2016-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 197  | 91      | 324     | 2013-07-06  | 2013-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 198  | 184     | 182     | 2018-02-03  | 2018-02-22  |
-- +------+---------+---------+-------------+-------------+
-- | 199  | 230     | 298     | 1994-02-13  | 1994-02-23  |
-- +------+---------+---------+-------------+-------------+
-- | 200  | 36      | 588     | 2010-10-26  | 2010-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 201  | 227     | 416     | 1997-09-22  | 1997-10-20  |
-- +------+---------+---------+-------------+-------------+
-- | 202  | 220     | 536     | 1996-08-31  | 1996-09-03  |
-- +------+---------+---------+-------------+-------------+
-- | 203  | 46      | 404     | 2009-02-27  | 2009-03-16  |
-- +------+---------+---------+-------------+-------------+
-- | 204  | 21      | 516     | 2006-06-16  | 2006-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 205  | 213     | 554     | 1998-10-28  | 1998-11-18  |
-- +------+---------+---------+-------------+-------------+
-- | 206  | 232     | 222     | 2017-08-24  | 2017-09-10  |
-- +------+---------+---------+-------------+-------------+
-- | 207  | 170     | 530     | 2011-11-26  | 2011-12-25  |
-- +------+---------+---------+-------------+-------------+
-- | 208  | 163     | 416     | 1994-08-18  | 1994-08-24  |
-- +------+---------+---------+-------------+-------------+
-- | 209  | 21      | 188     | 2004-03-18  | 2004-04-08  |
-- +------+---------+---------+-------------+-------------+
-- | 210  | 143     | 593     | 2010-03-05  | 2010-03-14  |
-- +------+---------+---------+-------------+-------------+
-- | 211  | 30      | 250     | 2016-10-24  | 2016-11-04  |
-- +------+---------+---------+-------------+-------------+
-- | 212  | 163     | 417     | 2006-01-12  | 2006-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 213  | 167     | 83      | 1993-07-04  | 1993-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 214  | 199     | 597     | 2007-08-07  | 2007-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 215  | 162     | 5       | 2018-08-04  | 2018-08-20  |
-- +------+---------+---------+-------------+-------------+
-- | 216  | 70      | 483     | 2006-06-25  | 2006-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 217  | 162     | 628     | 2009-10-23  | 2009-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 218  | 129     | 51      | 2017-09-05  |             |
-- +------+---------+---------+-------------+-------------+
-- | 219  | 130     | 619     | 2017-06-19  | 2017-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 220  | 99      | 198     | 2004-05-10  | 2004-06-06  |
-- +------+---------+---------+-------------+-------------+
-- | 221  | 39      | 463     | 2012-11-13  | 2012-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 222  | 119     | 245     | 2008-11-04  | 2008-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 223  | 145     | 339     | 2005-05-09  | 2005-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 224  | 193     | 295     | 2006-12-18  | 2007-01-06  |
-- +------+---------+---------+-------------+-------------+
-- | 225  | 148     | 601     | 1998-10-16  | 1998-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 226  | 205     | 329     | 2000-06-15  | 2000-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 227  | 36      | 423     | 1992-03-16  | 1992-04-06  |
-- +------+---------+---------+-------------+-------------+
-- | 228  | 24      | 173     | 1999-01-19  | 1999-01-25  |
-- +------+---------+---------+-------------+-------------+
-- | 229  | 205     | 529     | 1991-12-28  | 1992-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 230  | 163     | 35      | 1994-08-18  | 1994-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 231  | 144     | 540     | 1998-04-01  | 1998-04-26  |
-- +------+---------+---------+-------------+-------------+
-- | 232  | 224     | 122     | 2018-04-22  | 2018-05-03  |
-- +------+---------+---------+-------------+-------------+
-- | 233  | 20      | 130     | 2010-03-31  | 2010-04-04  |
-- +------+---------+---------+-------------+-------------+
-- | 234  | 126     | 331     | 2001-10-14  | 2001-10-14  |
-- +------+---------+---------+-------------+-------------+
-- | 235  | 159     | 219     | 2016-10-16  | 2016-10-20  |
-- +------+---------+---------+-------------+-------------+
-- | 236  | 19      | 607     | 2006-01-06  | 2006-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 237  | 209     | 563     | 2016-12-12  | 2017-01-07  |
-- +------+---------+---------+-------------+-------------+
-- | 238  | 168     | 399     | 2004-10-18  | 2004-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 239  | 8       | 476     | 2001-05-31  | 2001-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 240  | 238     | 578     | 2013-10-11  | 2013-11-05  |
-- +------+---------+---------+-------------+-------------+
-- | 241  | 80      | 291     | 1995-11-25  | 1995-12-18  |
-- +------+---------+---------+-------------+-------------+
-- | 242  | 31      | 468     | 2001-10-18  | 2001-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 243  | 72      | 498     | 2012-12-17  | 2012-12-22  |
-- +------+---------+---------+-------------+-------------+
-- | 244  | 205     | 203     | 2017-12-24  | 2018-01-09  |
-- +------+---------+---------+-------------+-------------+
-- | 245  | 2       | 481     | 1999-08-09  | 1999-09-04  |
-- +------+---------+---------+-------------+-------------+
-- | 246  | 173     | 228     | 2014-06-24  | 2014-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 247  | 248     | 310     | 2006-01-21  | 2006-01-30  |
-- +------+---------+---------+-------------+-------------+
-- | 248  | 144     | 59      | 1998-04-01  | 1998-04-18  |
-- +------+---------+---------+-------------+-------------+
-- | 249  | 245     | 289     | 2006-06-13  | 2006-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 250  | 67      | 628     | 2009-10-23  | 2009-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 251  | 45      | 98      | 2017-01-14  | 2017-01-21  |
-- +------+---------+---------+-------------+-------------+
-- | 252  | 237     | 505     | 2016-10-16  | 2016-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 253  | 117     | 627     | 2011-01-13  | 2011-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 254  | 123     | 561     | 2009-11-05  | 2009-11-17  |
-- +------+---------+---------+-------------+-------------+
-- | 255  | 119     | 216     | 2008-11-04  | 2008-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 256  | 22      | 460     | 2007-11-18  | 2007-11-30  |
-- +------+---------+---------+-------------+-------------+
-- | 257  | 32      | 6       | 2012-07-22  | 2012-08-09  |
-- +------+---------+---------+-------------+-------------+
-- | 258  | 139     | 496     | 2016-05-30  | 2016-06-25  |
-- +------+---------+---------+-------------+-------------+
-- | 259  | 55      | 336     | 2014-03-05  | 2014-03-19  |
-- +------+---------+---------+-------------+-------------+
-- | 260  | 219     | 26      | 2017-10-04  | 2017-10-21  |
-- +------+---------+---------+-------------+-------------+
-- | 261  | 191     | 197     | 2015-11-28  | 2015-12-07  |
-- +------+---------+---------+-------------+-------------+
-- | 262  | 166     | 341     | 2005-06-05  | 2005-07-01  |
-- +------+---------+---------+-------------+-------------+
-- | 263  | 69      | 585     | 2007-06-26  | 2007-07-07  |
-- +------+---------+---------+-------------+-------------+
-- | 264  | 48      | 481     | 2013-06-25  | 2013-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 265  | 105     | 15      | 2005-06-13  | 2005-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 266  | 120     | 356     | 1999-10-25  | 1999-10-29  |
-- +------+---------+---------+-------------+-------------+
-- | 267  | 91      | 606     | 2013-07-06  | 2013-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 268  | 196     | 228     | 2014-06-24  | 2014-06-29  |
-- +------+---------+---------+-------------+-------------+
-- | 269  | 84      | 244     | 2010-04-05  | 2010-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 270  | 73      | 48      | 2013-06-30  | 2013-07-14  |
-- +------+---------+---------+-------------+-------------+
-- | 271  | 178     | 52      | 2017-01-09  | 2017-02-06  |
-- +------+---------+---------+-------------+-------------+
-- | 272  | 35      | 108     | 2005-02-26  | 2005-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 273  | 158     | 387     | 2007-04-25  | 2007-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 274  | 165     | 260     | 2016-09-05  | 2016-09-30  |
-- +------+---------+---------+-------------+-------------+
-- | 275  | 61      | 56      | 2015-10-14  | 2015-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 276  | 199     | 316     | 1995-06-29  | 1995-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 277  | 23      | 141     | 2017-11-06  | 2017-11-24  |
-- +------+---------+---------+-------------+-------------+
-- | 278  | 188     | 362     | 1994-07-14  | 1994-08-12  |
-- +------+---------+---------+-------------+-------------+
-- | 279  | 147     | 221     | 2008-02-29  | 2008-03-28  |
-- +------+---------+---------+-------------+-------------+
-- | 280  | 109     | 575     | 2009-04-21  | 2009-05-12  |
-- +------+---------+---------+-------------+-------------+
-- | 281  | 92      | 626     | 2016-05-06  | 2016-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 282  | 215     | 617     | 2009-11-07  | 2009-11-25  |
-- +------+---------+---------+-------------+-------------+
-- | 283  | 155     | 4       | 2006-06-28  | 2006-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 284  | 71      | 332     | 2014-06-27  | 2014-07-11  |
-- +------+---------+---------+-------------+-------------+
-- | 285  | 12      | 147     | 2007-04-08  | 2007-04-24  |
-- +------+---------+---------+-------------+-------------+
-- | 286  | 185     | 305     | 2015-06-02  | 2015-06-30  |
-- +------+---------+---------+-------------+-------------+
-- | 287  | 66      | 521     | 2006-05-22  | 2006-06-15  |
-- +------+---------+---------+-------------+-------------+
-- | 288  | 138     | 372     | 2015-09-25  | 2015-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 289  | 14      | 530     | 2013-07-10  | 2013-07-27  |
-- +------+---------+---------+-------------+-------------+
-- | 290  | 38      | 275     | 2006-09-01  | 2006-09-29  |
-- +------+---------+---------+-------------+-------------+
-- | 291  | 52      | 441     | 2006-06-17  | 2006-07-03  |
-- +------+---------+---------+-------------+-------------+
-- | 292  | 34      | 357     | 1991-04-27  | 1991-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 293  | 20      | 605     | 2010-03-31  | 2010-04-15  |
-- +------+---------+---------+-------------+-------------+
-- | 294  | 71      | 14      | 2014-06-27  | 2014-07-25  |
-- +------+---------+---------+-------------+-------------+
-- | 295  | 40      | 260     | 2016-09-05  | 2016-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 296  | 53      | 299     | 1990-03-21  | 1990-04-19  |
-- +------+---------+---------+-------------+-------------+
-- | 297  | 208     | 293     | 2012-02-23  | 2012-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 298  | 245     | 376     | 2006-06-13  | 2006-06-22  |
-- +------+---------+---------+-------------+-------------+
-- | 299  | 164     | 138     | 1999-11-10  | 1999-11-29  |
-- +------+---------+---------+-------------+-------------+
-- | 300  | 64      | 626     | 1990-12-22  | 1991-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 301  | 121     | 468     | 2009-10-25  | 2009-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 302  | 17      | 616     | 2000-04-21  | 2000-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 303  | 181     | 523     | 2015-06-12  | 2015-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 304  | 26      | 106     | 2004-07-16  | 2004-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 305  | 57      | 440     | 1992-03-01  | 1992-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 306  | 242     | 58      | 2015-12-13  | 2015-12-21  |
-- +------+---------+---------+-------------+-------------+
-- | 307  | 203     | 247     | 1996-03-20  | 1996-04-17  |
-- +------+---------+---------+-------------+-------------+
-- | 308  | 221     | 55      | 2015-09-11  | 2015-09-25  |
-- +------+---------+---------+-------------+-------------+
-- | 309  | 60      | 123     | 2012-10-02  | 2012-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 310  | 143     | 587     | 2010-03-05  | 2010-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 311  | 1       | 444     | 2008-07-04  | 2008-08-01  |
-- +------+---------+---------+-------------+-------------+
-- | 312  | 108     | 449     | 1992-04-04  | 1992-04-12  |
-- +------+---------+---------+-------------+-------------+
-- | 313  | 195     | 334     | 2017-07-11  | 2017-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 314  | 54      | 81      | 2017-07-29  | 2017-08-08  |
-- +------+---------+---------+-------------+-------------+
-- | 315  | 136     | 210     | 2006-05-17  | 2006-05-31  |
-- +------+---------+---------+-------------+-------------+
-- | 316  | 98      | 141     | 2017-11-06  | 2017-11-26  |
-- +------+---------+---------+-------------+-------------+
-- | 317  | 120     | 438     | 1999-10-25  | 1999-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 318  | 41      | 297     | 2013-02-28  | 2013-02-28  |
-- +------+---------+---------+-------------+-------------+
-- | 319  | 24      | 19      | 1999-01-19  | 1999-02-16  |
-- +------+---------+---------+-------------+-------------+
-- | 320  | 158     | 94      | 2012-08-23  | 2012-09-07  |
-- +------+---------+---------+-------------+-------------+
-- | 321  | 39      | 29      | 2016-02-23  | 2016-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 322  | 173     | 308     | 2018-07-02  | 2018-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 323  | 5       | 420     | 2013-06-16  | 2013-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 324  | 14      | 323     | 2013-07-10  | 2013-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 325  | 163     | 177     | 1994-08-18  | 1994-08-20  |
-- +------+---------+---------+-------------+-------------+
-- | 326  | 5       | 270     | 2013-06-16  | 2013-06-27  |
-- +------+---------+---------+-------------+-------------+
-- | 327  | 212     | 274     | 1998-10-14  | 1998-10-15  |
-- +------+---------+---------+-------------+-------------+
-- | 328  | 8       | 320     | 2001-06-01  | 2001-06-17  |
-- +------+---------+---------+-------------+-------------+
-- | 329  | 243     | 33      | 2000-11-23  | 2000-12-11  |
-- +------+---------+---------+-------------+-------------+
-- | 330  | 164     | 94      | 2012-08-23  | 2012-08-29  |
-- +------+---------+---------+-------------+-------------+
-- | 331  | 229     | 259     | 2012-12-30  |             |
-- +------+---------+---------+-------------+-------------+
-- | 332  | 197     | 363     | 2012-11-05  | 2012-11-23  |
-- +------+---------+---------+-------------+-------------+
-- | 333  | 25      | 330     | 2003-06-09  | 2003-06-23  |
-- +------+---------+---------+-------------+-------------+
-- | 334  | 101     | 45      | 2002-07-04  | 2002-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 335  | 50      | 476     | 1990-11-08  | 1990-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 336  | 140     | 608     | 2011-04-12  | 2011-04-16  |
-- +------+---------+---------+-------------+-------------+
-- | 337  | 31      | 9       | 2001-10-18  | 2001-10-21  |
-- +------+---------+---------+-------------+-------------+
-- | 338  | 153     | 15      | 2002-09-20  | 2002-10-03  |
-- +------+---------+---------+-------------+-------------+
-- | 339  | 149     | 241     | 2009-10-04  | 2009-10-19  |
-- +------+---------+---------+-------------+-------------+
-- | 340  | 72      | 563     | 2016-12-12  | 2016-12-12  |
-- +------+---------+---------+-------------+-------------+
-- | 341  | 73      | 167     | 1997-05-11  | 1997-05-12  |
-- +------+---------+---------+-------------+-------------+
-- | 342  | 78      | 562     | 2010-12-13  |             |
-- +------+---------+---------+-------------+-------------+
-- | 343  | 136     | 177     | 2006-05-17  | 2006-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 344  | 231     | 495     | 2017-03-12  | 2017-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 345  | 76      | 612     | 2011-04-23  | 2011-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 346  | 90      | 367     | 2009-08-09  | 2009-08-12  |
-- +------+---------+---------+-------------+-------------+
-- | 347  | 82      | 153     | 2016-10-26  | 2016-11-05  |
-- +------+---------+---------+-------------+-------------+
-- | 348  | 57      | 436     | 1992-03-01  | 1992-03-07  |
-- +------+---------+---------+-------------+-------------+
-- | 349  | 94      | 99      | 2012-04-23  | 2012-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 350  | 130     | 104     | 2014-12-01  | 2014-12-20  |
-- +------+---------+---------+-------------+-------------+
-- | 351  | 115     | 92      | 2017-11-20  | 2017-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 352  | 190     | 38      | 2005-08-22  | 2005-08-22  |
-- +------+---------+---------+-------------+-------------+
-- | 353  | 239     | 620     | 2010-10-02  | 2010-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 354  | 188     | 247     | 1994-07-14  | 1994-07-23  |
-- +------+---------+---------+-------------+-------------+
-- | 355  | 171     | 37      | 2015-06-19  | 2015-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 356  | 173     | 223     | 1996-07-10  | 1996-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 357  | 246     | 49      | 1991-11-02  | 1991-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 358  | 229     | 247     | 1991-06-21  | 1991-07-08  |
-- +------+---------+---------+-------------+-------------+
-- | 359  | 17      | 527     | 2010-12-07  | 2010-12-17  |
-- +------+---------+---------+-------------+-------------+
-- | 360  | 152     | 267     | 2012-09-13  | 2012-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 361  | 123     | 483     | 2009-11-05  | 2009-12-02  |
-- +------+---------+---------+-------------+-------------+
-- | 362  | 123     | 492     | 2009-11-05  | 2009-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 363  | 242     | 349     | 1994-11-17  | 1994-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 364  | 167     | 443     | 1992-01-03  | 1992-01-24  |
-- +------+---------+---------+-------------+-------------+
-- | 365  | 7       | 569     | 2002-02-15  | 2002-03-07  |
-- +------+---------+---------+-------------+-------------+
-- | 366  | 81      | 465     | 2015-06-18  | 2015-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 367  | 2       | 107     | 1999-08-09  | 1999-08-19  |
-- +------+---------+---------+-------------+-------------+
-- | 368  | 120     | 323     | 1999-10-25  | 1999-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 369  | 82      | 402     | 2016-10-26  | 2016-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 370  | 168     | 607     | 2006-01-06  | 2006-02-01  |
-- +------+---------+---------+-------------+-------------+
-- | 371  | 147     | 617     | 2008-02-29  | 2008-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 372  | 183     | 418     | 2015-12-23  | 2016-01-01  |
-- +------+---------+---------+-------------+-------------+
-- | 373  | 45      | 44      | 2018-07-19  | 2018-07-29  |
-- +------+---------+---------+-------------+-------------+
-- | 374  | 226     | 437     | 2014-03-08  | 2014-03-18  |
-- +------+---------+---------+-------------+-------------+
-- | 375  | 136     | 41      | 2006-05-17  | 2006-06-14  |
-- +------+---------+---------+-------------+-------------+
-- | 376  | 180     | 342     | 2011-01-30  | 2011-02-15  |
-- +------+---------+---------+-------------+-------------+
-- | 377  | 197     | 257     | 2011-04-19  | 2011-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 378  | 59      | 285     | 2005-07-23  | 2005-07-26  |
-- +------+---------+---------+-------------+-------------+
-- | 379  | 145     | 57      | 2005-05-09  | 2005-06-07  |
-- +------+---------+---------+-------------+-------------+
-- | 380  | 237     | 406     | 2016-10-16  | 2016-10-22  |
-- +------+---------+---------+-------------+-------------+
-- | 381  | 244     | 31      | 2014-04-02  | 2014-04-11  |
-- +------+---------+---------+-------------+-------------+
-- | 382  | 196     | 93      | 2000-06-03  | 2000-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 383  | 136     | 545     | 2006-05-17  | 2006-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 384  | 112     | 92      | 2017-11-20  | 2017-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 385  | 164     | 502     | 1999-11-10  | 1999-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 386  | 107     | 148     | 2014-06-01  | 2014-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 387  | 90      | 237     | 2014-05-01  | 2014-05-01  |
-- +------+---------+---------+-------------+-------------+
-- | 388  | 190     | 336     | 2005-08-22  | 2005-08-30  |
-- +------+---------+---------+-------------+-------------+
-- | 389  | 120     | 405     | 1999-10-25  | 1999-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 390  | 104     | 97      | 2007-01-12  | 2007-01-28  |
-- +------+---------+---------+-------------+-------------+
-- | 391  | 0       | 530     | 1994-04-27  | 1994-05-18  |
-- +------+---------+---------+-------------+-------------+
-- | 392  | 49      | 312     | 2015-04-27  | 2015-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 393  | 120     | 252     | 1999-10-25  | 1999-10-25  |
-- +------+---------+---------+-------------+-------------+
-- | 394  | 247     | 196     | 1992-06-14  | 1992-06-24  |
-- +------+---------+---------+-------------+-------------+
-- | 395  | 229     | 587     | 1991-06-21  | 1991-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 396  | 32      | 168     | 2012-07-22  | 2012-08-09  |
-- +------+---------+---------+-------------+-------------+
-- | 397  | 238     | 509     | 2013-10-11  | 2013-11-01  |
-- +------+---------+---------+-------------+-------------+
-- | 398  | 164     | 540     | 1999-11-10  | 1999-11-22  |
-- +------+---------+---------+-------------+-------------+
-- | 399  | 154     | 393     | 2006-10-08  | 2006-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 400  | 188     | 37      | 1994-07-14  | 1994-08-11  |
-- +------+---------+---------+-------------+-------------+
-- | 401  | 14      | 214     | 2015-11-19  | 2015-12-15  |
-- +------+---------+---------+-------------+-------------+
-- | 402  | 157     | 490     | 2016-11-09  | 2016-12-07  |
-- +------+---------+---------+-------------+-------------+
-- | 403  | 79      | 173     | 2017-08-20  | 2017-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 404  | 154     | 2       | 2006-10-08  | 2006-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 405  | 244     | 70      | 2004-07-06  | 2004-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 406  | 19      | 288     | 2001-07-05  | 2001-07-18  |
-- +------+---------+---------+-------------+-------------+
-- | 407  | 194     | 488     | 2017-05-11  | 2017-05-25  |
-- +------+---------+---------+-------------+-------------+
-- | 408  | 21      | 207     | 2004-03-18  | 2004-03-22  |
-- +------+---------+---------+-------------+-------------+
-- | 409  | 74      | 127     | 2003-10-04  | 2003-10-09  |
-- +------+---------+---------+-------------+-------------+
-- | 410  | 77      | 610     | 2017-12-15  | 2017-12-18  |
-- +------+---------+---------+-------------+-------------+
-- | 411  | 214     | 579     | 1994-12-27  | 1995-01-08  |
-- +------+---------+---------+-------------+-------------+
-- | 412  | 90      | 115     | 2009-08-09  | 2009-08-16  |
-- +------+---------+---------+-------------+-------------+
-- | 413  | 220     | 623     | 1996-08-31  | 1996-09-15  |
-- +------+---------+---------+-------------+-------------+
-- | 414  | 83      | 98      | 2012-05-29  |             |
-- +------+---------+---------+-------------+-------------+
-- | 415  | 223     | 466     | 2010-03-06  | 2010-03-12  |
-- +------+---------+---------+-------------+-------------+
-- | 416  | 34      | 579     | 1991-04-27  | 1991-05-24  |
-- +------+---------+---------+-------------+-------------+
-- | 417  | 234     | 89      | 2009-02-15  | 2009-03-13  |
-- +------+---------+---------+-------------+-------------+
-- | 418  | 189     | 448     | 2015-11-06  | 2015-11-24  |
-- +------+---------+---------+-------------+-------------+
-- | 419  | 138     | 506     | 2009-04-03  | 2009-04-07  |
-- ...
-- | 1860 | 94      | 436     | 2012-04-23  | 2012-05-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1861 | 61      | 91      | 2015-10-14  | 2015-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1862 | 247     | 286     | 2016-06-03  | 2016-06-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1863 | 169     | 384     | 2017-01-01  | 2017-01-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1864 | 151     | 529     | 1993-09-11  | 1993-10-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1865 | 0       | 563     | 2016-12-12  | 2016-12-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1866 | 84      | 453     | 1995-05-02  | 1995-05-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1867 | 68      | 82      | 2016-05-20  | 2016-05-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1868 | 76      | 53      | 2011-04-23  | 2011-05-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1869 | 155     | 17      | 2006-06-28  | 2006-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1870 | 238     | 313     | 2013-10-11  | 2013-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1871 | 101     | 438     | 2002-07-04  | 2002-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1872 | 66      | 126     | 2015-02-17  | 2015-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1873 | 182     | 524     | 2004-12-26  | 2005-01-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1874 | 212     | 416     | 1998-10-14  | 1998-10-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1875 | 227     | 135     | 2015-07-03  | 2015-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1876 | 109     | 569     | 2009-04-21  | 2009-05-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1877 | 111     | 218     | 2015-04-29  | 2015-05-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1878 | 53      | 362     | 1990-10-21  | 1990-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1879 | 155     | 580     | 2009-10-08  | 2009-10-26  |
-- +------+---------+---------+-------------+-------------+
-- | 1880 | 73      | 458     | 1997-05-11  | 1997-05-19  |
-- +------+---------+---------+-------------+-------------+
-- | 1881 | 197     | 3       | 2017-03-02  | 2017-03-25  |
-- +------+---------+---------+-------------+-------------+
-- | 1882 | 230     | 12      | 1994-02-13  | 1994-02-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1883 | 21      | 490     | 2004-03-18  | 2004-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1884 | 89      | 476     | 1991-03-11  | 1991-04-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1885 | 126     | 130     | 2001-10-14  | 2001-11-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1886 | 133     | 338     | 2018-04-23  | 2018-05-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1887 | 38      | 459     | 2006-09-01  | 2006-09-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1888 | 123     | 310     | 2009-11-05  | 2009-11-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1889 | 1       | 190     | 2008-07-04  | 2008-07-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1890 | 123     | 153     | 2009-11-05  | 2009-11-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1891 | 150     | 277     | 2017-02-22  | 2017-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1892 | 86      | 417     | 2006-01-12  | 2006-01-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1893 | 131     | 239     | 2001-07-09  | 2001-08-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1894 | 218     | 602     | 2006-05-17  | 2006-05-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1895 | 56      | 489     | 2016-08-02  | 2016-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1896 | 92      | 9       | 2016-05-06  | 2016-06-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1897 | 185     | 82      | 2015-06-02  | 2015-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1898 | 78      | 191     | 2010-12-13  | 2011-01-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1899 | 203     | 302     | 2018-08-01  | 2018-08-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1900 | 71      | 339     | 2014-06-27  | 2014-07-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1901 | 165     | 183     | 1999-08-25  | 1999-09-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1902 | 38      | 114     | 2006-09-01  | 2006-09-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1903 | 91      | 602     | 2013-07-06  | 2013-07-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1904 | 243     | 167     | 2000-11-23  | 2000-12-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1905 | 225     | 613     | 2012-09-23  | 2012-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1906 | 247     | 208     | 1992-06-14  | 1992-06-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1907 | 132     | 316     | 2004-10-16  | 2004-10-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1908 | 102     | 195     | 2013-09-11  | 2013-09-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1909 | 68      | 228     | 2016-05-20  | 2016-05-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1910 | 109     | 365     | 2009-04-21  | 2009-04-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1911 | 38      | 543     | 2015-11-09  | 2015-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1912 | 142     | 534     | 2009-10-29  | 2009-10-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1913 | 29      | 293     | 2000-02-14  | 2000-02-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1914 | 171     | 135     | 2015-07-03  | 2015-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1915 | 127     | 63      | 2006-07-26  | 2006-08-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1916 | 230     | 196     | 1994-02-13  | 1994-02-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1917 | 95      | 368     | 2012-11-27  | 2012-12-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1918 | 32      | 624     | 2012-07-22  | 2012-07-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1919 | 160     | 446     | 1990-12-18  | 1991-01-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1920 | 31      | 268     | 2001-10-18  | 2001-10-27  |
-- +------+---------+---------+-------------+-------------+
-- | 1921 | 156     | 405     | 1998-03-13  | 1998-03-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1922 | 248     | 587     | 2006-01-21  | 2006-01-25  |
-- +------+---------+---------+-------------+-------------+
-- | 1923 | 76      | 150     | 2011-04-23  | 2011-05-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1924 | 223     | 327     | 2010-03-06  | 2010-03-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1925 | 6       | 45      | 1999-02-13  | 1999-02-18  |
-- +------+---------+---------+-------------+-------------+
-- | 1926 | 1       | 504     | 2008-07-04  | 2008-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1927 | 245     | 455     | 2012-09-24  | 2012-10-19  |
-- +------+---------+---------+-------------+-------------+
-- | 1928 | 166     | 97      | 2005-06-05  | 2005-06-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1929 | 48      | 636     | 2013-06-25  | 2013-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1930 | 184     | 172     | 2012-01-16  | 2012-02-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1931 | 169     | 622     | 2017-01-01  | 2017-01-20  |
-- +------+---------+---------+-------------+-------------+
-- | 1932 | 51      | 141     | 2017-11-06  | 2017-11-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1933 | 60      | 81      | 2012-10-02  | 2012-10-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1934 | 5       | 451     | 2013-06-16  | 2013-07-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1935 | 63      | 277     | 2017-02-22  | 2017-03-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1936 | 215     | 288     | 2009-11-07  | 2009-11-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1937 | 136     | 86      | 2006-05-17  | 2006-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1938 | 33      | 436     | 2006-06-17  | 2006-06-18  |
-- +------+---------+---------+-------------+-------------+
-- | 1939 | 104     | 104     | 2007-01-12  | 2007-01-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1940 | 109     | 373     | 2009-04-21  | 2009-05-02  |
-- +------+---------+---------+-------------+-------------+
-- | 1941 | 102     | 419     | 2008-03-07  | 2008-04-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1942 | 137     | 562     | 1998-04-23  | 1998-04-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1943 | 13      | 598     | 2003-10-21  | 2003-10-28  |
-- +------+---------+---------+-------------+-------------+
-- | 1944 | 15      | 47      | 2004-08-13  | 2004-08-31  |
-- +------+---------+---------+-------------+-------------+
-- | 1945 | 87      | 563     | 2016-12-12  | 2016-12-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1946 | 193     | 323     | 2006-12-18  | 2006-12-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1947 | 69      | 428     | 2007-06-26  | 2007-07-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1948 | 24      | 217     | 2008-09-17  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1949 | 180     | 48      | 2013-06-30  | 2013-06-30  |
-- +------+---------+---------+-------------+-------------+
-- | 1950 | 44      | 65      | 1992-10-24  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1951 | 32      | 349     | 2012-07-22  | 2012-08-13  |
-- +------+---------+---------+-------------+-------------+
-- | 1952 | 207     | 7       | 2007-10-01  | 2007-10-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1953 | 201     | 50      | 1999-02-16  | 1999-02-17  |
-- +------+---------+---------+-------------+-------------+
-- | 1954 | 54      | 506     | 2017-07-29  | 2017-08-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1955 | 9       | 317     | 2013-03-07  | 2013-03-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1956 | 229     | 37      | 1991-06-21  | 1991-07-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1957 | 5       | 421     | 2013-06-16  | 2013-07-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1958 | 194     | 90      | 2017-05-11  | 2017-05-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1959 | 14      | 411     | 2013-07-10  | 2013-07-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1960 | 166     | 249     | 2005-06-05  | 2005-06-11  |
-- +------+---------+---------+-------------+-------------+
-- | 1961 | 241     | 135     | 2015-07-13  | 2015-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1962 | 31      | 445     | 2001-10-18  | 2001-11-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1963 | 237     | 230     | 2016-10-16  | 2016-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1964 | 101     | 170     | 2002-07-04  | 2002-07-30  |
-- +------+---------+---------+-------------+-------------+
-- | 1965 | 185     | 425     | 2015-06-02  | 2015-06-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1966 | 80      | 443     | 1995-11-25  | 1995-12-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1967 | 119     | 337     | 2008-11-04  | 2008-12-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1968 | 196     | 100     | 2000-06-03  | 2000-06-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1969 | 94      | 424     | 2012-04-23  | 2012-04-23  |
-- +------+---------+---------+-------------+-------------+
-- | 1970 | 187     | 282     | 2008-11-22  | 2008-12-08  |
-- +------+---------+---------+-------------+-------------+
-- | 1971 | 83      | 71      | 2012-05-29  | 2012-06-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1972 | 112     | 541     | 2015-08-13  | 2015-09-01  |
-- +------+---------+---------+-------------+-------------+
-- | 1973 | 72      | 543     | 2015-11-09  | 2015-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1974 | 56      | 564     | 2016-08-02  | 2016-08-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1975 | 168     | 530     | 2004-10-18  | 2004-11-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1976 | 220     | 256     | 2018-06-23  | 2018-07-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1977 | 240     | 503     | 2007-06-29  | 2007-07-26  |
-- +------+---------+---------+-------------+-------------+
-- | 1978 | 10      | 163     | 2017-09-08  | 2017-10-05  |
-- +------+---------+---------+-------------+-------------+
-- | 1979 | 36      | 313     | 2011-10-17  | 2011-11-15  |
-- +------+---------+---------+-------------+-------------+
-- | 1980 | 130     | 333     | 2014-12-01  | 2014-12-04  |
-- +------+---------+---------+-------------+-------------+
-- | 1981 | 33      | 347     | 2013-07-31  | 2013-08-06  |
-- +------+---------+---------+-------------+-------------+
-- | 1982 | 166     | 181     | 2016-01-26  | 2016-01-29  |
-- +------+---------+---------+-------------+-------------+
-- | 1983 | 28      | 116     | 2017-08-20  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1984 | 44      | 133     | 2017-06-10  | 2017-06-21  |
-- +------+---------+---------+-------------+-------------+
-- | 1985 | 103     | 309     | 2006-01-03  |             |
-- +------+---------+---------+-------------+-------------+
-- | 1986 | 102     | 633     | 2008-03-07  | 2008-03-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1987 | 120     | 310     | 1999-10-25  | 1999-11-09  |
-- +------+---------+---------+-------------+-------------+
-- | 1988 | 248     | 185     | 2006-01-21  | 2006-02-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1989 | 174     | 623     | 1990-03-26  | 1990-04-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1990 | 14      | 479     | 2013-07-10  | 2013-07-16  |
-- +------+---------+---------+-------------+-------------+
-- | 1991 | 36      | 211     | 1995-05-18  | 1995-06-10  |
-- +------+---------+---------+-------------+-------------+
-- | 1992 | 89      | 547     | 1991-03-11  | 1991-03-24  |
-- +------+---------+---------+-------------+-------------+
-- | 1993 | 183     | 274     | 2015-12-23  | 2016-01-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1994 | 67      | 256     | 2018-06-23  | 2018-07-22  |
-- +------+---------+---------+-------------+-------------+
-- | 1995 | 182     | 414     | 2004-12-26  | 2005-01-12  |
-- +------+---------+---------+-------------+-------------+
-- | 1996 | 127     | 230     | 2006-07-26  | 2006-08-14  |
-- +------+---------+---------+-------------+-------------+
-- | 1997 | 118     | 356     | 1998-06-26  | 1998-07-12  |
-- +------+---------+---------+-------------+-------------+
-- | 1998 | 212     | 11      | 1998-10-14  | 1998-11-03  |
-- +------+---------+---------+-------------+-------------+
-- | 1999 | 173     | 547     | 1996-07-10  | 1996-07-22  |
-- +------+---------+---------+-------------+-------------+

-- %% [markdown]
-- Zapytanie i wynik zapytania:

-- %%
SELECT users.name,users.surname, 
(
    SELECT COUNT(borrowings.ID) FROM borrowings WHERE borrowings.user_id=users.ID
) 
AS books FROM users;
-- Out:
-- +-------------+---------------+-------+
-- | name        | surname       | books |
-- +-------------+---------------+-------+
-- | Igor        | Piotrowski    | 8     |
-- +-------------+---------------+-------+
-- | Róża      | Lewandowska   | 8     |
-- +-------------+---------------+-------+
-- | Adam        | Woźniak      | 10    |
-- +-------------+---------------+-------+
-- | Michał     | Kowalczyk     | 7     |
-- +-------------+---------------+-------+
-- | Leon        | Kaczmarek     | 9     |
-- +-------------+---------------+-------+
-- | Joanna      | Kwiatkowska   | 13    |
-- +-------------+---------------+-------+
-- | Michał     | Zieliński    | 10    |
-- +-------------+---------------+-------+
-- | Małgorzata | Woźniak      | 9     |
-- +-------------+---------------+-------+
-- | Joanna      | Kaczmarek     | 10    |
-- +-------------+---------------+-------+
-- | Izabela     | Wójcik       | 11    |
-- +-------------+---------------+-------+
-- | Klaudia     | Lewandowska   | 10    |
-- +-------------+---------------+-------+
-- | Igor        | Piotrowski    | 8     |
-- +-------------+---------------+-------+
-- | Róża      | Nowak         | 4     |
-- +-------------+---------------+-------+
-- | Izabela     | Kowalska      | 3     |
-- +-------------+---------------+-------+
-- | Izabela     | Kamińska     | 10    |
-- +-------------+---------------+-------+
-- | Mateusz     | Kowalczyk     | 8     |
-- +-------------+---------------+-------+
-- | Michał     | Mazur         | 8     |
-- +-------------+---------------+-------+
-- | Piotr       | Piotrowski    | 9     |
-- +-------------+---------------+-------+
-- | Adam        | Lewandowski   | 4     |
-- +-------------+---------------+-------+
-- | Matylda     | Kowalska      | 9     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Lewandowska   | 6     |
-- +-------------+---------------+-------+
-- | Aniela      | Lewandowska   | 15    |
-- +-------------+---------------+-------+
-- | Leon        | Szymański    | 8     |
-- +-------------+---------------+-------+
-- | Joanna      | Kwiatkowska   | 8     |
-- +-------------+---------------+-------+
-- | Wiktor      | Wójcik       | 7     |
-- +-------------+---------------+-------+
-- | Piotr       | Woźniak      | 9     |
-- +-------------+---------------+-------+
-- | Stanisław  | Wójcik       | 8     |
-- +-------------+---------------+-------+
-- | Paulina     | Jankowska     | 6     |
-- +-------------+---------------+-------+
-- | Piotr       | Kowalczyk     | 11    |
-- +-------------+---------------+-------+
-- | Adam        | Wójcik       | 8     |
-- +-------------+---------------+-------+
-- | Michał     | Kozłowski    | 10    |
-- +-------------+---------------+-------+
-- | Matylda     | Mazur         | 13    |
-- +-------------+---------------+-------+
-- | Katarzyna   | Wiśniewska   | 7     |
-- +-------------+---------------+-------+
-- | Joanna      | Jankowska     | 7     |
-- +-------------+---------------+-------+
-- | Róża      | Szymańska    | 13    |
-- +-------------+---------------+-------+
-- | Piotr       | Dąbrowski    | 3     |
-- +-------------+---------------+-------+
-- | Małgorzata | Kaczmarek     | 14    |
-- +-------------+---------------+-------+
-- | Marcel      | Mazur         | 8     |
-- +-------------+---------------+-------+
-- | Marcel      | Lewandowski   | 12    |
-- +-------------+---------------+-------+
-- | Adam        | Kozłowski    | 4     |
-- +-------------+---------------+-------+
-- | Klaudia     | Szymańska    | 10    |
-- +-------------+---------------+-------+
-- | Liliana     | Grabowska     | 8     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Mazur         | 7     |
-- +-------------+---------------+-------+
-- | Mateusz     | Szymański    | 9     |
-- +-------------+---------------+-------+
-- | Klaudia     | Nowak         | 7     |
-- +-------------+---------------+-------+
-- | Piotr       | Grabowski     | 5     |
-- +-------------+---------------+-------+
-- | Marta       | Woźniak      | 8     |
-- +-------------+---------------+-------+
-- | Sara        | Nowak         | 6     |
-- +-------------+---------------+-------+
-- | Wiktor      | Piotrowski    | 8     |
-- +-------------+---------------+-------+
-- | Liliana     | Grabowska     | 5     |
-- +-------------+---------------+-------+
-- | Matylda     | Zielińska    | 5     |
-- +-------------+---------------+-------+
-- | Mateusz     | Mazur         | 4     |
-- +-------------+---------------+-------+
-- | Leon        | Lewandowski   | 7     |
-- +-------------+---------------+-------+
-- | Adam        | Dąbrowski    | 7     |
-- +-------------+---------------+-------+
-- | Joanna      | Wojciechowska | 9     |
-- +-------------+---------------+-------+
-- | Wiktor      | Kozłowski    | 6     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Kozłowska    | 5     |
-- +-------------+---------------+-------+
-- | Paulina     | Jankowska     | 9     |
-- +-------------+---------------+-------+
-- | Adam        | Krawczyk      | 7     |
-- +-------------+---------------+-------+
-- | Róża      | Woźniak      | 9     |
-- +-------------+---------------+-------+
-- | Aniela      | Kaczmarek     | 13    |
-- +-------------+---------------+-------+
-- | Matylda     | Kaczmarek     | 9     |
-- +-------------+---------------+-------+
-- | Klaudia     | Kamińska     | 4     |
-- +-------------+---------------+-------+
-- | Piotr       | Kaczmarek     | 8     |
-- +-------------+---------------+-------+
-- | Wiktor      | Mazur         | 7     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Dąbrowska    | 2     |
-- +-------------+---------------+-------+
-- | Klaudia     | Kowalska      | 8     |
-- +-------------+---------------+-------+
-- | Klaudia     | Szymańska    | 10    |
-- +-------------+---------------+-------+
-- | Wiktor      | Wójcik       | 10    |
-- +-------------+---------------+-------+
-- | Klaudia     | Grabowska     | 10    |
-- +-------------+---------------+-------+
-- | Klaudia     | Piotrowska    | 6     |
-- +-------------+---------------+-------+
-- | Stanisław  | Kozłowski    | 10    |
-- +-------------+---------------+-------+
-- | Joanna      | Mazur         | 6     |
-- +-------------+---------------+-------+
-- | Adam        | Nowak         | 6     |
-- +-------------+---------------+-------+
-- | Małgorzata | Wiśniewska   | 7     |
-- +-------------+---------------+-------+
-- | Joanna      | Kozłowska    | 8     |
-- +-------------+---------------+-------+
-- | Piotr       | Kowalski      | 10    |
-- +-------------+---------------+-------+
-- | Marcel      | Jankowski     | 7     |
-- +-------------+---------------+-------+
-- | Marta       | Lewandowska   | 7     |
-- +-------------+---------------+-------+
-- | Paulina     | Kozłowska    | 8     |
-- +-------------+---------------+-------+
-- | Mateusz     | Nowak         | 10    |
-- +-------------+---------------+-------+
-- | Klaudia     | Dąbrowska    | 11    |
-- +-------------+---------------+-------+
-- | Klaudia     | Grabowska     | 5     |
-- +-------------+---------------+-------+
-- | Marta       | Kwiatkowska   | 9     |
-- +-------------+---------------+-------+
-- | Nikodem     | Krawczyk      | 7     |
-- +-------------+---------------+-------+
-- | Michał     | Kaczmarek     | 8     |
-- +-------------+---------------+-------+
-- | Klaudia     | Wójcik       | 12    |
-- +-------------+---------------+-------+
-- | Igor        | Dąbrowski    | 8     |
-- +-------------+---------------+-------+
-- | Michał     | Kaczmarek     | 8     |
-- +-------------+---------------+-------+
-- | Aniela      | Kowalczyk     | 6     |
-- +-------------+---------------+-------+
-- | Piotr       | Lewandowski   | 18    |
-- +-------------+---------------+-------+
-- | Izabela     | Kaczmarek     | 10    |
-- +-------------+---------------+-------+
-- | Leon        | Nowak         | 7     |
-- +-------------+---------------+-------+
-- | Michał     | Kwiatkowski   | 11    |
-- +-------------+---------------+-------+
-- | Małgorzata | Wiśniewska   | 7     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Mazur         | 9     |
-- +-------------+---------------+-------+
-- | Nikodem     | Nowak         | 3     |
-- +-------------+---------------+-------+
-- | Małgorzata | Kaczmarek     | 5     |
-- +-------------+---------------+-------+
-- | Małgorzata | Lewandowska   | 7     |
-- +-------------+---------------+-------+
-- | Małgorzata | Grabowska     | 6     |
-- +-------------+---------------+-------+
-- | Mateusz     | Grabowski     | 4     |
-- +-------------+---------------+-------+
-- | Paulina     | Wojciechowska | 13    |
-- +-------------+---------------+-------+
-- | Marta       | Woźniak      | 5     |
-- +-------------+---------------+-------+
-- | Joanna      | Dąbrowska    | 7     |
-- +-------------+---------------+-------+
-- | Marcel      | Kamiński     | 11    |
-- +-------------+---------------+-------+
-- | Michał     | Nowak         | 6     |
-- +-------------+---------------+-------+
-- | Marta       | Wiśniewska   | 3     |
-- +-------------+---------------+-------+
-- | Leon        | Zieliński    | 5     |
-- +-------------+---------------+-------+
-- | Wiktor      | Wojciechowski | 8     |
-- +-------------+---------------+-------+
-- | Małgorzata | Piotrowska    | 13    |
-- +-------------+---------------+-------+
-- | Paulina     | Kowalska      | 5     |
-- +-------------+---------------+-------+
-- | Paulina     | Kwiatkowska   | 2     |
-- +-------------+---------------+-------+
-- | Aniela      | Grabowska     | 8     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Kowalczyk     | 7     |
-- +-------------+---------------+-------+
-- | Liliana     | Nowak         | 7     |
-- +-------------+---------------+-------+
-- | Leon        | Kaczmarek     | 7     |
-- +-------------+---------------+-------+
-- | Leon        | Kowalczyk     | 8     |
-- +-------------+---------------+-------+
-- | Marta       | Kowalska      | 10    |
-- +-------------+---------------+-------+
-- | Joanna      | Kowalska      | 6     |
-- +-------------+---------------+-------+
-- | Paulina     | Krawczyk      | 10    |
-- +-------------+---------------+-------+
-- | Róża      | Dąbrowska    | 14    |
-- +-------------+---------------+-------+
-- | Joanna      | Grabowska     | 9     |
-- +-------------+---------------+-------+
-- | Igor        | Grabowski     | 6     |
-- +-------------+---------------+-------+
-- | Sara        | Kaczmarek     | 14    |
-- +-------------+---------------+-------+
-- | Izabela     | Lewandowska   | 7     |
-- +-------------+---------------+-------+
-- | Izabela     | Piotrowska    | 9     |
-- +-------------+---------------+-------+
-- | Róża      | Dąbrowska    | 7     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Nowak         | 6     |
-- +-------------+---------------+-------+
-- | Małgorzata | Kaczmarek     | 9     |
-- +-------------+---------------+-------+
-- | Adam        | Kowalczyk     | 13    |
-- +-------------+---------------+-------+
-- | Adam        | Szymański    | 7     |
-- +-------------+---------------+-------+
-- | Nikodem     | Woźniak      | 4     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Wojciechowska | 8     |
-- +-------------+---------------+-------+
-- | Igor        | Kaczmarek     | 8     |
-- +-------------+---------------+-------+
-- | Nikodem     | Dąbrowski    | 3     |
-- +-------------+---------------+-------+
-- | Aniela      | Dąbrowska    | 13    |
-- +-------------+---------------+-------+
-- | Izabela     | Wójcik       | 9     |
-- +-------------+---------------+-------+
-- | Izabela     | Piotrowska    | 7     |
-- +-------------+---------------+-------+
-- | Izabela     | Kwiatkowska   | 10    |
-- +-------------+---------------+-------+
-- | Małgorzata | Kowalska      | 2     |
-- +-------------+---------------+-------+
-- | Mateusz     | Nowak         | 6     |
-- +-------------+---------------+-------+
-- | Róża      | Zielińska    | 6     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Wiśniewska   | 9     |
-- +-------------+---------------+-------+
-- | Michał     | Wiśniewski   | 6     |
-- +-------------+---------------+-------+
-- | Aniela      | Dąbrowska    | 7     |
-- +-------------+---------------+-------+
-- | Róża      | Kaczmarek     | 3     |
-- +-------------+---------------+-------+
-- | Piotr       | Kamiński     | 5     |
-- +-------------+---------------+-------+
-- | Matylda     | Woźniak      | 5     |
-- +-------------+---------------+-------+
-- | Igor        | Dąbrowski    | 10    |
-- +-------------+---------------+-------+
-- | Marcel      | Lewandowski   | 6     |
-- +-------------+---------------+-------+
-- | Małgorzata | Jankowska     | 6     |
-- +-------------+---------------+-------+
-- | Wiktor      | Kamiński     | 7     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Krawczyk      | 14    |
-- +-------------+---------------+-------+
-- | Adam        | Mazur         | 2     |
-- +-------------+---------------+-------+
-- | Sara        | Kwiatkowska   | 9     |
-- +-------------+---------------+-------+
-- | Stanisław  | Wójcik       | 13    |
-- +-------------+---------------+-------+
-- | Mateusz     | Grabowski     | 10    |
-- +-------------+---------------+-------+
-- | Katarzyna   | Wiśniewska   | 5     |
-- +-------------+---------------+-------+
-- | Michał     | Krawczyk      | 10    |
-- +-------------+---------------+-------+
-- | Piotr       | Szymański    | 12    |
-- +-------------+---------------+-------+
-- | Leon        | Kamiński     | 11    |
-- +-------------+---------------+-------+
-- | Marcel      | Krawczyk      | 9     |
-- +-------------+---------------+-------+
-- | Aniela      | Kozłowska    | 7     |
-- +-------------+---------------+-------+
-- | Leon        | Wojciechowski | 9     |
-- +-------------+---------------+-------+
-- | Liliana     | Wójcik       | 13    |
-- +-------------+---------------+-------+
-- | Wiktor      | Piotrowski    | 8     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Wiśniewska   | 10    |
-- +-------------+---------------+-------+
-- | Sara        | Kozłowska    | 6     |
-- +-------------+---------------+-------+
-- | Adam        | Woźniak      | 8     |
-- +-------------+---------------+-------+
-- | Adam        | Nowak         | 8     |
-- +-------------+---------------+-------+
-- | Róża      | Kowalska      | 11    |
-- +-------------+---------------+-------+
-- | Michał     | Lewandowski   | 8     |
-- +-------------+---------------+-------+
-- | Izabela     | Nowak         | 7     |
-- +-------------+---------------+-------+
-- | Aniela      | Nowak         | 14    |
-- +-------------+---------------+-------+
-- | Joanna      | Piotrowska    | 11    |
-- +-------------+---------------+-------+
-- | Joanna      | Kowalczyk     | 7     |
-- +-------------+---------------+-------+
-- | Liliana     | Zielińska    | 10    |
-- +-------------+---------------+-------+
-- | Paulina     | Jankowska     | 9     |
-- +-------------+---------------+-------+
-- | Stanisław  | Piotrowski    | 9     |
-- +-------------+---------------+-------+
-- | Róża      | Wiśniewska   | 8     |
-- +-------------+---------------+-------+
-- | Piotr       | Piotrowski    | 14    |
-- +-------------+---------------+-------+
-- | Nikodem     | Wójcik       | 5     |
-- +-------------+---------------+-------+
-- | Sara        | Lewandowska   | 6     |
-- +-------------+---------------+-------+
-- | Marcel      | Wójcik       | 8     |
-- +-------------+---------------+-------+
-- | Małgorzata | Jankowska     | 7     |
-- +-------------+---------------+-------+
-- | Liliana     | Wiśniewska   | 9     |
-- +-------------+---------------+-------+
-- | Stanisław  | Kowalski      | 8     |
-- +-------------+---------------+-------+
-- | Aniela      | Nowak         | 9     |
-- +-------------+---------------+-------+
-- | Marta       | Grabowska     | 10    |
-- +-------------+---------------+-------+
-- | Paulina     | Kowalska      | 7     |
-- +-------------+---------------+-------+
-- | Róża      | Dąbrowska    | 7     |
-- +-------------+---------------+-------+
-- | Marcel      | Wójcik       | 7     |
-- +-------------+---------------+-------+
-- | Matylda     | Grabowska     | 10    |
-- +-------------+---------------+-------+
-- | Nikodem     | Dąbrowski    | 7     |
-- +-------------+---------------+-------+
-- | Piotr       | Nowak         | 6     |
-- +-------------+---------------+-------+
-- | Liliana     | Woźniak      | 8     |
-- +-------------+---------------+-------+
-- | Stanisław  | Zieliński    | 12    |
-- +-------------+---------------+-------+
-- | Piotr       | Grabowski     | 9     |
-- +-------------+---------------+-------+
-- | Michał     | Szymański    | 6     |
-- +-------------+---------------+-------+
-- | Stanisław  | Kowalski      | 12    |
-- +-------------+---------------+-------+
-- | Sara        | Wójcik       | 9     |
-- +-------------+---------------+-------+
-- | Aniela      | Kozłowska    | 7     |
-- +-------------+---------------+-------+
-- | Mateusz     | Kowalski      | 6     |
-- +-------------+---------------+-------+
-- | Igor        | Kowalczyk     | 13    |
-- +-------------+---------------+-------+
-- | Leon        | Kamiński     | 2     |
-- +-------------+---------------+-------+
-- | Katarzyna   | Szymańska    | 7     |
-- +-------------+---------------+-------+
-- | Róża      | Kowalska      | 12    |
-- +-------------+---------------+-------+
-- | Marta       | Wojciechowska | 4     |
-- +-------------+---------------+-------+
-- | Małgorzata | Kwiatkowska   | 11    |
-- +-------------+---------------+-------+
-- | Joanna      | Jankowska     | 4     |
-- +-------------+---------------+-------+
-- | Igor        | Wójcik       | 5     |
-- +-------------+---------------+-------+
-- | Klaudia     | Wojciechowska | 5     |
-- +-------------+---------------+-------+
-- | Marta       | Kaczmarek     | 10    |
-- +-------------+---------------+-------+
-- | Nikodem     | Krawczyk      | 7     |
-- +-------------+---------------+-------+
-- | Klaudia     | Kozłowska    | 7     |
-- +-------------+---------------+-------+
-- | Izabela     | Zielińska    | 10    |
-- +-------------+---------------+-------+
-- | Nikodem     | Jankowski     | 7     |
-- +-------------+---------------+-------+
-- | Adam        | Mazur         | 6     |
-- +-------------+---------------+-------+
-- | Matylda     | Kaczmarek     | 8     |
-- +-------------+---------------+-------+
-- | Igor        | Wójcik       | 8     |
-- +-------------+---------------+-------+
-- | Igor        | Szymański    | 9     |
-- +-------------+---------------+-------+
-- | Paulina     | Krawczyk      | 8     |
-- +-------------+---------------+-------+
-- | Marta       | Krawczyk      | 9     |
-- +-------------+---------------+-------+
-- | Mateusz     | Kaczmarek     | 9     |
-- +-------------+---------------+-------+
-- | Stanisław  | Lewandowski   | 6     |
-- +-------------+---------------+-------+
-- | Adam        | Nowak         | 5     |
-- +-------------+---------------+-------+
-- | Sara        | Lewandowska   | 6     |
-- +-------------+---------------+-------+
-- | Piotr       | Kozłowski    | 8     |
-- +-------------+---------------+-------+
-- | Nikodem     | Dąbrowski    | 4     |
-- +-------------+---------------+-------+
-- | Nikodem     | Kaczmarek     | 12    |
-- +-------------+---------------+-------+
-- | Piotr       | Kamiński     | 12    |
-- +-------------+---------------+-------+
-- | Igor        | Mazur         | 7     |
-- +-------------+---------------+-------+
-- | Wiktor      | Wojciechowski | 7     |
-- +-------------+---------------+-------+
-- | Róża      | Szymańska    | 4     |
-- +-------------+---------------+-------+
-- | Małgorzata | Dąbrowska    | 9     |
-- +-------------+---------------+-------+
-- | Izabela     | Grabowska     | 9     |
-- +-------------+---------------+-------+
-- | Marcel      | Lewandowski   | 5     |
-- +-------------+---------------+-------+
-- | Małgorzata | Krawczyk      | 4     |
-- +-------------+---------------+-------+
-- | Izabela     | Wójcik       | 12    |
-- +-------------+---------------+-------+
-- | Stanisław  | Kowalski      | 5     |
-- +-------------+---------------+-------+
-- | Wiktor      | Nowak         | 9     |
-- +-------------+---------------+-------+
-- | Matylda     | Kwiatkowska   | 5     |
-- +-------------+---------------+-------+
-- | Paulina     | Jankowska     | 9     |
-- +-------------+---------------+-------+
-- | Adam        | Mazur         | 10    |
-- +-------------+---------------+-------+
-- | Nikodem     | Wójcik       | 8     |
-- +-------------+---------------+-------+
-- | Mateusz     | Nowak         | 7     |
-- +-------------+---------------+-------+
-- | Igor        | Wójcik       | 6     |
-- +-------------+---------------+-------+
-- | Klaudia     | Lewandowska   | 10    |
-- +-------------+---------------+-------+
-- | Małgorzata | Szymańska    | 12    |
-- +-------------+---------------+-------+
-- | Klaudia     | Woźniak      | 6     |
-- +-------------+---------------+-------+

-- %% [markdown]
-- Co ważne - w podzapytaniu (w tym przypadku z tabeli **`Borrowings`**) możemy odwołać się do tabeli i pól z zapytania zewnętrznego (**`Users`**)

-- %%
SELECT COUNT(borrowings.ID) FROM borrowings WHERE borrowings.user_id=users.ID;
-- Out:
-- Error: no such column: users.ID

-- %% [markdown]
-- ### Wydajność
--
-- Nie musimy się martwić o wydajność takich podzapytań - mimo że pozornie liczenie średniej liczby wypożyczeń powinno się wykonywać z osobna dla każdego rekordu użytkownika, baza danych optymalizuje plan zapytania. Jeśli chcemy sprawdzić, jak nasze zapytanie przekłada się na operacje wykonywane w bazie, możemy przed treścią zapytania dodać komendę `EXPLAIN QUERY PLAN` - zapytanie nie zostanie wtedy wykonane, otrzymamy jednak listę kroków, które baza danych chce wykonać.

-- %% [markdown]
-- #### Przykład
--
-- Zapytanie i wynik zapytania:

-- %%
EXPLAIN QUERY PLAN 
SELECT users.name, users.surname,COUNT(borrowings.ID) AS books_borrowed FROM users JOIN borrowings 
ON users.ID=borrowings.user_id GROUP BY users.ID HAVING books_borrowed>
(
    SELECT 1.0*COUNT(DISTINCT borrowings.ID)/count(DISTINCT borrowings.user_id) FROM borrowings
)
;
-- Out:
-- +----+--------+---------+--------------------------------------------------------------+
-- | id | parent | notused | detail                                                       |
-- +----+--------+---------+--------------------------------------------------------------+
-- | 7  | 0      | 0       | SCAN users                                                   |
-- +----+--------+---------+--------------------------------------------------------------+
-- | 20 | 0      | 0       | SEARCH borrowings USING AUTOMATIC COVERING INDEX (user_id=?) |
-- +----+--------+---------+--------------------------------------------------------------+
-- | 26 | 0      | 0       | USE TEMP B-TREE FOR GROUP BY                                 |
-- +----+--------+---------+--------------------------------------------------------------+
-- | 61 | 0      | 0       | SCALAR SUBQUERY 1                                            |
-- +----+--------+---------+--------------------------------------------------------------+
-- | 66 | 61     | 0       | USE TEMP B-TREE FOR count(DISTINCT)                          |
-- +----+--------+---------+--------------------------------------------------------------+
-- | 68 | 61     | 0       | USE TEMP B-TREE FOR count(DISTINCT)                          |
-- +----+--------+---------+--------------------------------------------------------------+
-- | 70 | 61     | 0       | SCAN borrowings                                              |
-- +----+--------+---------+--------------------------------------------------------------+

-- %% [markdown]
-- ## Zadania utrwalające 3

-- %% [markdown]
-- ### Ćwiczenia
--
-- [`03_subquerries.md`](https://github.com/pkociepka/sql/blob/master/exercises/03_subquerries.md)

-- %% [markdown]
-- ### Materiały
--
-- [`library_db.sql`](https://github.com/pkociepka/sql/blob/master/library_db.sql)
