# %% [markdown]
# # Cloud-Based Image Processing
#
# _Mikołaj Leszczuk, Szymon Turek, Jakub Nawała_

# %% [markdown]
# ## Introduction

# %% [markdown]
# The aim of this exercise is to get acquainted with the basics of programming using cloud-based image processing software. The exercise will be performed in the Python programming environment. Utilizing it, we will call remote Clarifai (cloud-based image processing software) functions.
#
# ![Clarifai Web Logo](https://upload.wikimedia.org/wikipedia/commons/b/bc/Clarifai_Logo_FC_Web.png)

# %% [markdown]
# ## Setup Tasks

# %% [markdown]
# Below are instructions for setting up an environment for computer vision applications (Python + image processing libraries).
#
# **Python** is a general-purpose high-level programming language with an extensive standard library package, whose guiding principle is the readability and clarity of the source code. Its syntax is characterized by transparency and brevity.
#
# **Clarifai** is an Artificial Intelligence (AI) cloud service that specializes in computer vision and uses machine learning and deep neural networks to identify and analyze images and videos. The cloud service offers its solutions via API, mobile SDK, and on-premises solutions.

# %% [markdown]
# ### App-Specific API Keys

# %% [markdown]
# Start by creating a free Clarifai account ([https://portal.clarifai.com/signup](https://portal.clarifai.com/signup)).
#
# App-specific API Keys are used to authorize your Clarifai applications. A key is automatically generated when you create a new application. You can also go to the application's list, select an app of your choice and create a new key in the app details page. _Each API key is tied to a specific user and a specific app._
#
# After creating a free account, the next steps are: (i) create a new application and (ii) generate the application key (the key should be put in the script).

# %% [markdown]
# ### Create an Application and Generate the Application Key

# %% [markdown]
# To create an application, head on over to the applications page and press the 'Create Application' button.

# %% [markdown]
# ![](https://gblobscdn.gitbook.com/assets%2F-LisemUaXxC3S7Kk9xFz%2Fsync%2F069fd59ae3fb51f51b3acbed9dd72e997287a0f2.png?alt=media)

# %% [markdown]
# ### API Client Installation Instructions

# %% [markdown]
# Using client library to access API.

# %% [markdown]
# #### Installation

# %% [markdown]
# **Tip 1**: Please note that if you use Python, there might be two independently configured versions installed on the machine: Python 2 (`python`) and Python 3 (`python3`). The two versions are not always compatible. We advise to use Python 3 as Python 2 support officially ended in January 2020.

# %% [markdown]
# **Tip 2**: To install Clarifai for Python, you must execute the following command (usually you do not need administrative privileges to run this command):
#
# ```sh
# pip install clarifai-grpc
# ```
#
# Please keep in mind that the _pip_ command installs packages only for Python 3.

# %% [markdown]
# **Tip 3**: In case of error messages saying that the pip version is too old, you must upgrade it by executing the following command (it can be noted that this should not be necessary and may break your machine configuration):
#
# ```sh
# pip install --upgrade pip
# ```

# %% [markdown]
# **Tip 4**: In case of error messages saying that you do not have sufficient permissions, you can use the root (administrator) account. **Before you do so, please first consult with the tutor.**

# %% [markdown]
# #### Initialize Client

# %%
from clarifai_grpc.channel.clarifai_channel import ClarifaiChannel
from clarifai_grpc.grpc.api import service_pb2_grpc

stub = service_pb2_grpc.V2Stub(ClarifaiChannel.get_grpc_channel())

# %%
from clarifai_grpc.grpc.api import service_pb2, resources_pb2
from clarifai_grpc.grpc.api.status import status_code_pb2

with open('key.txt') as f: key = f.read()

# This is how you authenticate.
metadata = (('authorization', 'Key '+key),)

request = service_pb2.PostModelOutputsRequest(
    # This is the model ID of a publicly available General model. You may use any other public or custom model ID.
    model_id='aaa03c23b3724a16a56b629203edc62c',
    inputs=[
      resources_pb2.Input(data=resources_pb2.Data(image=resources_pb2.Image(url='https://samples.clarifai.com/metro-north.jpg')))
    ])
response = stub.PostModelOutputs(request, metadata=metadata)

if response.status.code != status_code_pb2.SUCCESS:
    print("There was an error with your request!")
    print("\tCode: {}".format(response.outputs[0].status.code))
    print("\tDescription: {}".format(response.outputs[0].status.description))
    print("\tDetails: {}".format(response.outputs[0].status.details))
    raise Exception("Request failed, status code: " + str(response.status.code))

for concept in response.outputs[0].data.concepts:
    print('%12s: %.2f' % (concept.name, concept.value))
# Out:
# E1230 01:47:40.028789000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:47:40.314345000 8640116224 ssl_transport_security.cc:1455]    Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:47:40.575165000 8640116224 ssl_transport_security.cc:1455]    Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:47:40.839155000 8640116224 ssl_transport_security.cc:1455]    Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /var/folders/_p/66rl240s45j0d661qs7f096c0000gn/T/ipykernel_53016/4122612137.py in <module>
#      13       resources_pb2.Input(data=resources_pb2.Data(image=resources_pb2.Image(url='https://samples.clarifai.com/metro-north.jpg')))
#      14     ])
# ---> 15 response = stub.PostModelOutputs(request, metadata=metadata)
#      16
#      17 if response.status.code != status_code_pb2.SUCCESS:
#
# /usr/local/Caskroom/miniconda/base/lib/python3.8/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     944         state, call, = self._blocking(request, timeout, metadata, credentials,
#     945                                       wait_for_ready, compression)
# --> 946         return _end_unary_response_blocking(state, call, False, None)
#     947
#     948     def with_call(self,
#
# /usr/local/Caskroom/miniconda/base/lib/python3.8/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     847             return state.response
#     848     else:
# --> 849         raise _InactiveRpcError(state)
#     850
#     851
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1640825260.839590000","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":5420,"referenced_errors":[{"created":"@1640825260.839578000","description":"failed to connect to all addresses","file":"src/core/ext/filters/client_channel/lb_policy/pick_first/pick_first.cc","file_line":398,"grpc_status":14}]}"
# >
# E1230 01:47:50.039289000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:47:50.041022000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:00.045944000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:05.047275000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:05.049597000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:10.052399000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:10.054624000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:20.064156000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:20.065816000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:20.068716000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:30.071113000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:30.073322000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:40.081642000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:40.085059000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:50.087865000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:48:50.089586000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:00.096847000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:10.102545000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:20.108934000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:20.110628000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:30.114406000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:40.121110000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:40.132411000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:50.131399000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:50.133312000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:49:50.135045000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:00.139544000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:00.159853000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:10.150205000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:15.151354000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:20.156365000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:25.155614000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:30.161019000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:30.162732000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:35.161216000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:45.169647000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:45.171354000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:50.174142000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:55.179863000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:50:55.185588000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:51:05.186502000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:51:15.191338000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:51:25.200188000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:51:35.206883000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:51:50.217404000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:52:00.222261000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:52:00.226252000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:52:15.229120000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:52:25.238010000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:52:25.241637000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:52
 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:22:41.427538000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:22:51.433383000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:23:11.445995000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:23:16.451318000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:23:56.484466000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:11.491110000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:11.494346000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:21.498287000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:21.500805000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:36.508789000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:46.516379000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:46.519404000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:24:46.538756000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:25:06.526496000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:25:26.536795000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:25:36.548536000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:25:51.566054000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:25:56.569576000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 02:26:31.592814000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# ...
# E1230 16:32:58.324930000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:33:13.332573000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:33:23.343818000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:33:43.359449000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:33:58.374315000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:34:03.376397000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:34:08.379511000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:34:13.386314000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:34:18.389397000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:34:38.411318000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:34:43.415077000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:34:48.417643000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:35:13.437791000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:35:48.459107000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:03.473059000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:13.483040000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:28.495841000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:28.497634000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:38.506233000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:38.508619000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:43.509124000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:48.513969000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:36:53.518623000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:37:33.613343000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:08.634156000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:18.642409000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:28.653411000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:33.654677000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:38.659413000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:43.659822000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:48.659746000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:48.663461000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:53.659269000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:38:58.664775000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:39:08.674881000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:39:43.703138000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:40:08.723501000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:40:28.735520000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:40:38.743049000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:40:48.750590000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:40:48.752321000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:40:58.763053000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:41:03.764531000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:41:03.768029000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:41:08.765141000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:41:13.766275000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:41:18.770198000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:41:23.776101000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:42:23.810058000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:42:28.810790000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:42:48.827259000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:42:53.832052000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:43:03.837400000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:43:03.839149000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:43:08.840368000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:43:13.844070000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:43:13.847160000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:43:18.848130000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:43:23.851827000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:44:33.880565000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:44:43.892435000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:44:53.904706000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:44:58.909105000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:45:03.911471000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:45:33.927977000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:45:38.929080000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:45:43.929487000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:45:48.935141000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:45:53.936244000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:45:58.937551000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:46:53.970704000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:08.985676000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:13.988884000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:18.991994000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:23.997609000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:28.999091000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:39.005949000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:49.013747000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:47:59.017321000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:48:04.019727000 13115834368 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:48:14.023185000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:48:24.031442000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 16:48:34.036822000 13116907520 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.

# %%
from clarifai_grpc.channel.clarifai_channel import ClarifaiChannel
from clarifai_grpc.grpc.api import resources_pb2, service_pb2, service_pb2_grpc
from clarifai_grpc.grpc.api.status import status_pb2, status_code_pb2

channel = ClarifaiChannel.get_grpc_channel()

# Note: You can also use a secure (encrypted) ClarifaiChannel.get_grpc_channel() however
# it is currently not possible to use it with the latest gRPC version

stub = service_pb2_grpc.V2Stub(channel)

# %%
# This will be used by every Clarifai endpoint call.
with open('key.txt') as f: key = f.read()
metadata = (('authorization', 'cceba878c089479b9f71b83ab68f25bd'),)

# %% [markdown]
# ## Example - Tags Extraction on Images via URL (Prediction of Concepts in an Image)

# %% [markdown]
# The script should point the Clarifai API to a URL path to an image:

# %%
request = service_pb2.PostModelOutputsRequest(
    # This is the model ID of a publicly available General model. You may use any other public or custom model ID.
    model_id='aaa03c23b3724a16a56b629203edc62c',
    inputs=[
      resources_pb2.Input(data=resources_pb2.Data(image=resources_pb2.Image(url='https://samples.clarifai.com/metro-north.jpg')))
    ])
response = stub.PostModelOutputs(request, metadata=metadata)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /var/folders/_p/66rl240s45j0d661qs7f096c0000gn/T/ipykernel_53016/3133702519.py in <module>
#       5       resources_pb2.Input(data=resources_pb2.Data(image=resources_pb2.Image(url='https://samples.clarifai.com/metro-north.jpg')))
#       6     ])
# ----> 7 response = stub.PostModelOutputs(request, metadata=metadata)
#
# /usr/local/Caskroom/miniconda/base/lib/python3.8/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     944         state, call, = self._blocking(request, timeout, metadata, credentials,
#     945                                       wait_for_ready, compression)
# --> 946         return _end_unary_response_blocking(state, call, False, None)
#     947
#     948     def with_call(self,
#
# /usr/local/Caskroom/miniconda/base/lib/python3.8/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     847             return state.response
#     848     else:
# --> 849         raise _InactiveRpcError(state)
#     850
#     851
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1640824095.218100000","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":5420,"referenced_errors":[{"created":"@1640824066.718824000","description":"failed to connect to all addresses","file":"src/core/ext/filters/client_channel/lb_policy/pick_first/pick_first.cc","file_line":398,"grpc_status":14}]}"
# >
# E1230 01:28:54.164355000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:29:04.167514000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.
# E1230 01:29:14.172459000 13116370944 ssl_transport_security.cc:1455]   Handshake failed with fatal error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED.

# %% [markdown]
# ```python
# if response.status.code != status_code_pb2.SUCCESS:
#     raise Exception("Request failed, status code: " + str(response.status.code))
# ```

# %% [markdown]
# Finally, please print the output data:

# %% [markdown]
# ```python
# print(response)
# ```

# %% [markdown]
# As the response is formatted using JSON (JavaScript Object Notation), instead of the regular **`print`**, it is better to use:

# %% [markdown]
# ```python
# for concept in response.outputs[0].data.concepts:
#     print('%12s: %.2f' % (concept.name, concept.value))
# ```

# %% [markdown]
# ## Tasks

# %% [markdown]
# Please perform the following tasks.
#
# Please perform automatic extraction of machine markers (tags), using Clarifai and Python (the script should be written in Python 3).

# %% [markdown]
# ### Classifying Image Content with Images Sent as Binary Data

# %% [markdown]
# Send the binary payload of an image and receive back predictions from the **`general`** model.
#
# **Please note that for this exercise you do not find the appropriate functions in the lecture slides. Independent studying of the documentation is necessary.**

# %% [markdown]
# ### (Optional) Classifying Video Content

# %% [markdown]
# Please send a binary payload to a video through the Clarifai API. You should receive back tags for each second of a video.
#
# Please note that similarly to the previous exercise, you must look through the documentation to find appropriate API functions.
#
# **If you manage to make this exercise, please send your source code to the tutor.**
#
# **The additional exercise is worth 5 points.**

# %% [markdown]
# ## Additional References

# %% [markdown]
# 1. “Getting Started Guide | Clarifai Developer” (link to the documentation),
# [https://www.clarifai.com/developer/guide/](https://www.clarifai.com/developer/guide/)
# 1. “Sign Up | Clarifai Developer” (setting up a free account),
# [https://clarifai.com/developer/account/signup](https://clarifai.com/developer/account/signup)
# 1. “Applications | Clarifai Developer” (creating a new application),
# [https://clarifai.com/developer/account/applications](https://clarifai.com/developer/account/applications)
# 1. “API Keys | Clarifai Developer” (generation of the application key),
# [https://www.clarifai.com/developer/account/keys](https://www.clarifai.com/developer/account/keys)
