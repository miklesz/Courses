# %%
python3 manage.py runserver
# Out:
# python3 manage.py runserver
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# May 19, 2024 - 13:30:03
# Django version 5.0.4, using settings 'goodmovies.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
#
# [19/May/2024 13:30:19] "GET /filmy/ HTTP/1.1" 200 0
# /Users/miklesz/Documents/Teaching/Courses/Django/goodmovies/urls.py changed, reloading.
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# May 19, 2024 - 13:30:30
# Django version 5.0.4, using settings 'goodmovies.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
#
# [19/May/2024 13:33:19] "GET /filmy/ HTTP/1.1" 200 341
# [19/May/2024 13:35:33] "GET /filmy/ HTTP/1.1" 200 396
# [19/May/2024 13:42:00] "GET /filmy/ HTTP/1.1" 200 396
# ...
