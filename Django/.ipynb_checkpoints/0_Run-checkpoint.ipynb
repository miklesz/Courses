# %%
python3 manage.py runserver
# Out:
# python3 manage.py runserver
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# April 26, 2025 - 00:19:36
# Django version 5.2, using settings 'goodmovies.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
#
# WARNING: This is a development server. Do not use it in a production setting. Use a production WSGI or ASGI server instead.
# For more information on production servers see: https://docs.djangoproject.com/en/5.2/howto/deployment/
# [26/Apr/2025 00:19:41] "GET /admin/ HTTP/1.1" 200 7148
# [26/Apr/2025 00:21:37] "GET /admin/movies/movie/ HTTP/1.1" 200 8219
# [26/Apr/2025 00:21:37] "GET /admin/jsi18n/ HTTP/1.1" 200 3342
# [26/Apr/2025 00:21:39] "GET /admin/movies/movie/add/ HTTP/1.1" 200 10640
# [26/Apr/2025 00:21:39] "GET /static/admin/css/forms.css HTTP/1.1" 200 8525
# [26/Apr/2025 00:21:39] "GET /static/admin/js/change_form.js HTTP/1.1" 200 606
# ...
